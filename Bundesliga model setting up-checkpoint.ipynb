# %%
import soccerdata as sd
understat = sd.Understat(leagues="GER-Bundesliga", seasons="2023/2024")
team_match_stats = understat.read_team_match_stats()
team_match_stats.head()
# Out:
# [03/26/24 20:12:58] INFO     Saving cached data to C:\Users\jbuck\soccerdata\data\Understat           ]8;id=818707;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=589730;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\
#                                                                          league_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                     3
#                       2023-08-19 Augsburg-Borussia M.Gladbach                    3
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig         3
#                       2023-08-19 Borussia Dortmund-FC Cologne                    3
#                       2023-08-19 Hoffenheim-Freiburg                             3
#
#                                                                           season_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                   2023
#                       2023-08-19 Augsburg-Borussia M.Gladbach                  2023
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig       2023
#                       2023-08-19 Borussia Dortmund-FC Cologne                  2023
#                       2023-08-19 Hoffenheim-Freiburg                           2023
#
#                                                                           game_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                23065
#                       2023-08-19 Augsburg-Borussia M.Gladbach               23069
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig    23066
#                       2023-08-19 Borussia Dortmund-FC Cologne               23071
#                       2023-08-19 Hoffenheim-Freiburg                        23068
#
#                                                                                         date  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich             2023-08-18 18:30:00
#                       2023-08-19 Augsburg-Borussia M.Gladbach            2023-08-19 13:30:00
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig 2023-08-19 13:30:00
#                       2023-08-19 Borussia Dortmund-FC Cologne            2023-08-19 16:30:00
#                       2023-08-19 Hoffenheim-Freiburg                     2023-08-19 13:30:00
#
#                                                                           home_team_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                       123
#                       2023-08-19 Augsburg-Borussia M.Gladbach                      121
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig           119
#                       2023-08-19 Borussia Dortmund-FC Cologne                      129
#                       2023-08-19 Hoffenheim-Freiburg                               120
#
#                                                                           away_team_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                       117
#                       2023-08-19 Augsburg-Borussia M.Gladbach                      130
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig           136
#                       2023-08-19 Borussia Dortmund-FC Cologne                      134
#                       2023-08-19 Hoffenheim-Freiburg                               135
#
#                                                                                   home_team  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                  Werder Bremen
#                       2023-08-19 Augsburg-Borussia M.Gladbach                      Augsburg
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig   Bayer Leverkusen
#                       2023-08-19 Borussia Dortmund-FC Cologne             Borussia Dortmund
#                       2023-08-19 Hoffenheim-Freiburg                             Hoffenheim
#
#                                                                                        away_team  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                       Bayern Munich
#                       2023-08-19 Augsburg-Borussia M.Gladbach                Borussia M.Gladbach
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  RasenBallsport Leipzig
#                       2023-08-19 Borussia Dortmund-FC Cologne                         FC Cologne
#                       2023-08-19 Hoffenheim-Freiburg                                    Freiburg
#
#                                                                          away_team_code  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                        BAY
#                       2023-08-19 Augsburg-Borussia M.Gladbach                       BMG
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig            RBL
#                       2023-08-19 Borussia Dortmund-FC Cologne                       COL
#                       2023-08-19 Hoffenheim-Freiburg                                FRE
#
#                                                                          home_team_code  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                        WER
#                       2023-08-19 Augsburg-Borussia M.Gladbach                       AUG
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig            LEV
#                       2023-08-19 Borussia Dortmund-FC Cologne                       DOR
#                       2023-08-19 Hoffenheim-Freiburg                                HOF
#
#                                                                           ...  \
# league         season game                                                ...
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich              ...
#                       2023-08-19 Augsburg-Borussia M.Gladbach             ...
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  ...
#                       2023-08-19 Borussia Dortmund-FC Cologne             ...
#                       2023-08-19 Hoffenheim-Freiburg                      ...
#
#                                                                           away_ppda  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich              19.714286
#                       2023-08-19 Augsburg-Borussia M.Gladbach                  19.5
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  12.105263
#                       2023-08-19 Borussia Dortmund-FC Cologne             19.608696
#                       2023-08-19 Hoffenheim-Freiburg                      21.727273
#
#                                                                           away_deep_completions  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                                 16
#                       2023-08-19 Augsburg-Borussia M.Gladbach                                 7
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig                      4
#                       2023-08-19 Borussia Dortmund-FC Cologne                                 8
#                       2023-08-19 Hoffenheim-Freiburg                                          7
#
#                                                                           home_points  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                        0
#                       2023-08-19 Augsburg-Borussia M.Gladbach                       1
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig            3
#                       2023-08-19 Borussia Dortmund-FC Cologne                       3
#                       2023-08-19 Hoffenheim-Freiburg                                0
#
#                                                                           home_expected_points  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                            0.1813
#                       2023-08-19 Augsburg-Borussia M.Gladbach                           1.8311
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig                1.4839
#                       2023-08-19 Borussia Dortmund-FC Cologne                           1.5453
#                       2023-08-19 Hoffenheim-Freiburg                                    0.5233
#
#                                                                           home_goals  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                       0
#                       2023-08-19 Augsburg-Borussia M.Gladbach                      4
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig           3
#                       2023-08-19 Borussia Dortmund-FC Cologne                      1
#                       2023-08-19 Hoffenheim-Freiburg                               1
#
#                                                                           home_xg  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich              0.63974
#                       2023-08-19 Augsburg-Borussia M.Gladbach             2.53482
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  1.73279
#                       2023-08-19 Borussia Dortmund-FC Cologne             1.72317
#                       2023-08-19 Hoffenheim-Freiburg                      1.67186
#
#                                                                           home_np_xg  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                 0.63974
#                       2023-08-19 Augsburg-Borussia M.Gladbach                1.77704
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig     1.73279
#                       2023-08-19 Borussia Dortmund-FC Cologne                1.72317
#                       2023-08-19 Hoffenheim-Freiburg                         1.67186
#
#                                                                           home_np_xg_difference  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                            -2.2573
#                       2023-08-19 Augsburg-Borussia M.Gladbach                           0.61633
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig                0.12886
#                       2023-08-19 Borussia Dortmund-FC Cologne                           0.20924
#                       2023-08-19 Hoffenheim-Freiburg                                   -1.57635
#
#                                                                           home_ppda  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich              12.433333
#                       2023-08-19 Augsburg-Borussia M.Gladbach             11.176471
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  14.333333
#                       2023-08-19 Borussia Dortmund-FC Cologne              8.272727
#                       2023-08-19 Hoffenheim-Freiburg                      11.045455
#
#                                                                           home_deep_completions
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                                  2
#                       2023-08-19 Augsburg-Borussia M.Gladbach                                12
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig                      5
#                       2023-08-19 Borussia Dortmund-FC Cologne                                 5
#                       2023-08-19 Hoffenheim-Freiburg                                          8
#
# [5 rows x 26 columns]

# %%
import pandas as pd

# Assuming 'team_match_stats' is your DataFrame loaded from the code you've provided

# Calculating total xG for teams when they are at home
home_xg = team_match_stats.groupby('home_team')['home_xg'].sum().rename('total_home_xg')

# Calculating total xG for teams when they are away
away_xg = team_match_stats.groupby('away_team')['away_xg'].sum().rename('total_away_xg')

# Calculating total xGA (expected goals against) for teams when they are at home
home_xga = team_match_stats.groupby('home_team')['away_xg'].sum().rename('total_home_xga')

# Calculating total xGA for teams when they are away
away_xga = team_match_stats.groupby('away_team')['home_xg'].sum().rename('total_away_xga')

# Merging the above series into a single DataFrame
teams_xg_xga = pd.concat([home_xg, away_xg, home_xga, away_xga], axis=1)

# Filling NaN values with 0, in case some teams didn't play home or away games yet
teams_xg_xga = teams_xg_xga.fillna(0)

# Calculating overall total xG and xGA
teams_xg_xga['total_xg'] = teams_xg_xga['total_home_xg'] + teams_xg_xga['total_away_xg']
teams_xg_xga['total_xga'] = teams_xg_xga['total_home_xga'] + teams_xg_xga['total_away_xga']

teams_xg_xga
# Out:
#                         total_home_xg  total_away_xg  total_home_xga  \
# Augsburg                    19.883267      19.116624       19.392782
# Bayer Leverkusen               33.418      26.171382        9.022861
# Bayern Munich                44.20542      34.603918       10.580899
# Bochum                      24.546587       13.20738       18.746351
# Borussia Dortmund            31.24126       24.23116       17.168898
# Borussia M.Gladbach         23.210002      17.359368       18.672592
# Darmstadt                   18.499344      10.059558       29.462206
# Eintracht Frankfurt         21.608295      17.153107       14.606714
# FC Cologne                  15.267248      14.603034       26.973148
# FC Heidenheim                17.74534      14.083649       22.143478
# Freiburg                    25.905458      14.524663        21.18532
# Hoffenheim                  21.012603      19.856981       22.247943
# Mainz 05                    18.383334       14.82805       13.429069
# RasenBallsport Leipzig      32.735063      23.638301       14.411941
# Union Berlin                20.154791      14.062537       18.987388
# VfB Stuttgart                37.24799      24.306257       12.762305
# Werder Bremen               19.440576      14.345215       19.475075
# Wolfsburg                   20.488287      12.727219       19.609433
#
#                         total_away_xga   total_xg  total_xga
# Augsburg                      25.14283  38.999891  44.535612
# Bayer Leverkusen              15.80107  59.589382  24.823931
# Bayern Munich                15.221863  78.809338  25.802762
# Bochum                       35.378538  37.753967  54.124889
# Borussia Dortmund             23.02395   55.47242  40.192848
# Borussia M.Gladbach           29.02209   40.56937  47.694682
# Darmstadt                     31.67986  28.558902  61.142066
# Eintracht Frankfurt          27.584951  38.761402  42.191665
# FC Cologne                   31.489607  29.870282  58.462755
# FC Heidenheim                28.739124  31.828989  50.882602
# Freiburg                     25.600593  40.430121  46.785913
# Hoffenheim                   29.282203  40.869584  51.530146
# Mainz 05                     25.616053  33.211384  39.045122
# RasenBallsport Leipzig       17.366063  56.373364  31.778004
# Union Berlin                 22.822004  34.217328  41.809392
# VfB Stuttgart                17.379457  61.554247  30.141762
# Werder Bremen                23.746578  33.785791  43.221653
# Wolfsburg                    20.096031  33.215506  39.705464

# %%
import pandas as pd

# Identify all unique teams
teams = pd.concat([team_match_stats['home_team'], team_match_stats['away_team']]).unique()

# Prepare a list to collect each team's average xG and xGA for home and away games
team_averages = []

# Iterate through each team
for team in teams:
    # Filter home games involving the current team
    team_home_games = team_match_stats[team_match_stats['home_team'] == team]
    # Sort home games by date in descending order and select the last 5
    team_last_5_home_games = team_home_games.sort_values(by='date', ascending=False).head(5)
    
    # Filter away games involving the current team
    team_away_games = team_match_stats[team_match_stats['away_team'] == team]
    # Sort away games by date in descending order and select the last 5
    team_last_5_away_games = team_away_games.sort_values(by='date', ascending=False).head(5)
    
    # Calculate average xG and xGA for home games
    team_home_xg_avg = team_last_5_home_games['home_xg'].mean()
    team_home_xga_avg = team_last_5_home_games['away_xg'].mean()
    
    # Calculate average xG and xGA for away games
    team_away_xg_avg = team_last_5_away_games['away_xg'].mean()
    team_away_xga_avg = team_last_5_away_games['home_xg'].mean()
    
    # Append the averages to the list
    team_averages.append({
        'Team': team,
        'Average Home xG Last 5': team_home_xg_avg,
        'Average Home xGA Last 5': team_home_xga_avg,
        'Average Away xG Last 5': team_away_xg_avg,
        'Average Away xGA Last 5': team_away_xga_avg
    })

# Convert the list of averages into a DataFrame
teams_xg_xga_df = pd.DataFrame(team_averages)

# Display the DataFrame
teams_xg_xga_df
# Out:
#                       Team  Average Home xG Last 5  Average Home xGA Last 5  \
# 0            Werder Bremen                1.675010                 1.525979
# 1                 Augsburg                1.449081                 1.615124
# 2         Bayer Leverkusen                2.290800                 0.428071
# 3        Borussia Dortmund                2.710048                 0.773196
# 4               Hoffenheim                1.500805                 1.592522
# 5            VfB Stuttgart                2.227576                 0.922358
# 6                Wolfsburg                1.701490                 1.104354
# 7      Eintracht Frankfurt                2.037366                 0.904373
# 8             Union Berlin                1.551903                 1.176962
# 9   RasenBallsport Leipzig                2.354288                 1.049524
# 10                  Bochum                1.162409                 1.961814
# 11     Borussia M.Gladbach                2.314394                 1.347724
# 12               Darmstadt                1.369712                 2.746154
# 13              FC Cologne                1.318688                 2.311790
# 14           FC Heidenheim                1.071866                 1.262144
# 15                Freiburg                1.773620                 2.160272
# 16           Bayern Munich                2.982958                 0.667677
# 17                Mainz 05                1.693626                 0.936921
#
#     Average Away xG Last 5  Average Away xGA Last 5
# 0                 0.871748                 1.341538
# 1                 1.597203                 1.692342
# 2                 2.075188                 0.987391
# 3                 1.675590                 1.373790
# 4                 1.465362                 2.819116
# 5                 2.138152                 1.147025
# 6                 0.851587                 1.153940
# 7                 1.250210                 1.987706
# 8                 1.135341                 1.572870
# 9                 1.781359                 1.534733
# 10                0.943733                 2.970382
# 11                0.874833                 2.020422
# 12                0.811239                 2.736358
# 13                0.759527                 1.831419
# 14                1.229854                 1.490951
# 15                1.204041                 2.199422
# 16                2.683120                 1.757484
# 17                1.007724                 2.579058

# %%
# Count the number of home matches played by each team
home_matches_played = team_match_stats.groupby('home_team')['home_ppda'].count().rename('home_matches_played')

# Count the number of away matches played by each team
away_matches_played = team_match_stats.groupby('away_team')['away_ppda'].count().rename('away_matches_played')

# Merging these counts into the teams_xg_xga DataFrame
teams_xg_xga = teams_xg_xga.merge(home_matches_played, how='left', left_index=True, right_index=True)
teams_xg_xga = teams_xg_xga.merge(away_matches_played, how='left', left_index=True, right_index=True)

# Filling NaN values with 0 in case some teams didn't play home or away games
teams_xg_xga['home_matches_played'] = teams_xg_xga['home_matches_played'].fillna(0)
teams_xg_xga['away_matches_played'] = teams_xg_xga['away_matches_played'].fillna(0)

# Calculating the total matches played by adding home and away matches
teams_xg_xga['matches_played'] = teams_xg_xga['home_matches_played'] + teams_xg_xga['away_matches_played']

teams_xg_xga
# Out:
#                         total_home_xg  total_away_xg  total_home_xga  \
# Augsburg                    19.883267      19.116624       19.392782
# Bayer Leverkusen               33.418      26.171382        9.022861
# Bayern Munich                44.20542      34.603918       10.580899
# Bochum                      24.546587       13.20738       18.746351
# Borussia Dortmund            31.24126       24.23116       17.168898
# Borussia M.Gladbach         23.210002      17.359368       18.672592
# Darmstadt                   18.499344      10.059558       29.462206
# Eintracht Frankfurt         21.608295      17.153107       14.606714
# FC Cologne                  15.267248      14.603034       26.973148
# FC Heidenheim                17.74534      14.083649       22.143478
# Freiburg                    25.905458      14.524663        21.18532
# Hoffenheim                  21.012603      19.856981       22.247943
# Mainz 05                    18.383334       14.82805       13.429069
# RasenBallsport Leipzig      32.735063      23.638301       14.411941
# Union Berlin                20.154791      14.062537       18.987388
# VfB Stuttgart                37.24799      24.306257       12.762305
# Werder Bremen               19.440576      14.345215       19.475075
# Wolfsburg                   20.488287      12.727219       19.609433
#
#                         total_away_xga   total_xg  total_xga  \
# Augsburg                      25.14283  38.999891  44.535612
# Bayer Leverkusen              15.80107  59.589382  24.823931
# Bayern Munich                15.221863  78.809338  25.802762
# Bochum                       35.378538  37.753967  54.124889
# Borussia Dortmund             23.02395   55.47242  40.192848
# Borussia M.Gladbach           29.02209   40.56937  47.694682
# Darmstadt                     31.67986  28.558902  61.142066
# Eintracht Frankfurt          27.584951  38.761402  42.191665
# FC Cologne                   31.489607  29.870282  58.462755
# FC Heidenheim                28.739124  31.828989  50.882602
# Freiburg                     25.600593  40.430121  46.785913
# Hoffenheim                   29.282203  40.869584  51.530146
# Mainz 05                     25.616053  33.211384  39.045122
# RasenBallsport Leipzig       17.366063  56.373364  31.778004
# Union Berlin                 22.822004  34.217328  41.809392
# VfB Stuttgart                17.379457  61.554247  30.141762
# Werder Bremen                23.746578  33.785791  43.221653
# Wolfsburg                    20.096031  33.215506  39.705464
#
#                         home_matches_played  away_matches_played  \
# Augsburg                                 13                   13
# Bayer Leverkusen                         13                   13
# Bayern Munich                            13                   13
# Bochum                                   13                   13
# Borussia Dortmund                        13                   13
# Borussia M.Gladbach                      13                   13
# Darmstadt                                14                   12
# Eintracht Frankfurt                      12                   14
# FC Cologne                               13                   13
# FC Heidenheim                            13                   13
# Freiburg                                 13                   13
# Hoffenheim                               13                   13
# Mainz 05                                 13                   13
# RasenBallsport Leipzig                   13                   13
# Union Berlin                             13                   13
# VfB Stuttgart                            13                   13
# Werder Bremen                            13                   13
# Wolfsburg                                13                   13
#
#                         matches_played
# Augsburg                            26
# Bayer Leverkusen                    26
# Bayern Munich                       26
# Bochum                              26
# Borussia Dortmund                   26
# Borussia M.Gladbach                 26
# Darmstadt                           26
# Eintracht Frankfurt                 26
# FC Cologne                          26
# FC Heidenheim                       26
# Freiburg                            26
# Hoffenheim                          26
# Mainz 05                            26
# RasenBallsport Leipzig              26
# Union Berlin                        26
# VfB Stuttgart                       26
# Werder Bremen                       26
# Wolfsburg                           26

# %%
# Calculating xG difference for home games
teams_xg_xga['home_xg_diff'] = teams_xg_xga['total_home_xg'] - teams_xg_xga['total_home_xga']

# Calculating xG difference for away games
teams_xg_xga['away_xg_diff'] = teams_xg_xga['total_away_xg'] - teams_xg_xga['total_away_xga']

# Display the updated DataFrame
teams_xg_xga
# Out:
#                         total_home_xg  total_away_xg  total_home_xga  \
# Augsburg                    19.883267      19.116624       19.392782
# Bayer Leverkusen               33.418      26.171382        9.022861
# Bayern Munich                44.20542      34.603918       10.580899
# Bochum                      24.546587       13.20738       18.746351
# Borussia Dortmund            31.24126       24.23116       17.168898
# Borussia M.Gladbach         23.210002      17.359368       18.672592
# Darmstadt                   18.499344      10.059558       29.462206
# Eintracht Frankfurt         21.608295      17.153107       14.606714
# FC Cologne                  15.267248      14.603034       26.973148
# FC Heidenheim                17.74534      14.083649       22.143478
# Freiburg                    25.905458      14.524663        21.18532
# Hoffenheim                  21.012603      19.856981       22.247943
# Mainz 05                    18.383334       14.82805       13.429069
# RasenBallsport Leipzig      32.735063      23.638301       14.411941
# Union Berlin                20.154791      14.062537       18.987388
# VfB Stuttgart                37.24799      24.306257       12.762305
# Werder Bremen               19.440576      14.345215       19.475075
# Wolfsburg                   20.488287      12.727219       19.609433
#
#                         total_away_xga   total_xg  total_xga  \
# Augsburg                      25.14283  38.999891  44.535612
# Bayer Leverkusen              15.80107  59.589382  24.823931
# Bayern Munich                15.221863  78.809338  25.802762
# Bochum                       35.378538  37.753967  54.124889
# Borussia Dortmund             23.02395   55.47242  40.192848
# Borussia M.Gladbach           29.02209   40.56937  47.694682
# Darmstadt                     31.67986  28.558902  61.142066
# Eintracht Frankfurt          27.584951  38.761402  42.191665
# FC Cologne                   31.489607  29.870282  58.462755
# FC Heidenheim                28.739124  31.828989  50.882602
# Freiburg                     25.600593  40.430121  46.785913
# Hoffenheim                   29.282203  40.869584  51.530146
# Mainz 05                     25.616053  33.211384  39.045122
# RasenBallsport Leipzig       17.366063  56.373364  31.778004
# Union Berlin                 22.822004  34.217328  41.809392
# VfB Stuttgart                17.379457  61.554247  30.141762
# Werder Bremen                23.746578  33.785791  43.221653
# Wolfsburg                    20.096031  33.215506  39.705464
#
#                         home_matches_played  away_matches_played  \
# Augsburg                                 13                   13
# Bayer Leverkusen                         13                   13
# Bayern Munich                            13                   13
# Bochum                                   13                   13
# Borussia Dortmund                        13                   13
# Borussia M.Gladbach                      13                   13
# Darmstadt                                14                   12
# Eintracht Frankfurt                      12                   14
# FC Cologne                               13                   13
# FC Heidenheim                            13                   13
# Freiburg                                 13                   13
# Hoffenheim                               13                   13
# Mainz 05                                 13                   13
# RasenBallsport Leipzig                   13                   13
# Union Berlin                             13                   13
# VfB Stuttgart                            13                   13
# Werder Bremen                            13                   13
# Wolfsburg                                13                   13
#
#                         matches_played  home_xg_diff  away_xg_diff
# Augsburg                            26      0.490485     -6.026206
# Bayer Leverkusen                    26     24.395139     10.370312
# Bayern Munich                       26     33.624521     19.382055
# Bochum                              26      5.800236    -22.171158
# Borussia Dortmund                   26     14.072362       1.20721
# Borussia M.Gladbach                 26       4.53741    -11.662722
# Darmstadt                           26    -10.962862    -21.620302
# Eintracht Frankfurt                 26      7.001581    -10.431844
# FC Cologne                          26      -11.7059    -16.886573
# FC Heidenheim                       26     -4.398138    -14.655475
# Freiburg                            26      4.720138     -11.07593
# Hoffenheim                          26      -1.23534     -9.425222
# Mainz 05                            26      4.954265    -10.788003
# RasenBallsport Leipzig              26     18.323122      6.272238
# Union Berlin                        26      1.167403     -8.759467
# VfB Stuttgart                       26     24.485685        6.9268
# Werder Bremen                       26     -0.034499     -9.401363
# Wolfsburg                           26      0.878854     -7.368812

# %%
# Assuming 'teams_xg_xga' is your DataFrame

# Calculate the averages for each specified column
averages = teams_xg_xga.mean()

# Creating a new DataFrame with the averages to append it properly with a label
averages_df = pd.DataFrame([averages], index=['Average'])

# Append the averages row to your original DataFrame
teams_xg_xga_with_averages = pd.concat([teams_xg_xga, averages_df])

teams_xg_xga_with_averages
# Out:
#                         total_home_xg  total_away_xg  total_home_xga  \
# Augsburg                    19.883267      19.116624       19.392782
# Bayer Leverkusen               33.418      26.171382        9.022861
# Bayern Munich                44.20542      34.603918       10.580899
# Bochum                      24.546587       13.20738       18.746351
# Borussia Dortmund            31.24126       24.23116       17.168898
# Borussia M.Gladbach         23.210002      17.359368       18.672592
# Darmstadt                   18.499344      10.059558       29.462206
# Eintracht Frankfurt         21.608295      17.153107       14.606714
# FC Cologne                  15.267248      14.603034       26.973148
# FC Heidenheim                17.74534      14.083649       22.143478
# Freiburg                    25.905458      14.524663        21.18532
# Hoffenheim                  21.012603      19.856981       22.247943
# Mainz 05                    18.383334       14.82805       13.429069
# RasenBallsport Leipzig      32.735063      23.638301       14.411941
# Union Berlin                20.154791      14.062537       18.987388
# VfB Stuttgart                37.24799      24.306257       12.762305
# Werder Bremen               19.440576      14.345215       19.475075
# Wolfsburg                   20.488287      12.727219       19.609433
# Average                     24.721826      18.271022       18.271022
#
#                         total_away_xga   total_xg  total_xga  \
# Augsburg                      25.14283  38.999891  44.535612
# Bayer Leverkusen              15.80107  59.589382  24.823931
# Bayern Munich                15.221863  78.809338  25.802762
# Bochum                       35.378538  37.753967  54.124889
# Borussia Dortmund             23.02395   55.47242  40.192848
# Borussia M.Gladbach           29.02209   40.56937  47.694682
# Darmstadt                     31.67986  28.558902  61.142066
# Eintracht Frankfurt          27.584951  38.761402  42.191665
# FC Cologne                   31.489607  29.870282  58.462755
# FC Heidenheim                28.739124  31.828989  50.882602
# Freiburg                     25.600593  40.430121  46.785913
# Hoffenheim                   29.282203  40.869584  51.530146
# Mainz 05                     25.616053  33.211384  39.045122
# RasenBallsport Leipzig       17.366063  56.373364  31.778004
# Union Berlin                 22.822004  34.217328  41.809392
# VfB Stuttgart                17.379457  61.554247  30.141762
# Werder Bremen                23.746578  33.785791  43.221653
# Wolfsburg                    20.096031  33.215506  39.705464
# Average                      24.721826  42.992848  42.992848
#
#                         home_matches_played  away_matches_played  \
# Augsburg                               13.0                 13.0
# Bayer Leverkusen                       13.0                 13.0
# Bayern Munich                          13.0                 13.0
# Bochum                                 13.0                 13.0
# Borussia Dortmund                      13.0                 13.0
# Borussia M.Gladbach                    13.0                 13.0
# Darmstadt                              14.0                 12.0
# Eintracht Frankfurt                    12.0                 14.0
# FC Cologne                             13.0                 13.0
# FC Heidenheim                          13.0                 13.0
# Freiburg                               13.0                 13.0
# Hoffenheim                             13.0                 13.0
# Mainz 05                               13.0                 13.0
# RasenBallsport Leipzig                 13.0                 13.0
# Union Berlin                           13.0                 13.0
# VfB Stuttgart                          13.0                 13.0
# Werder Bremen                          13.0                 13.0
# Wolfsburg                              13.0                 13.0
# Average                                13.0                 13.0
#
#                         matches_played  home_xg_diff  away_xg_diff
# Augsburg                          26.0      0.490485     -6.026206
# Bayer Leverkusen                  26.0     24.395139     10.370312
# Bayern Munich                     26.0     33.624521     19.382055
# Bochum                            26.0      5.800236    -22.171158
# Borussia Dortmund                 26.0     14.072362       1.20721
# Borussia M.Gladbach               26.0       4.53741    -11.662722
# Darmstadt                         26.0    -10.962862    -21.620302
# Eintracht Frankfurt               26.0      7.001581    -10.431844
# FC Cologne                        26.0      -11.7059    -16.886573
# FC Heidenheim                     26.0     -4.398138    -14.655475
# Freiburg                          26.0      4.720138     -11.07593
# Hoffenheim                        26.0      -1.23534     -9.425222
# Mainz 05                          26.0      4.954265    -10.788003
# RasenBallsport Leipzig            26.0     18.323122      6.272238
# Union Berlin                      26.0      1.167403     -8.759467
# VfB Stuttgart                     26.0     24.485685        6.9268
# Werder Bremen                     26.0     -0.034499     -9.401363
# Wolfsburg                         26.0      0.878854     -7.368812
# Average                           26.0      6.450803     -6.450803

# %%
import numpy as np

# Create a new DataFrame for per match averages
teams_per_match_averages = pd.DataFrame(index=teams_xg_xga.index)

# Calculate per match averages for home and away xG and xGA
teams_per_match_averages['per_match_home_xg'] = teams_xg_xga['total_home_xg'] / teams_xg_xga['home_matches_played']
teams_per_match_averages['per_match_away_xg'] = teams_xg_xga['total_away_xg'] / teams_xg_xga['away_matches_played']
teams_per_match_averages['per_match_home_xga'] = teams_xg_xga['total_home_xga'] / teams_xg_xga['home_matches_played']
teams_per_match_averages['per_match_away_xga'] = teams_xg_xga['total_away_xga'] / teams_xg_xga['away_matches_played']

# Calculate overall total xG and xGA per match
teams_per_match_averages['total_xg_per_match'] = teams_xg_xga['total_xg'] / teams_xg_xga['matches_played']
teams_per_match_averages['total_xga_per_match'] = teams_xg_xga['total_xga'] / teams_xg_xga['matches_played']

# Replace any potential infinite values with NaN (in case of division by zero) and then fill with 0
teams_per_match_averages.replace([np.inf, -np.inf], np.nan, inplace=True)
teams_per_match_averages.fillna(0, inplace=True)

# Calculate the average for each column
average_stats = teams_per_match_averages.mean()

# Append the 'Average' row with these averages to the DataFrame
teams_per_match_averages.loc['Average'] = average_stats

teams_per_match_averages
# Out:
#                         per_match_home_xg  per_match_away_xg  \
# Augsburg                         1.529482            1.47051
# Bayer Leverkusen                 2.570615           2.013183
# Bayern Munich                    3.400417            2.66184
# Bochum                           1.888199           1.015952
# Borussia Dortmund                2.403174           1.863935
# Borussia M.Gladbach              1.785385           1.335336
# Darmstadt                        1.321382           0.838296
# Eintracht Frankfurt              1.800691           1.225222
# FC Cologne                       1.174404            1.12331
# FC Heidenheim                    1.365026           1.083358
# Freiburg                         1.992728           1.117282
# Hoffenheim                       1.616354            1.52746
# Mainz 05                         1.414103           1.140619
# RasenBallsport Leipzig           2.518082           1.818331
# Union Berlin                     1.550369           1.081734
# VfB Stuttgart                     2.86523           1.869712
# Werder Bremen                    1.495429           1.103478
# Wolfsburg                        1.576022           0.979017
# Average                          1.903727            1.40381
#
#                         per_match_home_xga  per_match_away_xga  \
# Augsburg                          1.491752            1.934064
# Bayer Leverkusen                  0.694066            1.215467
# Bayern Munich                     0.813915            1.170913
# Bochum                            1.442027            2.721426
# Borussia Dortmund                 1.320684            1.771073
# Borussia M.Gladbach               1.436353            2.232468
# Darmstadt                         2.104443            2.639988
# Eintracht Frankfurt               1.217226            1.970354
# FC Cologne                        2.074858            2.422277
# FC Heidenheim                     1.703344            2.210702
# Freiburg                           1.62964            1.969276
# Hoffenheim                         1.71138            2.252477
# Mainz 05                          1.033005            1.970466
# RasenBallsport Leipzig            1.108611            1.335851
# Union Berlin                      1.460568            1.755539
# VfB Stuttgart                     0.981716            1.336881
# Werder Bremen                     1.498083             1.82666
# Wolfsburg                         1.508418            1.545849
# Average                           1.401672            1.904541
#
#                         total_xg_per_match  total_xga_per_match
# Augsburg                          1.499996             1.712908
# Bayer Leverkusen                  2.291899             0.954767
# Bayern Munich                     3.031128             0.992414
# Bochum                            1.452076             2.081726
# Borussia Dortmund                 2.133555             1.545879
# Borussia M.Gladbach                1.56036             1.834411
# Darmstadt                         1.098419             2.351618
# Eintracht Frankfurt               1.490823             1.622756
# FC Cologne                        1.148857             2.248568
# FC Heidenheim                     1.224192             1.957023
# Freiburg                          1.555005             1.799458
# Hoffenheim                        1.571907             1.981929
# Mainz 05                          1.277361             1.501735
# RasenBallsport Leipzig            2.168206             1.222231
# Union Berlin                      1.316051             1.608054
# VfB Stuttgart                     2.367471             1.159299
# Werder Bremen                     1.299454             1.662371
# Wolfsburg                         1.277519             1.527133
# Average                           1.653571             1.653571

# %%
# Load the full schedule
schedule_df = understat.read_schedule()

# Convert the 'date' column to datetime format, then format it to keep only the date part
schedule_df['date'] = pd.to_datetime(schedule_df['date']).dt.date

# Display the first few rows to verify the change
print(schedule_df.head())
# Out:
#                                                                          league_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                     3
#                       2023-08-19 Augsburg-Borussia M.Gladbach                    3
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig         3
#                       2023-08-19 Borussia Dortmund-FC Cologne                    3
#                       2023-08-19 Hoffenheim-Freiburg                             3
#
#                                                                           season_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                   2023
#                       2023-08-19 Augsburg-Borussia M.Gladbach                  2023
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig       2023
#                       2023-08-19 Borussia Dortmund-FC Cologne                  2023
#                       2023-08-19 Hoffenheim-Freiburg                           2023
#
#                                                                           game_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                23065
#                       2023-08-19 Augsburg-Borussia M.Gladbach               23069
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig    23066
#                       2023-08-19 Borussia Dortmund-FC Cologne               23071
#                       2023-08-19 Hoffenheim-Freiburg                        23068
#
#                                                                                 date  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich              2023-08-18
#                       2023-08-19 Augsburg-Borussia M.Gladbach             2023-08-19
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  2023-08-19
#                       2023-08-19 Borussia Dortmund-FC Cologne             2023-08-19
#                       2023-08-19 Hoffenheim-Freiburg                      2023-08-19
#
#                                                                           home_team_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                       123
#                       2023-08-19 Augsburg-Borussia M.Gladbach                      121
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig           119
#                       2023-08-19 Borussia Dortmund-FC Cologne                      129
#                       2023-08-19 Hoffenheim-Freiburg                               120
#
#                                                                           away_team_id  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                       117
#                       2023-08-19 Augsburg-Borussia M.Gladbach                      130
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig           136
#                       2023-08-19 Borussia Dortmund-FC Cologne                      134
#                       2023-08-19 Hoffenheim-Freiburg                               135
#
#                                                                                   home_team  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                  Werder Bremen
#                       2023-08-19 Augsburg-Borussia M.Gladbach                      Augsburg
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig   Bayer Leverkusen
#                       2023-08-19 Borussia Dortmund-FC Cologne             Borussia Dortmund
#                       2023-08-19 Hoffenheim-Freiburg                             Hoffenheim
#
#                                                                                        away_team  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                       Bayern Munich
#                       2023-08-19 Augsburg-Borussia M.Gladbach                Borussia M.Gladbach
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  RasenBallsport Leipzig
#                       2023-08-19 Borussia Dortmund-FC Cologne                         FC Cologne
#                       2023-08-19 Hoffenheim-Freiburg                                    Freiburg
#
#                                                                          away_team_code  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                        BAY
#                       2023-08-19 Augsburg-Borussia M.Gladbach                       BMG
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig            RBL
#                       2023-08-19 Borussia Dortmund-FC Cologne                       COL
#                       2023-08-19 Hoffenheim-Freiburg                                FRE
#
#                                                                          home_team_code  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                        WER
#                       2023-08-19 Augsburg-Borussia M.Gladbach                       AUG
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig            LEV
#                       2023-08-19 Borussia Dortmund-FC Cologne                       DOR
#                       2023-08-19 Hoffenheim-Freiburg                                HOF
#
#                                                                           home_goals  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                       0
#                       2023-08-19 Augsburg-Borussia M.Gladbach                      4
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig           3
#                       2023-08-19 Borussia Dortmund-FC Cologne                      1
#                       2023-08-19 Hoffenheim-Freiburg                               1
#
#                                                                           away_goals  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                       4
#                       2023-08-19 Augsburg-Borussia M.Gladbach                      4
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig           2
#                       2023-08-19 Borussia Dortmund-FC Cologne                      0
#                       2023-08-19 Hoffenheim-Freiburg                               2
#
#                                                                           home_xg  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich              0.63974
#                       2023-08-19 Augsburg-Borussia M.Gladbach             2.53482
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  1.73279
#                       2023-08-19 Borussia Dortmund-FC Cologne             1.72317
#                       2023-08-19 Hoffenheim-Freiburg                      1.67186
#
#                                                                           away_xg  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich              2.89704
#                       2023-08-19 Augsburg-Borussia M.Gladbach             1.91849
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  1.60393
#                       2023-08-19 Borussia Dortmund-FC Cologne             1.51393
#                       2023-08-19 Hoffenheim-Freiburg                      3.24821
#
#                                                                           is_result  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                   True
#                       2023-08-19 Augsburg-Borussia M.Gladbach                  True
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig       True
#                       2023-08-19 Borussia Dortmund-FC Cologne                  True
#                       2023-08-19 Hoffenheim-Freiburg                           True
#
#                                                                           has_data  \
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich                  True
#                       2023-08-19 Augsburg-Borussia M.Gladbach                 True
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig      True
#                       2023-08-19 Borussia Dortmund-FC Cologne                 True
#                       2023-08-19 Hoffenheim-Freiburg                          True
#
#                                                                                                         url
# league         season game
# GER-Bundesliga 2324   2023-08-18 Werder Bremen-Bayern Munich              https://understat.com/match/23065
#                       2023-08-19 Augsburg-Borussia M.Gladbach             https://understat.com/match/23069
#                       2023-08-19 Bayer Leverkusen-RasenBallsport Leipzig  https://understat.com/match/23066
#                       2023-08-19 Borussia Dortmund-FC Cologne             https://understat.com/match/23071
#                       2023-08-19 Hoffenheim-Freiburg                      https://understat.com/match/23068

# %%
import pandas as pd

# Assuming 'schedule_df' is your DataFrame and it's already loaded

# Make sure the 'date' column is in datetime format
schedule_df['date'] = pd.to_datetime(schedule_df['date'])

# Define the start and end dates for filtering
start_date = pd.to_datetime('2024-03-29')
end_date = pd.to_datetime('2024-04-01')

# Filter the DataFrame for games within the date range, and use .copy() to avoid SettingWithCopyWarning
filtered_games = schedule_df[(schedule_df['date'] >= start_date) & (schedule_df['date'] <= end_date)].copy()

# Create a new column 'game_matchup' by concatenating 'home_team', 'vs.', and 'away_team'
filtered_games['game_matchup'] = filtered_games['home_team'] + ' vs. ' + filtered_games['away_team']

# Now, create a separate DataFrame that contains only the 'game_matchup' column
games_list_df = filtered_games[['game_matchup']].reset_index(drop=True)

# Display the new DataFrame to verify
print(games_list_df)
# Out:
#                            game_matchup
# 0       Bayer Leverkusen vs. Hoffenheim
# 1   Bayern Munich vs. Borussia Dortmund
# 2      Borussia M.Gladbach vs. Freiburg
# 3  Eintracht Frankfurt vs. Union Berlin
# 4   RasenBallsport Leipzig vs. Mainz 05
# 5           Werder Bremen vs. Wolfsburg
# 6               Augsburg vs. FC Cologne
# 7                  Bochum vs. Darmstadt
# 8       VfB Stuttgart vs. FC Heidenheim

# %%
import pandas as pd

# Assuming 'teams_per_match_averages' and 'games_list_df' are already defined

# Initialize an empty list for storing game metrics along with the matchup information
games_metrics_list = []

# Retrieve the 'Average' row for league-wide average stats
avg_stats = teams_per_match_averages.loc['Average']

# Looping through each game to calculate metrics using 'teams_per_match_averages'
for index, row in games_list_df.iterrows():
    # Extract home and away team names
    home_team, away_team = row['game_matchup'].split(' vs. ')
    
    # Retrieve team stats from 'teams_per_match_averages'
    home_team_stats = teams_per_match_averages.loc[home_team]
    away_team_stats = teams_per_match_averages.loc[away_team]
    
    # Calculate the metrics using the per match averages
    home_attack = home_team_stats['per_match_home_xg'] / avg_stats['per_match_home_xg']
    away_defence = away_team_stats['per_match_away_xga'] / avg_stats['per_match_away_xga']
    away_attack = away_team_stats['per_match_away_xg'] / avg_stats['per_match_away_xg']
    home_defence = home_team_stats['per_match_home_xga'] / avg_stats['per_match_home_xga']
    
    # Append the calculated metrics for this game to the list along with the game_matchup
    games_metrics_list.append({
        'Game Matchup': row['game_matchup'],
        'Home Attack': home_attack, 
        'Away Defence': away_defence,
        'Away Attack': away_attack, 
        'Home Defence': home_defence
    })

# Once all games are processed, create the DataFrame from the list
games_metrics_df = pd.DataFrame(games_metrics_list)

# Splitting 'Game Matchup' into 'Home Team' and 'Away Team'
games_metrics_df[['Home Team', 'Away Team']] = games_metrics_df['Game Matchup'].str.split(' vs. ', expand=True)

# Display the DataFrame with calculated metrics for each game
games_metrics_df
# Out:
#                            Game Matchup  Home Attack  Away Defence  \
# 0       Bayer Leverkusen vs. Hoffenheim     1.350307      1.182688
# 1   Bayern Munich vs. Borussia Dortmund     1.786189      0.929921
# 2      Borussia M.Gladbach vs. Freiburg     0.937836      1.033990
# 3  Eintracht Frankfurt vs. Union Berlin     0.945877      0.921765
# 4   RasenBallsport Leipzig vs. Mainz 05     1.322711      1.034615
# 5           Werder Bremen vs. Wolfsburg     0.785527      0.811665
# 6               Augsburg vs. FC Cologne     0.803415      1.271843
# 7                  Bochum vs. Darmstadt     0.991843      1.386155
# 8       VfB Stuttgart vs. FC Heidenheim     1.505063      1.160753
#
#    Away Attack  Home Defence               Home Team          Away Team
# 0     1.088082      0.495170        Bayer Leverkusen         Hoffenheim
# 1     1.327769      0.580675           Bayern Munich  Borussia Dortmund
# 2     0.795893      1.024743     Borussia M.Gladbach           Freiburg
# 3     0.770570      0.868410     Eintracht Frankfurt       Union Berlin
# 4     0.812517      0.790920  RasenBallsport Leipzig           Mainz 05
# 5     0.697400      1.068783           Werder Bremen          Wolfsburg
# 6     0.800187      1.064267                Augsburg         FC Cologne
# 7     0.597158      1.028791                  Bochum          Darmstadt
# 8     0.771727      0.700389           VfB Stuttgart      FC Heidenheim

# %%
# Merge home team averages
games_metrics_df = games_metrics_df.merge(
    teams_xg_xga_df[['Team', 'Average Home xG Last 5', 'Average Home xGA Last 5']],
    left_on='Home Team',
    right_on='Team',
    how='left'
).drop(columns=['Team'])  # Dropping the redundant 'Team' column after merge

# Merge away team averages
games_metrics_df = games_metrics_df.merge(
    teams_xg_xga_df[['Team', 'Average Away xG Last 5', 'Average Away xGA Last 5']],
    left_on='Away Team',
    right_on='Team',
    how='left',
    suffixes=('_home', '_away')
).drop(columns=['Team'])  # Dropping the redundant 'Team' column after merge

# %%
import pandas as pd

# Assuming 'teams_per_match_averages', 'games_list_df', and 'teams_xg_xga_df' are already defined

# Retrieve season-long averages
season_avg_home_xg = teams_per_match_averages['per_match_home_xg'].mean()
season_avg_away_xg = teams_per_match_averages['per_match_away_xg'].mean()
season_avg_home_xga = teams_per_match_averages['per_match_home_xga'].mean()
season_avg_away_xga = teams_per_match_averages['per_match_away_xga'].mean()

# Initialize an empty list for storing game metrics along with the matchup information
games_metrics_list = []

# Loop through each game to calculate metrics using 'teams_per_match_averages'
for index, row in games_list_df.iterrows():
    home_team, away_team = row['game_matchup'].split(' vs. ')
    
    # Retrieve team stats from 'teams_per_match_averages'
    home_team_stats = teams_per_match_averages.loc[home_team]
    away_team_stats = teams_per_match_averages.loc[away_team]
    
    # Retrieve recent form from 'teams_xg_xga_df'
    home_recent_xg = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == home_team, 'Average Home xG Last 5'].values[0]
    away_recent_xg = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == away_team, 'Average Away xG Last 5'].values[0]
    home_recent_xga = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == home_team, 'Average Home xGA Last 5'].values[0]
    away_recent_xga = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == away_team, 'Average Away xGA Last 5'].values[0]
    
    # Compare recent form to season-long averages to get adjustment factors
    home_attack_factor = home_recent_xg / home_team_stats['per_match_home_xg'] if home_team_stats['per_match_home_xg'] != 0 else 1
    away_defence_factor = away_recent_xga / away_team_stats['per_match_away_xga'] if away_team_stats['per_match_away_xga'] != 0 else 1
    away_attack_factor = away_recent_xg / away_team_stats['per_match_away_xg'] if away_team_stats['per_match_away_xg'] != 0 else 1
    home_defence_factor = home_recent_xga / home_team_stats['per_match_home_xga'] if home_team_stats['per_match_home_xga'] != 0 else 1
    
    # Adjust metrics using the factors
    home_attack_adjusted = home_team_stats['per_match_home_xg'] * home_attack_factor / season_avg_home_xg
    away_defence_adjusted = away_team_stats['per_match_away_xga'] * away_defence_factor / season_avg_away_xga
    away_attack_adjusted = away_team_stats['per_match_away_xg'] * away_attack_factor / season_avg_away_xg
    home_defence_adjusted = home_team_stats['per_match_home_xga'] * home_defence_factor / season_avg_home_xga
    
    # Append the adjusted metrics for this game to the list
    games_metrics_list.append({
        'Game Matchup': row['game_matchup'],
        'Home Attack': home_attack_adjusted,
        'Away Defence': away_defence_adjusted,
        'Away Attack': away_attack_adjusted,
        'Home Defence': home_defence_adjusted
    })

# Create the DataFrame from the list
games_metrics_df = pd.DataFrame(games_metrics_list)

# Split 'Game Matchup' into 'Home Team' and 'Away Team'
games_metrics_df[['Home Team', 'Away Team']] = games_metrics_df['Game Matchup'].str.split(' vs. ', expand=True)

games_metrics_df
# Out:
#                            Game Matchup  Home Attack  Away Defence  \
# 0       Bayer Leverkusen vs. Hoffenheim     1.203324      1.480208
# 1   Bayern Munich vs. Borussia Dortmund     1.566904      0.721324
# 2      Borussia M.Gladbach vs. Freiburg     1.215717      1.154831
# 3  Eintracht Frankfurt vs. Union Berlin     1.070198      0.825853
# 4   RasenBallsport Leipzig vs. Mainz 05     1.236673      1.354163
# 5           Werder Bremen vs. Wolfsburg     0.879858      0.605889
# 6               Augsburg vs. FC Cologne     0.761181      0.961607
# 7                  Bochum vs. Darmstadt     0.610597      1.436755
# 8       VfB Stuttgart vs. FC Heidenheim     1.170113      0.782840
#
#    Away Attack  Home Defence               Home Team          Away Team
# 0     1.043846      0.305400        Bayer Leverkusen         Hoffenheim
# 1     1.193602      0.476343           Bayern Munich  Borussia Dortmund
# 2     0.857695      0.961512     Borussia M.Gladbach           Freiburg
# 3     0.808757      0.645210     Eintracht Frankfurt       Union Berlin
# 4     0.717849      0.748766  RasenBallsport Leipzig           Mainz 05
# 5     0.606626      1.088685           Werder Bremen          Wolfsburg
# 6     0.541047      1.152284                Augsburg         FC Cologne
# 7     0.577884      1.399624                  Bochum          Darmstadt
# 8     0.876083      0.658042           VfB Stuttgart      FC Heidenheim

# %%
# Initialize an empty list for storing projected goals data
projected_goals_list = []

# Retrieve the league-wide average per match home and away xG
league_avg_per_match_home_xg = teams_per_match_averages.loc['Average', 'per_match_home_xg']
league_avg_per_match_away_xg = teams_per_match_averages.loc['Average', 'per_match_away_xg']

# Iterate over each row in the games_metrics_df to calculate projected goals
for index, row in games_metrics_df.iterrows():
    # Extract home and away team names from the game matchup
    home_team, away_team = row['Game Matchup'].split(' vs. ')

    # Calculate metrics using the teams' attack and defence strengths
    home_attack = row['Home Attack']
    away_defence = row['Away Defence']
    away_attack = row['Away Attack']
    home_defence = row['Home Defence']

    # Calculate projected home and away goals using the league-wide average per game xG
    projected_home_goals = home_attack * away_defence * league_avg_per_match_home_xg
    projected_away_goals = away_attack * home_defence * league_avg_per_match_away_xg

    # Calculate total projected goals
    total_projected_goals = projected_home_goals + projected_away_goals

    # Append the results to the list
    projected_goals_list.append({
        'Game Matchup': row['Game Matchup'],
        'Projected Home Goals': projected_home_goals,
        'Projected Away Goals': projected_away_goals,
        'Total Projected Goals': total_projected_goals
    })

# Convert the list to a DataFrame
projected_goals_df = pd.DataFrame(projected_goals_list)

# Display the DataFrame
projected_goals_df
# Out:
#                            Game Matchup  Projected Home Goals  \
# 0       Bayer Leverkusen vs. Hoffenheim              3.390860
# 1   Bayern Munich vs. Borussia Dortmund              2.151679
# 2      Borussia M.Gladbach vs. Freiburg              2.672733
# 3  Eintracht Frankfurt vs. Union Berlin              1.682564
# 4   RasenBallsport Leipzig vs. Mainz 05              3.188089
# 5           Werder Bremen vs. Wolfsburg              1.014870
# 6               Augsburg vs. FC Cologne              1.393446
# 7                  Bochum vs. Darmstadt              1.670097
# 8       VfB Stuttgart vs. FC Heidenheim              1.743836
#
#    Projected Away Goals  Total Projected Goals
# 0              0.447521               3.838382
# 1              0.798156               2.949835
# 2              1.157699               3.830433
# 3              0.732533               2.415098
# 4              0.754549               3.942638
# 5              0.927110               1.941980
# 6              0.875191               2.268637
# 7              1.135430               2.805527
# 8              0.809295               2.553131

# %%
import numpy as np

# Number of simulations to run for each game
n_simulations = 10000

# Initialize lists to store the win/draw probabilities
home_win_probs = []
away_win_probs = []
draw_probs = []

for index, row in projected_goals_df.iterrows():
    home_goals_proj = row['Projected Home Goals']
    away_goals_proj = row['Projected Away Goals']

    # Simulate match outcomes
    home_goals_sim = np.random.poisson(home_goals_proj, n_simulations)
    away_goals_sim = np.random.poisson(away_goals_proj, n_simulations)

    # Calculate outcomes
    home_wins = np.sum(home_goals_sim > away_goals_sim)
    away_wins = np.sum(away_goals_sim > home_goals_sim)
    draws = np.sum(home_goals_sim == away_goals_sim)

    # Calculate probabilities
    home_win_prob = home_wins / n_simulations
    away_win_prob = away_wins / n_simulations
    draw_prob = draws / n_simulations

    # Append probabilities to lists
    home_win_probs.append(home_win_prob)
    away_win_probs.append(away_win_prob)
    draw_probs.append(draw_prob)

# Add the calculated probabilities to the projected_goals_df DataFrame
projected_goals_df['Home Win Probability'] = home_win_probs
projected_goals_df['Away Win Probability'] = away_win_probs
projected_goals_df['Draw Probability'] = draw_probs

# Convert probabilities to percentage format and append '%' sign
projected_goals_df['Home Win Probability'] = (projected_goals_df['Home Win Probability'] * 100).apply(lambda x: f'{x:.2f}%')
projected_goals_df['Away Win Probability'] = (projected_goals_df['Away Win Probability'] * 100).apply(lambda x: f'{x:.2f}%')
projected_goals_df['Draw Probability'] = (projected_goals_df['Draw Probability'] * 100).apply(lambda x: f'{x:.2f}%')

# Display the updated DataFrame with formatted probabilities
projected_goals_df
# Out:
#                            Game Matchup  Projected Home Goals  \
# 0       Bayer Leverkusen vs. Hoffenheim              3.390860
# 1   Bayern Munich vs. Borussia Dortmund              2.151679
# 2      Borussia M.Gladbach vs. Freiburg              2.672733
# 3  Eintracht Frankfurt vs. Union Berlin              1.682564
# 4   RasenBallsport Leipzig vs. Mainz 05              3.188089
# 5           Werder Bremen vs. Wolfsburg              1.014870
# 6               Augsburg vs. FC Cologne              1.393446
# 7                  Bochum vs. Darmstadt              1.670097
# 8       VfB Stuttgart vs. FC Heidenheim              1.743836
#
#    Projected Away Goals  Total Projected Goals Home Win Probability  \
# 0              0.447521               3.838382               90.90%
# 1              0.798156               2.949835               68.49%
# 2              1.157699               3.830433               69.56%
# 3              0.732533               2.415098               60.47%
# 4              0.754549               3.942638               84.05%
# 5              0.927110               1.941980               36.48%
# 6              0.875191               2.268637               48.72%
# 7              1.135430               2.805527               49.94%
# 8              0.809295               2.553131               58.93%
#
#   Away Win Probability Draw Probability
# 0                2.27%            6.83%
# 1               13.01%           18.50%
# 2               13.89%           16.55%
# 3               15.86%           23.67%
# 4                5.56%           10.39%
# 5               32.28%           31.24%
# 6               24.17%           27.11%
# 7               26.06%           24.00%
# 8               17.60%           23.47%

# %%
import requests


# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
API_KEY = '6ea2753ab77393e63fe86bb67324fc40'

SPORT = 'soccer' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h,spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# %%
import requests

# Your API key for the odds API
api_key = '6ea2753ab77393e63fe86bb67324fc40'

# Define the endpoint URL
url = 'https://api.the-odds-api.com/v4/sports/soccer_germany_bundesliga/odds/'

# Parameters for the API request
params = {
    'apiKey': api_key,
    'regions': 'us',  # Adjust if targeting a different region
    'markets': 'h2h',  # Head-to-head odds; adjust if looking for different market types
    'bookmakers': 'bovada',
    'oddsFormat': 'decimal'
}

# Make the GET request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Convert the response to JSON
    odds_data = response.json()
    # Process your data here
    print(odds_data)
else:
    print(f"Error fetching data: {response.status_code}")
# Out:
# [{'id': '362de314a53301a77ef649ed554ed3d0', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-03-30T14:30:00Z', 'home_team': 'Bayer Leverkusen', 'away_team': 'TSG Hoffenheim', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:11:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:11:18Z', 'outcomes': [{'name': 'Bayer Leverkusen', 'price': 1.23}, {'name': 'TSG Hoffenheim', 'price': 10.0}, {'name': 'Draw', 'price': 7.0}]}]}]}, {'id': 'b19530adc0d39fbc70d237f674e65a74', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-03-30T14:30:00Z', 'home_team': 'Borussia Monchengladbach', 'away_team': 'SC Freiburg', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:11:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:11:18Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 2.25}, {'name': 'SC Freiburg', 'price': 2.95}, {'name': 'Draw', 'price': 3.7}]}]}]}, {'id': '3cd6170c7a9229537d881a67b76abc92', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-03-30T14:30:00Z', 'home_team': 'Eintracht Frankfurt', 'away_team': 'Union Berlin', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:11:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:11:18Z', 'outcomes': [{'name': 'Eintracht Frankfurt', 'price': 2.05}, {'name': 'Union Berlin', 'price': 3.75}, {'name': 'Draw', 'price': 3.45}]}]}]}, {'id': '0fa036b4b3bd50f8008f46cad56b49e7', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-03-30T14:30:00Z', 'home_team': 'RB Leipzig', 'away_team': 'FSV Mainz 05', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:11:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:11:18Z', 'outcomes': [{'name': 'FSV Mainz 05', 'price': 7.0}, {'name': 'RB Leipzig', 'price': 1.38}, {'name': 'Draw', 'price': 5.2}]}]}]}, {'id': '9cb85a10f16bea70d5bbd41768297be2', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-03-30T14:30:00Z', 'home_team': 'Werder Bremen', 'away_team': 'VfL Wolfsburg', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:11:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:11:18Z', 'outcomes': [{'name': 'VfL Wolfsburg', 'price': 2.55}, {'name': 'Werder Bremen', 'price': 2.65}, {'name': 'Draw', 'price': 3.6}]}]}]}, {'id': '8ec2948899992014a6faa2815a38799f', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-03-30T17:30:00Z', 'home_team': 'Bayern Munich', 'away_team': 'Borussia Dortmund', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:11:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:11:18Z', 'outcomes': [{'name': 'Bayern Munich', 'price': 1.43}, {'name': 'Borussia Dortmund', 'price': 5.6}, {'name': 'Draw', 'price': 5.6}]}]}]}, {'id': '0158d5d1645e7bf43e5c034ffb97aca4', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-03-31T13:30:00Z', 'home_team': 'Augsburg', 'away_team': 'FC Koln', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:11:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:11:18Z', 'outcomes': [{'name': 'Augsburg', 'price': 1.74}, {'name': 'FC Koln', 'price': 4.5}, {'name': 'Draw', 'price': 4.0}]}]}]}, {'id': '6202c2fc8249d5972975d9a11a3b17a9', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-03-31T15:30:00Z', 'home_team': 'VfB Stuttgart', 'away_team': 'FC Heidenheim', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:11:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-2 ...

# %%
# Initialize an empty list to hold the simplified odds data
simplified_odds_list = []

# Iterate over the odds data
for event in odds_data:
    # Extract the essential information
    event_name = event.get('sport_title', 'No sport title')
    home_team = event.get('home_team', 'No home team')
    away_team = event.get('away_team', 'No away team')
    start_time = event.get('commence_time', 'No start time')
    
    # Initialize default odds
    home_team_odds = 'N/A'
    away_team_odds = 'N/A'
    draw_odds = 'N/A'  # Initialize draw odds

    # If there are bookmakers data available
    if event.get('bookmakers'):
        # Look for the Bovada bookmaker in the list
        for bookmaker in event['bookmakers']:
            if bookmaker['key'].lower() == 'bovada':  # Ensure case-insensitive matching
                # Assuming 'markets' is a list and we're interested in the first item (h2h)
                markets = bookmaker.get('markets', [])
                if markets:
                    # Assuming the structure of 'outcomes' in the first market
                    outcomes = markets[0].get('outcomes', [])
                    for outcome in outcomes:
                        # Assign odds based on the team or if it's a draw
                        if outcome['name'] == home_team:
                            home_team_odds = outcome.get('price', 'N/A')
                        elif outcome['name'] == away_team:
                            away_team_odds = outcome.get('price', 'N/A')
                        elif outcome['name'].lower() == 'draw':  # Checking for a draw
                            draw_odds = outcome.get('price', 'N/A')
                
                # Once we've found Bovada and extracted the odds, no need to check other bookmakers
                break

    # Create a simplified representation of the event including draw odds
    simplified_event = f"{event_name}: {home_team} vs. {away_team}, Date: {start_time}, Home Odds: {home_team_odds}, Away Odds: {away_team_odds}, Draw Odds: {draw_odds}"
    
    # Add to the list
    simplified_odds_list.append(simplified_event)

# Now, 'simplified_odds_list' contains a more readable version of the odds data, including draw odds
for item in simplified_odds_list:
    print(item)
# Out:
# Bundesliga - Germany: Bayer Leverkusen vs. TSG Hoffenheim, Date: 2024-03-30T14:30:00Z, Home Odds: 1.23, Away Odds: 10.0, Draw Odds: 7.0
# Bundesliga - Germany: Borussia Monchengladbach vs. SC Freiburg, Date: 2024-03-30T14:30:00Z, Home Odds: 2.25, Away Odds: 2.95, Draw Odds: 3.7
# Bundesliga - Germany: Eintracht Frankfurt vs. Union Berlin, Date: 2024-03-30T14:30:00Z, Home Odds: 2.05, Away Odds: 3.75, Draw Odds: 3.45
# Bundesliga - Germany: RB Leipzig vs. FSV Mainz 05, Date: 2024-03-30T14:30:00Z, Home Odds: 1.38, Away Odds: 7.0, Draw Odds: 5.2
# Bundesliga - Germany: Werder Bremen vs. VfL Wolfsburg, Date: 2024-03-30T14:30:00Z, Home Odds: 2.65, Away Odds: 2.55, Draw Odds: 3.6
# Bundesliga - Germany: Bayern Munich vs. Borussia Dortmund, Date: 2024-03-30T17:30:00Z, Home Odds: 1.43, Away Odds: 5.6, Draw Odds: 5.6
# Bundesliga - Germany: Augsburg vs. FC Koln, Date: 2024-03-31T13:30:00Z, Home Odds: 1.74, Away Odds: 4.5, Draw Odds: 4.0
# Bundesliga - Germany: VfB Stuttgart vs. FC Heidenheim, Date: 2024-03-31T15:30:00Z, Home Odds: 1.29, Away Odds: 8.75, Draw Odds: 6.0
# Bundesliga - Germany: VfL Bochum vs. SV Darmstadt 98, Date: 2024-03-31T17:30:00Z, Home Odds: 1.69, Away Odds: 4.7, Draw Odds: 4.1
# Bundesliga - Germany: Eintracht Frankfurt vs. Werder Bremen, Date: 2024-04-05T18:30:00Z, Home Odds: 1.91, Away Odds: 3.85, Draw Odds: 3.75
# Bundesliga - Germany: Union Berlin vs. Bayer Leverkusen, Date: 2024-04-06T13:30:00Z, Home Odds: 5.75, Away Odds: 1.54, Draw Odds: 4.3
# Bundesliga - Germany: FC Heidenheim vs. Bayern Munich, Date: 2024-04-06T13:30:00Z, Home Odds: 7.5, Away Odds: 1.32, Draw Odds: 6.0
# Bundesliga - Germany: FC Koln vs. VfL Bochum, Date: 2024-04-06T13:30:00Z, Home Odds: 2.3, Away Odds: 2.95, Draw Odds: 3.6
# Bundesliga - Germany: FSV Mainz 05 vs. SV Darmstadt 98, Date: 2024-04-06T13:30:00Z, Home Odds: 1.54, Away Odds: 5.75, Draw Odds: 4.4
# Bundesliga - Germany: SC Freiburg vs. RB Leipzig, Date: 2024-04-06T13:30:00Z, Home Odds: 4.4, Away Odds: 1.69, Draw Odds: 4.4
# Bundesliga - Germany: Borussia Dortmund vs. VfB Stuttgart, Date: 2024-04-06T16:30:00Z, Home Odds: 2.35, Away Odds: 2.7, Draw Odds: 3.9
# Bundesliga - Germany: TSG Hoffenheim vs. Augsburg, Date: 2024-04-07T13:30:00Z, Home Odds: 2.2, Away Odds: 2.95, Draw Odds: 3.9
# Bundesliga - Germany: VfL Wolfsburg vs. Borussia Monchengladbach, Date: 2024-04-07T15:30:00Z, Home Odds: 2.05, Away Odds: 3.4, Draw Odds: 3.8

# %%
odds_data_list = []

for event in odds_data:
    home_team = event.get('home_team')
    away_team = event.get('away_team')
    start_time = event.get('commence_time')  # Assuming datetime format or additional parsing might be needed
    
    # Initialize odds
    home_odds = 'N/A'
    away_odds = 'N/A'
    draw_odds = 'N/A'  # Initialize draw odds variable

    # Iterate through bookmakers to find Bovada and extract the odds
    for bookmaker in event.get('bookmakers', []):
        if bookmaker['key'].lower() == 'bovada':  # Ensure case-insensitive matching
            markets = bookmaker.get('markets', [])
            if markets:
                outcomes = markets[0].get('outcomes', [])
                for outcome in outcomes:
                    # Check and assign odds based on the team or if it's a draw
                    if outcome['name'] == home_team:
                        home_odds = outcome.get('price', 'N/A')
                    elif outcome['name'] == away_team:
                        away_odds = outcome.get('price', 'N/A')
                    elif outcome['name'].lower() == 'draw':  # Check for draw odds
                        draw_odds = outcome.get('price', 'N/A')

    # Append the data including draw odds to the list
    odds_data_list.append({
        'Game Matchup': f"{home_team} vs. {away_team}",
        'Home Odds': home_odds,
        'Away Odds': away_odds,
        'Draw Odds': draw_odds,  # Include draw odds
        'Start Time': start_time
    })

# Convert the list to a DataFrame
odds_df = pd.DataFrame(odds_data_list)

# %%
name_replacements = {
    'TSG Hoffenheim': 'Hoffenheim',
    'Borussia Monchengladbach': 'Borussia M.Gladbach',
    'SC Freiburg': 'Freiburg',
    'RB Leipzig': 'RasenBallsport Leipzig',
    'FSV Mainz 05': 'Mainz 05',
    'VfL Wolfsburg': 'Wolfsburg',
    'FC Koln': 'FC Cologne',
    'VfL Bochum': 'Bochum',
    'SV Darmstadt 98': 'Darmstadt'
    # Add any other specific replacements you need here
}
import pandas as pd

# Assuming odds_df is already defined

# Apply replacements in the 'Game Matchup' column
for original_name, new_name in name_replacements.items():
    odds_df['Game Matchup'] = odds_df['Game Matchup'].str.replace(original_name, new_name, regex=False)

# Display the updated DataFrame
print(odds_df)
# Out:
#                              Game Matchup  Home Odds  Away Odds  Draw Odds  \
# 0         Bayer Leverkusen vs. Hoffenheim       1.23      10.00       7.00
# 1        Borussia M.Gladbach vs. Freiburg       2.25       2.95       3.70
# 2    Eintracht Frankfurt vs. Union Berlin       2.05       3.75       3.45
# 3     RasenBallsport Leipzig vs. Mainz 05       1.38       7.00       5.20
# 4             Werder Bremen vs. Wolfsburg       2.65       2.55       3.60
# 5     Bayern Munich vs. Borussia Dortmund       1.43       5.60       5.60
# 6                 Augsburg vs. FC Cologne       1.74       4.50       4.00
# 7         VfB Stuttgart vs. FC Heidenheim       1.29       8.75       6.00
# 8                    Bochum vs. Darmstadt       1.69       4.70       4.10
# 9   Eintracht Frankfurt vs. Werder Bremen       1.91       3.85       3.75
# 10      Union Berlin vs. Bayer Leverkusen       5.75       1.54       4.30
# 11        FC Heidenheim vs. Bayern Munich       7.50       1.32       6.00
# 12                  FC Cologne vs. Bochum       2.30       2.95       3.60
# 13                 Mainz 05 vs. Darmstadt       1.54       5.75       4.40
# 14    Freiburg vs. RasenBallsport Leipzig       4.40       1.69       4.40
# 15    Borussia Dortmund vs. VfB Stuttgart       2.35       2.70       3.90
# 16                Hoffenheim vs. Augsburg       2.20       2.95       3.90
# 17      Wolfsburg vs. Borussia M.Gladbach       2.05       3.40       3.80
#
#               Start Time
# 0   2024-03-30T14:30:00Z
# 1   2024-03-30T14:30:00Z
# 2   2024-03-30T14:30:00Z
# 3   2024-03-30T14:30:00Z
# 4   2024-03-30T14:30:00Z
# 5   2024-03-30T17:30:00Z
# 6   2024-03-31T13:30:00Z
# 7   2024-03-31T15:30:00Z
# 8   2024-03-31T17:30:00Z
# 9   2024-04-05T18:30:00Z
# 10  2024-04-06T13:30:00Z
# 11  2024-04-06T13:30:00Z
# 12  2024-04-06T13:30:00Z
# 13  2024-04-06T13:30:00Z
# 14  2024-04-06T13:30:00Z
# 15  2024-04-06T16:30:00Z
# 16  2024-04-07T13:30:00Z
# 17  2024-04-07T15:30:00Z

# %%
# Assuming 'projected_goals_df' exists and has a 'Game Matchup' column
merged_df = pd.merge(projected_goals_df, odds_df, on='Game Matchup', how='left')

# Now 'merged_df' contains both the projected probabilities and the odds

# %%
merged_df
# Out:
#                            Game Matchup  Projected Home Goals  \
# 0       Bayer Leverkusen vs. Hoffenheim              3.390860
# 1   Bayern Munich vs. Borussia Dortmund              2.151679
# 2      Borussia M.Gladbach vs. Freiburg              2.672733
# 3  Eintracht Frankfurt vs. Union Berlin              1.682564
# 4   RasenBallsport Leipzig vs. Mainz 05              3.188089
# 5           Werder Bremen vs. Wolfsburg              1.014870
# 6               Augsburg vs. FC Cologne              1.393446
# 7                  Bochum vs. Darmstadt              1.670097
# 8       VfB Stuttgart vs. FC Heidenheim              1.743836
#
#    Projected Away Goals  Total Projected Goals Home Win Probability  \
# 0              0.447521               3.838382               90.90%
# 1              0.798156               2.949835               68.49%
# 2              1.157699               3.830433               69.56%
# 3              0.732533               2.415098               60.47%
# 4              0.754549               3.942638               84.05%
# 5              0.927110               1.941980               36.48%
# 6              0.875191               2.268637               48.72%
# 7              1.135430               2.805527               49.94%
# 8              0.809295               2.553131               58.93%
#
#   Away Win Probability Draw Probability  Home Odds  Away Odds  Draw Odds  \
# 0                2.27%            6.83%       1.23      10.00       7.00
# 1               13.01%           18.50%       1.43       5.60       5.60
# 2               13.89%           16.55%       2.25       2.95       3.70
# 3               15.86%           23.67%       2.05       3.75       3.45
# 4                5.56%           10.39%       1.38       7.00       5.20
# 5               32.28%           31.24%       2.65       2.55       3.60
# 6               24.17%           27.11%       1.74       4.50       4.00
# 7               26.06%           24.00%       1.69       4.70       4.10
# 8               17.60%           23.47%       1.29       8.75       6.00
#
#              Start Time
# 0  2024-03-30T14:30:00Z
# 1  2024-03-30T17:30:00Z
# 2  2024-03-30T14:30:00Z
# 3  2024-03-30T14:30:00Z
# 4  2024-03-30T14:30:00Z
# 5  2024-03-30T14:30:00Z
# 6  2024-03-31T13:30:00Z
# 7  2024-03-31T17:30:00Z
# 8  2024-03-31T15:30:00Z

# %%
# Convert percentage strings to decimal probabilities
merged_df['Home Win Probability'] = merged_df['Home Win Probability'].str.rstrip('%').astype(float) / 100
merged_df['Away Win Probability'] = merged_df['Away Win Probability'].str.rstrip('%').astype(float) / 100
merged_df['Draw Probability'] = merged_df['Draw Probability'].str.rstrip('%').astype(float) / 100
# Calculate implied odds
merged_df['Implied Home Odds'] = 1 / merged_df['Home Win Probability']
merged_df['Implied Away Odds'] = 1 / merged_df['Away Win Probability']
merged_df['Implied Draw Odds'] = 1 / merged_df['Draw Probability']
# Create a new DataFrame with implied odds
implied_odds_df = merged_df[['Game Matchup', 'Implied Home Odds', 'Implied Away Odds', 'Implied Draw Odds', 'Home Odds', 'Away Odds', 'Draw Odds']].copy()

# %%
# Calculate edge for home win
implied_odds_df['Home Win Edge'] = round((1 / implied_odds_df['Implied Home Odds']) * implied_odds_df['Home Odds'] - 1, 2)

# Calculate edge for away win
implied_odds_df['Away Win Edge'] = round((1 / implied_odds_df['Implied Away Odds']) * implied_odds_df['Away Odds'] - 1, 2)

# Calculate edge for draw
implied_odds_df['Draw Edge'] = round((1 / implied_odds_df['Implied Draw Odds']) * implied_odds_df['Draw Odds'] - 1, 2)

# Round implied odds to 2 decimal points
implied_odds_df['Implied Home Odds'] = round(implied_odds_df['Implied Home Odds'], 2)
implied_odds_df['Implied Away Odds'] = round(implied_odds_df['Implied Away Odds'], 2)
implied_odds_df['Implied Draw Odds'] = round(implied_odds_df['Implied Draw Odds'], 2)

implied_odds_df
# Out:
#                            Game Matchup  Implied Home Odds  Implied Away Odds  \
# 0       Bayer Leverkusen vs. Hoffenheim               1.10              44.05
# 1   Bayern Munich vs. Borussia Dortmund               1.46               7.69
# 2      Borussia M.Gladbach vs. Freiburg               1.44               7.20
# 3  Eintracht Frankfurt vs. Union Berlin               1.65               6.31
# 4   RasenBallsport Leipzig vs. Mainz 05               1.19              17.99
# 5           Werder Bremen vs. Wolfsburg               2.74               3.10
# 6               Augsburg vs. FC Cologne               2.05               4.14
# 7                  Bochum vs. Darmstadt               2.00               3.84
# 8       VfB Stuttgart vs. FC Heidenheim               1.70               5.68
#
#    Implied Draw Odds  Home Odds  Away Odds  Draw Odds  Home Win Edge  \
# 0              14.64       1.23      10.00       7.00           0.12
# 1               5.41       1.43       5.60       5.60          -0.02
# 2               6.04       2.25       2.95       3.70           0.57
# 3               4.22       2.05       3.75       3.45           0.24
# 4               9.62       1.38       7.00       5.20           0.16
# 5               3.20       2.65       2.55       3.60          -0.03
# 6               3.69       1.74       4.50       4.00          -0.15
# 7               4.17       1.69       4.70       4.10          -0.16
# 8               4.26       1.29       8.75       6.00          -0.24
#
#    Away Win Edge  Draw Edge
# 0          -0.77      -0.52
# 1          -0.27       0.04
# 2          -0.59      -0.39
# 3          -0.41      -0.18
# 4          -0.61      -0.46
# 5          -0.18       0.12
# 6           0.09       0.08
# 7           0.22      -0.02
# 8           0.54       0.41

# %%
# Assuming 'projected_goals_df' is the DataFrame containing projected goals

# Merge the implied odds DataFrame with the projected goals DataFrame on the 'Game Matchup' column
implied_odds_with_goals = implied_odds_df.merge(projected_goals_df, on='Game Matchup', how='left')

# Display the DataFrame with projected goals added
implied_odds_with_goals
# Out:
#                            Game Matchup  Implied Home Odds  Implied Away Odds  \
# 0       Bayer Leverkusen vs. Hoffenheim               1.10              44.05
# 1   Bayern Munich vs. Borussia Dortmund               1.46               7.69
# 2      Borussia M.Gladbach vs. Freiburg               1.44               7.20
# 3  Eintracht Frankfurt vs. Union Berlin               1.65               6.31
# 4   RasenBallsport Leipzig vs. Mainz 05               1.19              17.99
# 5           Werder Bremen vs. Wolfsburg               2.74               3.10
# 6               Augsburg vs. FC Cologne               2.05               4.14
# 7                  Bochum vs. Darmstadt               2.00               3.84
# 8       VfB Stuttgart vs. FC Heidenheim               1.70               5.68
#
#    Implied Draw Odds  Home Odds  Away Odds  Draw Odds  Home Win Edge  \
# 0              14.64       1.23      10.00       7.00           0.12
# 1               5.41       1.43       5.60       5.60          -0.02
# 2               6.04       2.25       2.95       3.70           0.57
# 3               4.22       2.05       3.75       3.45           0.24
# 4               9.62       1.38       7.00       5.20           0.16
# 5               3.20       2.65       2.55       3.60          -0.03
# 6               3.69       1.74       4.50       4.00          -0.15
# 7               4.17       1.69       4.70       4.10          -0.16
# 8               4.26       1.29       8.75       6.00          -0.24
#
#    Away Win Edge  Draw Edge  Projected Home Goals  Projected Away Goals  \
# 0          -0.77      -0.52              3.390860              0.447521
# 1          -0.27       0.04              2.151679              0.798156
# 2          -0.59      -0.39              2.672733              1.157699
# 3          -0.41      -0.18              1.682564              0.732533
# 4          -0.61      -0.46              3.188089              0.754549
# 5          -0.18       0.12              1.014870              0.927110
# 6           0.09       0.08              1.393446              0.875191
# 7           0.22      -0.02              1.670097              1.135430
# 8           0.54       0.41              1.743836              0.809295
#
#    Total Projected Goals Home Win Probability Away Win Probability  \
# 0               3.838382               90.90%                2.27%
# 1               2.949835               68.49%               13.01%
# 2               3.830433               69.56%               13.89%
# 3               2.415098               60.47%               15.86%
# 4               3.942638               84.05%                5.56%
# 5               1.941980               36.48%               32.28%
# 6               2.268637               48.72%               24.17%
# 7               2.805527               49.94%               26.06%
# 8               2.553131               58.93%               17.60%
#
#   Draw Probability
# 0            6.83%
# 1           18.50%
# 2           16.55%
# 3           23.67%
# 4           10.39%
# 5           31.24%
# 6           27.11%
# 7           24.00%
# 8           23.47%

# %%
# Save the DataFrame to a CSV file
implied_odds_with_goals.to_csv('Bundes_odds_3-29.csv', index=False)

# %%
# Define a function to color code values based on conditions
def color_edges(val):
    if val < 0:
        return 'background-color: maroon'
    elif 0.0 <= val < 0.1:
        return 'background-color: yellow'
    else:
        return 'background-color: green'

# Apply the styling to the specified columns
styled_df = implied_odds_with_goals.style.applymap(color_edges, subset=['Home Win Edge', 'Away Win Edge', 'Draw Edge'])

# Display the styled DataFrame
styled_df
# Out:
# C:\Users\jbuck\AppData\Local\Temp\ipykernel_24104\2992074314.py:11: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = implied_odds_with_goals.style.applymap(color_edges, subset=['Home Win Edge', 'Away Win Edge', 'Draw Edge'])
# <style type="text/css">
# #T_7c412_row0_col7, #T_7c412_row2_col7, #T_7c412_row3_col7, #T_7c412_row4_col7, #T_7c412_row5_col9, #T_7c412_row7_col8, #T_7c412_row8_col8, #T_7c412_row8_col9 {
#   background-color: green;
# }
# #T_7c412_row0_col8, #T_7c412_row0_col9, #T_7c412_row1_col7, #T_7c412_row1_col8, #T_7c412_row2_col8, #T_7c412_row2_col9, #T_7c412_row3_col8, #T_7c412_row3_col9, #T_7c412_row4_col8, #T_7c412_row4_col9, #T_7c412_row5_col7, #T_7c412_row5_col8, #T_7c412_row6_col7, #T_7c412_row7_col7, #T_7c412_row7_col9, #T_7c412_row8_col7 {
#   background-color: maroon;
# }
# #T_7c412_row1_col9, #T_7c412_row6_col8, #T_7c412_row6_col9 {
#   background-color: yellow;
# }
# </style>
# <table id="T_7c412">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c412_level0_col0" class="col_heading level0 col0" >Game Matchup</th>
#       <th id="T_7c412_level0_col1" class="col_heading level0 col1" >Implied Home Odds</th>
#       <th id="T_7c412_level0_col2" class="col_heading level0 col2" >Implied Away Odds</th>
#       <th id="T_7c412_level0_col3" class="col_heading level0 col3" >Implied Draw Odds</th>
#       <th id="T_7c412_level0_col4" class="col_heading level0 col4" >Home Odds</th>
#       <th id="T_7c412_level0_col5" class="col_heading level0 col5" >Away Odds</th>
#       <th id="T_7c412_level0_col6" class="col_heading level0 col6" >Draw Odds</th>
#       <th id="T_7c412_level0_col7" class="col_heading level0 col7" >Home Win Edge</th>
#       <th id="T_7c412_level0_col8" class="col_heading level0 col8" >Away Win Edge</th>
#       <th id="T_7c412_level0_col9" class="col_heading level0 col9" >Draw Edge</th>
#       <th id="T_7c412_level0_col10" class="col_heading level0 col10" >Projected Home Goals</th>
#       <th id="T_7c412_level0_col11" class="col_heading level0 col11" >Projected Away Goals</th>
#       <th id="T_7c412_level0_col12" class="col_heading level0 col12" >Total Projected Goals</th>
#       <th id="T_7c412_level0_col13" class="col_heading level0 col13" >Home Win Probability</th>
#       <th id="T_7c412_level0_col14" class="col_heading level0 col14" >Away Win Probability</th>
#       <th id="T_7c412_level0_col15" class="col_heading level0 col15" >Draw Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c412_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c412_row0_col0" class="data row0 col0" >Bayer Leverkusen vs. Hoffenheim</td>
#       <td id="T_7c412_row0_col1" class="data row0 col1" >1.100000</td>
#       <td id="T_7c412_row0_col2" class="data row0 col2" >44.050000</td>
#       <td id="T_7c412_row0_col3" class="data row0 col3" >14.640000</td>
#       <td id="T_7c412_row0_col4" class="data row0 col4" >1.230000</td>
#       <td id="T_7c412_row0_col5" class="data row0 col5" >10.000000</td>
#       <td id="T_7c412_row0_col6" class="data row0 col6" >7.000000</td>
#       <td id="T_7c412_row0_col7" class="data row0 col7" >0.120000</td>
#       <td id="T_7c412_row0_col8" class="data row0 col8" >-0.770000</td>
#       <td id="T_7c412_row0_col9" class="data row0 col9" >-0.520000</td>
#       <td id="T_7c412_row0_col10" class="data row0 col10" >3.390860</td>
#       <td id="T_7c412_row0_col11" class="data row0 col11" >0.447521</td>
#       <td id="T_7c412_row0_col12" class="data row0 col12" >3.838382</td>
#       <td id="T_7c412_row0_col13" class="data row0 col13" >90.90%</td>
#       <td id="T_7c412_row0_col14" class="data row0 col14" >2.27%</td>
#       <td id="T_7c412_row0_col15" class="data row0 col15" >6.83%</td>
#     </tr>
#     <tr>
#       <th id="T_7c412_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c412_row1_col0" class="data row1 col0" >Bayern Munich vs. Borussia Dortmund</td>
#       <td id="T_7c412_row1_col1" class="data row1 col1" >1.460000</td>
#       <td id="T_7c412_row1_col2" class="data row1 col2" >7.690000</td>
#       <td id="T_7c412_row1_col3" class="data row1 col3" >5.410000</td>
#       <td id="T_7c412_row1_col4" class="data row1 col4" >1.430000</td>
#       <td id="T_7c412_row1_col5" class="data row1 col5" >5.600000</td>
#       <td id="T_7c412_row1_col6" class="data row1 col6" >5.600000</td>
#       <td id="T_7c412_row1_col7" class="data row1 col7" >-0.020000</td>
#       <td id="T_7c412_row1_col8" class="data row1 col8" >-0.270000</td>
#       <td id="T_7c412_row1_col9" class="data row1 col9" >0.040000</td>
#       <td id="T_7c412_row1_col10" class="data row1 col10" >2.151679</td>
#       <td id="T_7c412_row1_col11" class="data row1 col11" >0.798156</td>
#       <td id="T_7c412_row1_col12" class="data row1 col12" >2.949835</td>
#       <td id="T_7c412_row1_col13" class="data row1 col13" >68.49%</td>
#       <td id="T_7c412_row1_col14" class="data row1 col14" >13.01%</td>
#       <td id="T_7c412_row1_col15" class="data row1 col15" >18.50%</td>
#     </tr>
#     <tr>
#       <th id="T_7c412_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c412_row2_col0" class="data row2 col0" >Borussia M.Gladbach vs. Freiburg</td>
#       <td id="T_7c412_row2_col1" class="data row2 col1" >1.440000</td>
#       <td id="T_7c412_row2_col2" class="data row2 col2" >7.200000</td>
#       <td id="T_7c412_row2_col3" class="data row2 col3" >6.040000</td>
#       <td id="T_7c412_row2_col4" class="data row2 col4" >2.250000</td>
#       <td id="T_7c412_row2_col5" class="data row2 col5" >2.950000</td>
#       <td id="T_7c412_row2_col6" class="data row2 col6" >3.700000</td>
#       <td id="T_7c412_row2_col7" class="data row2 col7" >0.570000</td>
#       <td id="T_7c412_row2_col8" class="data row2 col8" >-0.590000</td>
#       <td id="T_7c412_row2_col9" class="data row2 col9" >-0.390000</td>
#       <td id="T_7c412_row2_col10" class="data row2 col10" >2.672733</td>
#       <td id="T_7c412_row2_col11" class="data row2 col11" >1.157699</td>
#       <td id="T_7c412_row2_col12" class="data row2 col12" >3.830433</td>
#       <td id="T_7c412_row2_col13" class="data row2 col13" >69.56%</td>
#       <td id="T_7c412_row2_col14" class="data row2 col14" >13.89%</td>
#       <td id="T_7c412_row2_col15" class="data row2 col15" >16.55%</td>
#     </tr>
#     <tr>
#       <th id="T_7c412_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c412_row3_col0" class="data row3 col0" >Eintracht Frankfurt vs. Union Berlin</td>
#       <td id="T_7c412_row3_col1" class="data row3 col1" >1.650000</td>
#       <td id="T_7c412_row3_col2" class="data row3 col2" >6.310000</td>
#       <td id="T_7c412_row3_col3" class="data row3 col3" >4.220000</td>
#       <td id="T_7c412_row3_col4" class="data row3 col4" >2.050000</td>
#       <td id="T_7c412_row3_col5" class="data row3 col5" >3.750000</td>
#       <td id="T_7c412_row3_col6" class="data row3 col6" >3.450000</td>
#       <td id="T_7c412_row3_col7" class="data row3 col7" >0.240000</td>
#       <td id="T_7c412_row3_col8" class="data row3 col8" >-0.410000</td>
#       <td id="T_7c412_row3_col9" class="data row3 col9" >-0.180000</td>
#       <td id="T_7c412_row3_col10" class="data row3 col10" >1.682564</td>
#       <td id="T_7c412_row3_col11" class="data row3 col11" >0.732533</td>
#       <td id="T_7c412_row3_col12" class="data row3 col12" >2.415098</td>
#       <td id="T_7c412_row3_col13" class="data row3 col13" >60.47%</td>
#       <td id="T_7c412_row3_col14" class="data row3 col14" >15.86%</td>
#       <td id="T_7c412_row3_col15" class="data row3 col15" >23.67%</td>
#     </tr>
#     <tr>
#       <th id="T_7c412_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c412_row4_col0" class="data row4 col0" >RasenBallsport Leipzig vs. Mainz 05</td>
#       <td id="T_7c412_row4_col1" class="data row4 col1" >1.190000</td>
#       <td id="T_7c412_row4_col2" class="data row4 col2" >17.990000</td>
#       <td id="T_7c412_row4_col3" class="data row4 col3" >9.620000</td>
#       <td id="T_7c412_row4_col4" class="data row4 col4" >1.380000</td>
#       <td id="T_7c412_row4_col5" class="data row4 col5" >7.000000</td>
#       <td id="T_7c412_row4_col6" class="data row4 col6" >5.200000</td>
#       <td id="T_7c412_row4_col7" class="data row4 col7" >0.160000</td>
#       <td id="T_7c412_row4_col8" class="data ro

# %%
# Round all numbers to the 2nd decimal place
styled_df = styled_df.format('{:.2f}')

# Display the styled DataFrame with rounded numbers
styled_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:408, in Styler._repr_html_(self)
#     403 """
#     404 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     405 default if an object is returned at the end of a cell.
#     406 """
#     407 if get_option("styler.render.repr") == "html":
# --> 408     return self.to_html()
#     409 return None
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1348, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1345     obj.set_caption(caption)
#    1347 # Build HTML string..
# -> 1348 html = obj._render_html(
#    1349     sparse_index=sparse_index,
#    1350     sparse_columns=sparse_columns,
#    1351     max_rows=max_rows,
#    1352     max_cols=max_columns,
#    1353     exclude_styles=exclude_styles,
#    1354     encoding=encoding or get_option("styler.render.encoding"),
#    1355     doctype_html=doctype_html,
#    1356     **kwargs,
#    1357 )
#    1359 return save_to_buffer(
#    1360     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1361 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:204, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     192 def _render_html(
#     193     self,
#     194     sparse_index: bool,
#    (...)
#     198     **kwargs,
#     199 ) -> str:
#     200     """
#     201     Renders the ``Styler`` including all applied styles to HTML.
#     202     Generates a dict with necessary kwargs passed to jinja2 template.
#     203     """
# --> 204     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     205     d.update(kwargs)
#     206     return self.template_html.render(
#     207         **d,
#     208         html_table_tpl=self.template_html_table,
#     209         html_style_tpl=self.template_html_style,
#     210     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:187, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     183         self.ctx_index[(r + ctx_len, c)] = v
#     185     ctx_len += len(concatenated.index)
# --> 187 d = self._translate(
#     188     sparse_index, sparse_columns, max_rows, max_cols, blank, dxs
#     189 )
#     190 return d
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:335, in StylerRenderer._translate(self, sparse_index, sparse_cols, max_rows, max_cols, blank, dxs)
#     329 self.cellstyle_map: DefaultDict[tuple[CSSPair, ...], list[str]] = defaultdict(
#     330     list
#     331 )
#     332 self.cellstyle_map_index: DefaultDict[
#     333     tuple[CSSPair, ...], list[str]
#     334 ] = defaultdict(list)
# --> 335 body: list = self._translate_body(idx_lengths, max_rows, max_cols)
#     336 d.update({"body": body})
#     338 ctx_maps = {
#     339     "cellstyle": "cellstyle_map",
#     340     "cellstyle_index": "cellstyle_map_index",
#     341     "cellstyle_columns": "cellstyle_map_columns",
#     342 }  # add the cell_ids styles map to the render dictionary in right format
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:629, in StylerRenderer._translate_body(self, idx_lengths, max_rows, max_cols)
#     621     if self._check_trim(
#     622         visible_row_count,
#     623         max_rows,
#     624         body,
#     625         "row",
#     626     ):
#     627         break
# --> 629     body_row = self._generate_body_row(
#     630         (r, row_tup, rlabels), max_cols, idx_lengths
#     631     )
#     632     body.append(body_row)
#     633 return body
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:826, in StylerRenderer._generate_body_row(self, iter, max_cols, idx_lengths)
#     814 if (r, c) in self.cell_context:
#     815     cls = " " + self.cell_context[r, c]
#     817 data_element = _element(
#     818     "td",
#     819     (
#     820         f"{self.css['data']} {self.css['row']}{r} "
#     821         f"{self.css['col']}{c}{cls}"
#     822     ),
#     823     value,
#     824     data_element_visible,
#     825     attributes="",
# --> 826     display_value=self._display_funcs[(r, c)](value),
#     827 )
#     829 if self.cell_ids:
#     830     data_element["id"] = f"{self.css['row']}{r}_{self.css['col']}{c}"
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:1829, in _maybe_wrap_formatter.<locals>.<lambda>(x)
#    1827 # Get initial func from input string, input callable, or from default factory
#    1828 if isinstance(formatter, str):
# -> 1829     func_0 = lambda x: formatter.format(x)
#    1830 elif callable(formatter):
#    1831     func_0 = formatter
#
# ValueError: Unknown format code 'f' for object of type 'str'
