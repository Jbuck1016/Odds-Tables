# %%
import soccerdata as sd
understat = sd.Understat(leagues="FRA-Ligue 1", seasons="2023/2024")
team_match_stats = understat.read_team_match_stats()
team_match_stats.head()
# Out:
# [03/26/24 20:06:34] INFO     No custom team name replacements found. You can configure these in       ]8;id=981814;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=169179;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py#87\87]8;;\
#                              C:\Users\jbuck\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=18257;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=857558;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py#177\177]8;;\
#                              C:\Users\jbuck\soccerdata\config\league_dict.json.
#                     INFO     Saving cached data to C:\Users\jbuck\soccerdata\data\Understat           ]8;id=247356;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=43535;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\
#                                                           league_id  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                          5
#                    2023-08-12 Marseille-Reims                     5
#                    2023-08-12 Nice-Lille                          5
#                    2023-08-12 Paris Saint Germain-Lorient         5
#                    2023-08-13 Clermont Foot-Monaco                5
#
#                                                            season_id  game_id  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                        2023    23378
#                    2023-08-12 Marseille-Reims                   2023    23372
#                    2023-08-12 Nice-Lille                        2023    23377
#                    2023-08-12 Paris Saint Germain-Lorient       2023    23379
#                    2023-08-13 Clermont Foot-Monaco              2023    23375
#
#                                                                          date  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                  2023-08-12 18:00:00
#                    2023-08-12 Marseille-Reims             2023-08-12 18:00:00
#                    2023-08-12 Nice-Lille                  2023-08-12 18:00:00
#                    2023-08-12 Paris Saint Germain-Lorient 2023-08-12 18:00:00
#                    2023-08-13 Clermont Foot-Monaco        2023-08-13 13:00:00
#
#                                                            home_team_id  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                            241
#                    2023-08-12 Marseille-Reims                       164
#                    2023-08-12 Nice-Lille                            170
#                    2023-08-12 Paris Saint Germain-Lorient           161
#                    2023-08-13 Clermont Foot-Monaco                  270
#
#                                                            away_team_id  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                            210
#                    2023-08-12 Marseille-Reims                       177
#                    2023-08-12 Nice-Lille                            160
#                    2023-08-12 Paris Saint Germain-Lorient           179
#                    2023-08-13 Clermont Foot-Monaco                  171
#
#                                                                      home_team  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                                 Brest
#                    2023-08-12 Marseille-Reims                        Marseille
#                    2023-08-12 Nice-Lille                                  Nice
#                    2023-08-12 Paris Saint Germain-Lorient  Paris Saint Germain
#                    2023-08-13 Clermont Foot-Monaco               Clermont Foot
#
#                                                           away_team  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                       Lens
#                    2023-08-12 Marseille-Reims                 Reims
#                    2023-08-12 Nice-Lille                      Lille
#                    2023-08-12 Paris Saint Germain-Lorient   Lorient
#                    2023-08-13 Clermont Foot-Monaco           Monaco
#
#                                                           away_team_code  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                             LEN
#                    2023-08-12 Marseille-Reims                        REI
#                    2023-08-12 Nice-Lille                             LIL
#                    2023-08-12 Paris Saint Germain-Lorient            LOR
#                    2023-08-13 Clermont Foot-Monaco                   MON
#
#                                                           home_team_code  ...  \
# league      season game                                                   ...
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                             BRE  ...
#                    2023-08-12 Marseille-Reims                        MAR  ...
#                    2023-08-12 Nice-Lille                             NIC  ...
#                    2023-08-12 Paris Saint Germain-Lorient            PSG  ...
#                    2023-08-13 Clermont Foot-Monaco                   CLE  ...
#
#                                                            away_ppda  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                   10.842105
#                    2023-08-12 Marseille-Reims                5.37931
#                    2023-08-12 Nice-Lille                    6.020833
#                    2023-08-12 Paris Saint Germain-Lorient       41.6
#                    2023-08-13 Clermont Foot-Monaco               9.1
#
#                                                            away_deep_completions  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                                       6
#                    2023-08-12 Marseille-Reims                                  3
#                    2023-08-12 Nice-Lille                                       6
#                    2023-08-12 Paris Saint Germain-Lorient                      1
#                    2023-08-13 Clermont Foot-Monaco                            11
#
#                                                            home_points  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                             3
#                    2023-08-12 Marseille-Reims                        3
#                    2023-08-12 Nice-Lille                             1
#                    2023-08-12 Paris Saint Germain-Lorient            1
#                    2023-08-13 Clermont Foot-Monaco                   0
#
#                                                            home_expected_points  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                                 2.6626
#                    2023-08-12 Marseille-Reims                            1.7955
#                    2023-08-12 Nice-Lille                                  1.006
#                    2023-08-12 Paris Saint Germain-Lorient                2.4181
#                    2023-08-13 Clermont Foot-Monaco                       0.4618
#
#                                                            home_goals  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                            3
#                    2023-08-12 Marseille-Reims                       2
#                    2023-08-12 Nice-Lille                            1
#                    2023-08-12 Paris Saint Germain-Lorient           0
#                    2023-08-13 Clermont Foot-Monaco                  2
#
#                                                            home_xg  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                   2.91934
#                    2023-08-12 Marseille-Reims               1.5127
#                    2023-08-12 Nice-Lille                   1.12141
#                    2023-08-12 Paris Saint Germain-Lorient  1.36166
#                    2023-08-13 Clermont Foot-Monaco         1.97981
#
#                                                            home_np_xg  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                      1.39915
#                    2023-08-12 Marseille-Reims                  1.5127
#                    2023-08-12 Nice-Lille                      1.12141
#                    2023-08-12 Paris Saint Germain-Lorient     1.36166
#                    2023-08-13 Clermont Foot-Monaco            1.97981
#
#                                                            home_np_xg_difference  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                                0.439148
#                    2023-08-12 Marseille-Reims                           0.519326
#                    2023-08-12 Nice-Lille                                -0.41296
#                    2023-08-12 Paris Saint Germain-Lorient               1.225391
#                    2023-08-13 Clermont Foot-Monaco                      -1.42447
#
#                                                            home_ppda  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                    7.592593
#                    2023-08-12 Marseille-Reims              14.647059
#                    2023-08-12 Nice-Lille                   19.277778
#                    2023-08-12 Paris Saint Germain-Lorient        7.5
#                    2023-08-13 Clermont Foot-Monaco             10.52
#
#                                                            home_deep_completions
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                                       4
#                    2023-08-12 Marseille-Reims                                 10
#                    2023-08-12 Nice-Lille                                       3
#                    2023-08-12 Paris Saint Germain-Lorient                     15
#                    2023-08-13 Clermont Foot-Monaco                             5
#
# [5 rows x 26 columns]

# %%
import pandas as pd

# Assuming 'team_match_stats' is your DataFrame loaded from the code you've provided

# Calculating total xG for teams when they are at home
home_xg = team_match_stats.groupby('home_team')['home_xg'].sum().rename('total_home_xg')

# Calculating total xG for teams when they are away
away_xg = team_match_stats.groupby('away_team')['away_xg'].sum().rename('total_away_xg')

# Calculating total xGA (expected goals against) for teams when they are at home
home_xga = team_match_stats.groupby('home_team')['away_xg'].sum().rename('total_home_xga')

# Calculating total xGA for teams when they are away
away_xga = team_match_stats.groupby('away_team')['home_xg'].sum().rename('total_away_xga')

# Merging the above series into a single DataFrame
teams_xg_xga = pd.concat([home_xg, away_xg, home_xga, away_xga], axis=1)

# Filling NaN values with 0, in case some teams didn't play home or away games yet
teams_xg_xga = teams_xg_xga.fillna(0)

# Calculating overall total xG and xGA
teams_xg_xga['total_xg'] = teams_xg_xga['total_home_xg'] + teams_xg_xga['total_away_xg']
teams_xg_xga['total_xga'] = teams_xg_xga['total_home_xga'] + teams_xg_xga['total_away_xga']

teams_xg_xga
# Out:
#                      total_home_xg  total_away_xg  total_home_xga  \
# Brest                    23.930517      15.529946       10.034953
# Clermont Foot            15.003876      12.022555       23.162442
# Le Havre                 17.210425       10.82501        16.16019
# Lens                     27.684247      18.558772       18.224354
# Lille                    28.703933      15.508514       10.920693
# Lorient                  14.460508      11.917485       21.577835
# Lyon                     22.661346       16.34067       20.709636
# Marseille                27.691101      17.749429        9.135964
# Metz                     10.683216      13.323216       12.160734
# Monaco                    22.91039      24.499925       12.800384
# Montpellier              25.885759      13.575261        17.98993
# Nantes                   18.907583      11.981308       25.727364
# Nice                     22.234768       18.52776       12.850903
# Paris Saint Germain       24.90338       30.45931       11.160547
# Reims                    20.658357      19.662587       16.257697
# Rennes                    29.52547      12.871352       18.112053
# Strasbourg               17.302853      14.909032       19.214063
# Toulouse                 19.570143      13.792327       15.854717
#
#                      total_away_xga   total_xg  total_xga
# Brest                      18.90635  39.460463  28.941303
# Clermont Foot              25.96368  27.026431  49.126122
# Le Havre                  26.888378  28.035435  43.048568
# Lens                      21.162952  46.243019  39.387306
# Lille                     19.044851  44.212447  29.965544
# Lorient                   22.569762  26.377993  44.147597
# Lyon                      21.458901  39.002016  42.168537
# Marseille                 17.310695   45.44053  26.446659
# Metz                      29.551641  24.006432  41.712375
# Monaco                    22.445782  47.410315  35.246166
# Montpellier               22.324361   39.46102  40.314291
# Nantes                    22.067267  30.888891  47.794631
# Nice                      14.459059  40.762528  27.309962
# Paris Saint Germain        25.45315   55.36269  36.613697
# Reims                     18.995123  40.320944   35.25282
# Rennes                    16.250961  42.396822  34.363014
# Strasbourg                19.644017  32.211885   38.85808
# Toulouse                  25.430942   33.36247  41.285659

# %%
import pandas as pd

# Identify all unique teams
teams = pd.concat([team_match_stats['home_team'], team_match_stats['away_team']]).unique()

# Prepare a list to collect each team's average xG and xGA for home and away games
team_averages = []

# Iterate through each team
for team in teams:
    # Filter home games involving the current team
    team_home_games = team_match_stats[team_match_stats['home_team'] == team]
    # Sort home games by date in descending order and select the last 5
    team_last_5_home_games = team_home_games.sort_values(by='date', ascending=False).head(5)
    
    # Filter away games involving the current team
    team_away_games = team_match_stats[team_match_stats['away_team'] == team]
    # Sort away games by date in descending order and select the last 5
    team_last_5_away_games = team_away_games.sort_values(by='date', ascending=False).head(5)
    
    # Calculate average xG and xGA for home games
    team_home_xg_avg = team_last_5_home_games['home_xg'].mean()
    team_home_xga_avg = team_last_5_home_games['away_xg'].mean()
    
    # Calculate average xG and xGA for away games
    team_away_xg_avg = team_last_5_away_games['away_xg'].mean()
    team_away_xga_avg = team_last_5_away_games['home_xg'].mean()
    
    # Append the averages to the list
    team_averages.append({
        'Team': team,
        'Average Home xG Last 5': team_home_xg_avg,
        'Average Home xGA Last 5': team_home_xga_avg,
        'Average Away xG Last 5': team_away_xg_avg,
        'Average Away xGA Last 5': team_away_xga_avg
    })

# Convert the list of averages into a DataFrame
teams_xg_xga_df = pd.DataFrame(team_averages)

# Display the DataFrame
teams_xg_xga_df
# Out:
#                    Team  Average Home xG Last 5  Average Home xGA Last 5  \
# 0                 Brest                1.939687                 0.580971
# 1             Marseille                2.474930                 0.844794
# 2                  Nice                2.115546                 1.371354
# 3   Paris Saint Germain                1.986616                 1.041332
# 4         Clermont Foot                1.079986                 1.839624
# 5           Montpellier                2.055384                 1.341739
# 6                Nantes                1.231798                 1.766178
# 7                Rennes                2.277562                 1.009002
# 8            Strasbourg                1.103687                 1.602185
# 9                  Metz                1.166003                 0.994436
# 10                 Lyon                1.586333                 1.255171
# 11             Toulouse                1.766485                 1.135530
# 12             Le Havre                1.548230                 1.416719
# 13                 Lens                1.915877                 1.626105
# 14                Lille                2.823028                 0.767041
# 15              Lorient                1.199081                 1.399908
# 16               Monaco                2.016204                 1.248576
# 17                Reims                1.278500                 1.363598
#
#     Average Away xG Last 5  Average Away xGA Last 5
# 0                 1.303135                 1.076692
# 1                 1.203840                 1.512162
# 2                 1.176522                 1.273223
# 3                 1.903890                 2.471376
# 4                 1.175195                 2.430292
# 5                 0.958419                 2.366048
# 6                 0.648467                 1.375182
# 7                 1.414494                 1.491726
# 8                 1.527346                 1.456533
# 9                 1.098581                 1.991769
# 10                1.460970                 1.472501
# 11                1.217218                 1.733440
# 12                0.673852                 1.955906
# 13                1.632199                 1.852729
# 14                0.926653                 1.545580
# 15                1.266185                 2.103623
# 16                1.672391                 2.069466
# 17                1.730174                 1.567508

# %%
# Count the number of home matches played by each team
home_matches_played = team_match_stats.groupby('home_team')['home_ppda'].count().rename('home_matches_played')

# Count the number of away matches played by each team
away_matches_played = team_match_stats.groupby('away_team')['away_ppda'].count().rename('away_matches_played')

# Merging these counts into the teams_xg_xga DataFrame
teams_xg_xga = teams_xg_xga.merge(home_matches_played, how='left', left_index=True, right_index=True)
teams_xg_xga = teams_xg_xga.merge(away_matches_played, how='left', left_index=True, right_index=True)

# Filling NaN values with 0 in case some teams didn't play home or away games
teams_xg_xga['home_matches_played'] = teams_xg_xga['home_matches_played'].fillna(0)
teams_xg_xga['away_matches_played'] = teams_xg_xga['away_matches_played'].fillna(0)

# Calculating the total matches played by adding home and away matches
teams_xg_xga['matches_played'] = teams_xg_xga['home_matches_played'] + teams_xg_xga['away_matches_played']

teams_xg_xga
# Out:
#                      total_home_xg  total_away_xg  total_home_xga  \
# Brest                    23.930517      15.529946       10.034953
# Clermont Foot            15.003876      12.022555       23.162442
# Le Havre                 17.210425       10.82501        16.16019
# Lens                     27.684247      18.558772       18.224354
# Lille                    28.703933      15.508514       10.920693
# Lorient                  14.460508      11.917485       21.577835
# Lyon                     22.661346       16.34067       20.709636
# Marseille                27.691101      17.749429        9.135964
# Metz                     10.683216      13.323216       12.160734
# Monaco                    22.91039      24.499925       12.800384
# Montpellier              25.885759      13.575261        17.98993
# Nantes                   18.907583      11.981308       25.727364
# Nice                     22.234768       18.52776       12.850903
# Paris Saint Germain       24.90338       30.45931       11.160547
# Reims                    20.658357      19.662587       16.257697
# Rennes                    29.52547      12.871352       18.112053
# Strasbourg               17.302853      14.909032       19.214063
# Toulouse                 19.570143      13.792327       15.854717
#
#                      total_away_xga   total_xg  total_xga  \
# Brest                      18.90635  39.460463  28.941303
# Clermont Foot              25.96368  27.026431  49.126122
# Le Havre                  26.888378  28.035435  43.048568
# Lens                      21.162952  46.243019  39.387306
# Lille                     19.044851  44.212447  29.965544
# Lorient                   22.569762  26.377993  44.147597
# Lyon                      21.458901  39.002016  42.168537
# Marseille                 17.310695   45.44053  26.446659
# Metz                      29.551641  24.006432  41.712375
# Monaco                    22.445782  47.410315  35.246166
# Montpellier               22.324361   39.46102  40.314291
# Nantes                    22.067267  30.888891  47.794631
# Nice                      14.459059  40.762528  27.309962
# Paris Saint Germain        25.45315   55.36269  36.613697
# Reims                     18.995123  40.320944   35.25282
# Rennes                    16.250961  42.396822  34.363014
# Strasbourg                19.644017  32.211885   38.85808
# Toulouse                  25.430942   33.36247  41.285659
#
#                      home_matches_played  away_matches_played  matches_played
# Brest                                 13                   13              26
# Clermont Foot                         13                   13              26
# Le Havre                              12                   14              26
# Lens                                  13                   13              26
# Lille                                 12                   14              26
# Lorient                               13                   13              26
# Lyon                                  13                   13              26
# Marseille                             13                   13              26
# Metz                                  12                   14              26
# Monaco                                13                   13              26
# Montpellier                           14                   12              26
# Nantes                                14                   12              26
# Nice                                  13                   13              26
# Paris Saint Germain                   13                   13              26
# Reims                                 13                   13              26
# Rennes                                14                   12              26
# Strasbourg                            13                   13              26
# Toulouse                              13                   13              26

# %%
# Calculating xG difference for home games
teams_xg_xga['home_xg_diff'] = teams_xg_xga['total_home_xg'] - teams_xg_xga['total_home_xga']

# Calculating xG difference for away games
teams_xg_xga['away_xg_diff'] = teams_xg_xga['total_away_xg'] - teams_xg_xga['total_away_xga']

# Display the updated DataFrame
teams_xg_xga
# Out:
#                      total_home_xg  total_away_xg  total_home_xga  \
# Brest                    23.930517      15.529946       10.034953
# Clermont Foot            15.003876      12.022555       23.162442
# Le Havre                 17.210425       10.82501        16.16019
# Lens                     27.684247      18.558772       18.224354
# Lille                    28.703933      15.508514       10.920693
# Lorient                  14.460508      11.917485       21.577835
# Lyon                     22.661346       16.34067       20.709636
# Marseille                27.691101      17.749429        9.135964
# Metz                     10.683216      13.323216       12.160734
# Monaco                    22.91039      24.499925       12.800384
# Montpellier              25.885759      13.575261        17.98993
# Nantes                   18.907583      11.981308       25.727364
# Nice                     22.234768       18.52776       12.850903
# Paris Saint Germain       24.90338       30.45931       11.160547
# Reims                    20.658357      19.662587       16.257697
# Rennes                    29.52547      12.871352       18.112053
# Strasbourg               17.302853      14.909032       19.214063
# Toulouse                 19.570143      13.792327       15.854717
#
#                      total_away_xga   total_xg  total_xga  \
# Brest                      18.90635  39.460463  28.941303
# Clermont Foot              25.96368  27.026431  49.126122
# Le Havre                  26.888378  28.035435  43.048568
# Lens                      21.162952  46.243019  39.387306
# Lille                     19.044851  44.212447  29.965544
# Lorient                   22.569762  26.377993  44.147597
# Lyon                      21.458901  39.002016  42.168537
# Marseille                 17.310695   45.44053  26.446659
# Metz                      29.551641  24.006432  41.712375
# Monaco                    22.445782  47.410315  35.246166
# Montpellier               22.324361   39.46102  40.314291
# Nantes                    22.067267  30.888891  47.794631
# Nice                      14.459059  40.762528  27.309962
# Paris Saint Germain        25.45315   55.36269  36.613697
# Reims                     18.995123  40.320944   35.25282
# Rennes                    16.250961  42.396822  34.363014
# Strasbourg                19.644017  32.211885   38.85808
# Toulouse                  25.430942   33.36247  41.285659
#
#                      home_matches_played  away_matches_played  matches_played  \
# Brest                                 13                   13              26
# Clermont Foot                         13                   13              26
# Le Havre                              12                   14              26
# Lens                                  13                   13              26
# Lille                                 12                   14              26
# Lorient                               13                   13              26
# Lyon                                  13                   13              26
# Marseille                             13                   13              26
# Metz                                  12                   14              26
# Monaco                                13                   13              26
# Montpellier                           14                   12              26
# Nantes                                14                   12              26
# Nice                                  13                   13              26
# Paris Saint Germain                   13                   13              26
# Reims                                 13                   13              26
# Rennes                                14                   12              26
# Strasbourg                            13                   13              26
# Toulouse                              13                   13              26
#
#                      home_xg_diff  away_xg_diff
# Brest                   13.895564     -3.376404
# Clermont Foot           -8.158566    -13.941125
# Le Havre                 1.050235    -16.063368
# Lens                     9.459893      -2.60418
# Lille                    17.78324     -3.536337
# Lorient                 -7.117327    -10.652277
# Lyon                      1.95171     -5.118231
# Marseille               18.555137      0.438734
# Metz                    -1.477518    -16.228425
# Monaco                  10.110006      2.054143
# Montpellier              7.895829       -8.7491
# Nantes                  -6.819781    -10.085959
# Nice                     9.383865      4.068701
# Paris Saint Germain     13.742833       5.00616
# Reims                     4.40066      0.667464
# Rennes                  11.413417     -3.379609
# Strasbourg               -1.91121     -4.734985
# Toulouse                 3.715426    -11.638615

# %%
# Assuming 'teams_xg_xga' is your DataFrame

# Calculate the averages for each specified column
averages = teams_xg_xga.mean()

# Creating a new DataFrame with the averages to append it properly with a label
averages_df = pd.DataFrame([averages], index=['Average'])

# Append the averages row to your original DataFrame
teams_xg_xga_with_averages = pd.concat([teams_xg_xga, averages_df])

teams_xg_xga_with_averages
# Out:
#                      total_home_xg  total_away_xg  total_home_xga  \
# Brest                    23.930517      15.529946       10.034953
# Clermont Foot            15.003876      12.022555       23.162442
# Le Havre                 17.210425       10.82501        16.16019
# Lens                     27.684247      18.558772       18.224354
# Lille                    28.703933      15.508514       10.920693
# Lorient                  14.460508      11.917485       21.577835
# Lyon                     22.661346       16.34067       20.709636
# Marseille                27.691101      17.749429        9.135964
# Metz                     10.683216      13.323216       12.160734
# Monaco                    22.91039      24.499925       12.800384
# Montpellier              25.885759      13.575261        17.98993
# Nantes                   18.907583      11.981308       25.727364
# Nice                     22.234768       18.52776       12.850903
# Paris Saint Germain       24.90338       30.45931       11.160547
# Reims                    20.658357      19.662587       16.257697
# Rennes                    29.52547      12.871352       18.112053
# Strasbourg               17.302853      14.909032       19.214063
# Toulouse                 19.570143      13.792327       15.854717
# Average                   21.66266      16.225248       16.225248
#
#                      total_away_xga   total_xg  total_xga  \
# Brest                      18.90635  39.460463  28.941303
# Clermont Foot              25.96368  27.026431  49.126122
# Le Havre                  26.888378  28.035435  43.048568
# Lens                      21.162952  46.243019  39.387306
# Lille                     19.044851  44.212447  29.965544
# Lorient                   22.569762  26.377993  44.147597
# Lyon                      21.458901  39.002016  42.168537
# Marseille                 17.310695   45.44053  26.446659
# Metz                      29.551641  24.006432  41.712375
# Monaco                    22.445782  47.410315  35.246166
# Montpellier               22.324361   39.46102  40.314291
# Nantes                    22.067267  30.888891  47.794631
# Nice                      14.459059  40.762528  27.309962
# Paris Saint Germain        25.45315   55.36269  36.613697
# Reims                     18.995123  40.320944   35.25282
# Rennes                    16.250961  42.396822  34.363014
# Strasbourg                19.644017  32.211885   38.85808
# Toulouse                  25.430942   33.36247  41.285659
# Average                    21.66266  37.887907  37.887907
#
#                      home_matches_played  away_matches_played  matches_played  \
# Brest                               13.0                 13.0            26.0
# Clermont Foot                       13.0                 13.0            26.0
# Le Havre                            12.0                 14.0            26.0
# Lens                                13.0                 13.0            26.0
# Lille                               12.0                 14.0            26.0
# Lorient                             13.0                 13.0            26.0
# Lyon                                13.0                 13.0            26.0
# Marseille                           13.0                 13.0            26.0
# Metz                                12.0                 14.0            26.0
# Monaco                              13.0                 13.0            26.0
# Montpellier                         14.0                 12.0            26.0
# Nantes                              14.0                 12.0            26.0
# Nice                                13.0                 13.0            26.0
# Paris Saint Germain                 13.0                 13.0            26.0
# Reims                               13.0                 13.0            26.0
# Rennes                              14.0                 12.0            26.0
# Strasbourg                          13.0                 13.0            26.0
# Toulouse                            13.0                 13.0            26.0
# Average                             13.0                 13.0            26.0
#
#                      home_xg_diff  away_xg_diff
# Brest                   13.895564     -3.376404
# Clermont Foot           -8.158566    -13.941125
# Le Havre                 1.050235    -16.063368
# Lens                     9.459893      -2.60418
# Lille                    17.78324     -3.536337
# Lorient                 -7.117327    -10.652277
# Lyon                      1.95171     -5.118231
# Marseille               18.555137      0.438734
# Metz                    -1.477518    -16.228425
# Monaco                  10.110006      2.054143
# Montpellier              7.895829       -8.7491
# Nantes                  -6.819781    -10.085959
# Nice                     9.383865      4.068701
# Paris Saint Germain     13.742833       5.00616
# Reims                     4.40066      0.667464
# Rennes                  11.413417     -3.379609
# Strasbourg               -1.91121     -4.734985
# Toulouse                 3.715426    -11.638615
# Average                  5.437412     -5.437412

# %%
import numpy as np

# Create a new DataFrame for per match averages
teams_per_match_averages = pd.DataFrame(index=teams_xg_xga.index)

# Calculate per match averages for home and away xG and xGA
teams_per_match_averages['per_match_home_xg'] = teams_xg_xga['total_home_xg'] / teams_xg_xga['home_matches_played']
teams_per_match_averages['per_match_away_xg'] = teams_xg_xga['total_away_xg'] / teams_xg_xga['away_matches_played']
teams_per_match_averages['per_match_home_xga'] = teams_xg_xga['total_home_xga'] / teams_xg_xga['home_matches_played']
teams_per_match_averages['per_match_away_xga'] = teams_xg_xga['total_away_xga'] / teams_xg_xga['away_matches_played']

# Calculate overall total xG and xGA per match
teams_per_match_averages['total_xg_per_match'] = teams_xg_xga['total_xg'] / teams_xg_xga['matches_played']
teams_per_match_averages['total_xga_per_match'] = teams_xg_xga['total_xga'] / teams_xg_xga['matches_played']

# Replace any potential infinite values with NaN (in case of division by zero) and then fill with 0
teams_per_match_averages.replace([np.inf, -np.inf], np.nan, inplace=True)
teams_per_match_averages.fillna(0, inplace=True)

# Calculate the average for each column
average_stats = teams_per_match_averages.mean()

# Append the 'Average' row with these averages to the DataFrame
teams_per_match_averages.loc['Average'] = average_stats

teams_per_match_averages
# Out:
#                      per_match_home_xg  per_match_away_xg  per_match_home_xga  \
# Brest                         1.840809           1.194611            0.771919
# Clermont Foot                 1.154144           0.924812            1.781726
# Le Havre                      1.434202           0.773215            1.346683
# Lens                          2.129557           1.427598            1.401873
# Lille                         2.391994           1.107751            0.910058
# Lorient                       1.112347            0.91673            1.659833
# Lyon                           1.74318           1.256975            1.593049
# Marseille                     2.130085           1.365341            0.702766
# Metz                          0.890268           0.951658            1.013394
# Monaco                        1.762338            1.88461            0.984645
# Montpellier                   1.848983           1.131272            1.284995
# Nantes                        1.350542           0.998442            1.837669
# Nice                          1.710367           1.425212            0.988531
# Paris Saint Germain           1.915645           2.343024            0.858504
# Reims                         1.589104           1.512507            1.250592
# Rennes                        2.108962           1.072613            1.293718
# Strasbourg                    1.330989           1.146849            1.478005
# Toulouse                      1.505396           1.060948            1.219594
# Average                       1.663828           1.249676            1.243197
#
#                      per_match_away_xga  total_xg_per_match  \
# Brest                          1.454335             1.51771
# Clermont Foot                  1.997206            1.039478
# Le Havre                       1.920598            1.078286
# Lens                           1.627919            1.778578
# Lille                          1.360347            1.700479
# Lorient                        1.736136            1.014538
# Lyon                           1.650685            1.500078
# Marseille                      1.331592            1.747713
# Metz                           2.110832            0.923324
# Monaco                         1.726599            1.823474
# Montpellier                    1.860363            1.517732
# Nantes                         1.838939            1.188034
# Nice                           1.112235             1.56779
# Paris Saint Germain            1.957935            2.129334
# Reims                          1.461163            1.550806
# Rennes                         1.354247            1.630647
# Strasbourg                     1.511078            1.238919
# Toulouse                       1.956226            1.283172
# Average                        1.664913            1.457227
#
#                      total_xga_per_match
# Brest                           1.113127
# Clermont Foot                   1.889466
# Le Havre                        1.655714
# Lens                            1.514896
# Lille                           1.152521
# Lorient                         1.697985
# Lyon                            1.621867
# Marseille                       1.017179
# Metz                            1.604322
# Monaco                          1.355622
# Montpellier                      1.55055
# Nantes                          1.838255
# Nice                            1.050383
# Paris Saint Germain             1.408219
# Reims                           1.355878
# Rennes                          1.321654
# Strasbourg                      1.494542
# Toulouse                         1.58791
# Average                         1.457227

# %%
# Load the full schedule
schedule_df = understat.read_schedule()

# Convert the 'date' column to datetime format, then format it to keep only the date part
schedule_df['date'] = pd.to_datetime(schedule_df['date']).dt.date

# Display the first few rows to verify the change
print(schedule_df.head())
# Out:
#                                                           league_id  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                          5
#                    2023-08-12 Marseille-Reims                     5
#                    2023-08-12 Nice-Lille                          5
#                    2023-08-12 Paris Saint Germain-Lorient         5
#                    2023-08-13 Clermont Foot-Monaco                5
#
#                                                            season_id  game_id  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                        2023    23378
#                    2023-08-12 Marseille-Reims                   2023    23372
#                    2023-08-12 Nice-Lille                        2023    23377
#                    2023-08-12 Paris Saint Germain-Lorient       2023    23379
#                    2023-08-13 Clermont Foot-Monaco              2023    23375
#
#                                                                  date  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                   2023-08-12
#                    2023-08-12 Marseille-Reims              2023-08-12
#                    2023-08-12 Nice-Lille                   2023-08-12
#                    2023-08-12 Paris Saint Germain-Lorient  2023-08-12
#                    2023-08-13 Clermont Foot-Monaco         2023-08-13
#
#                                                            home_team_id  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                            241
#                    2023-08-12 Marseille-Reims                       164
#                    2023-08-12 Nice-Lille                            170
#                    2023-08-12 Paris Saint Germain-Lorient           161
#                    2023-08-13 Clermont Foot-Monaco                  270
#
#                                                            away_team_id  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                            210
#                    2023-08-12 Marseille-Reims                       177
#                    2023-08-12 Nice-Lille                            160
#                    2023-08-12 Paris Saint Germain-Lorient           179
#                    2023-08-13 Clermont Foot-Monaco                  171
#
#                                                                      home_team  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                                 Brest
#                    2023-08-12 Marseille-Reims                        Marseille
#                    2023-08-12 Nice-Lille                                  Nice
#                    2023-08-12 Paris Saint Germain-Lorient  Paris Saint Germain
#                    2023-08-13 Clermont Foot-Monaco               Clermont Foot
#
#                                                           away_team  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                       Lens
#                    2023-08-12 Marseille-Reims                 Reims
#                    2023-08-12 Nice-Lille                      Lille
#                    2023-08-12 Paris Saint Germain-Lorient   Lorient
#                    2023-08-13 Clermont Foot-Monaco           Monaco
#
#                                                           away_team_code  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                             LEN
#                    2023-08-12 Marseille-Reims                        REI
#                    2023-08-12 Nice-Lille                             LIL
#                    2023-08-12 Paris Saint Germain-Lorient            LOR
#                    2023-08-13 Clermont Foot-Monaco                   MON
#
#                                                           home_team_code  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                             BRE
#                    2023-08-12 Marseille-Reims                        MAR
#                    2023-08-12 Nice-Lille                             NIC
#                    2023-08-12 Paris Saint Germain-Lorient            PSG
#                    2023-08-13 Clermont Foot-Monaco                   CLE
#
#                                                            home_goals  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                            3
#                    2023-08-12 Marseille-Reims                       2
#                    2023-08-12 Nice-Lille                            1
#                    2023-08-12 Paris Saint Germain-Lorient           0
#                    2023-08-13 Clermont Foot-Monaco                  2
#
#                                                            away_goals  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                            2
#                    2023-08-12 Marseille-Reims                       1
#                    2023-08-12 Nice-Lille                            1
#                    2023-08-12 Paris Saint Germain-Lorient           0
#                    2023-08-13 Clermont Foot-Monaco                  4
#
#                                                            home_xg   away_xg  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                   2.91934  0.960002
#                    2023-08-12 Marseille-Reims               1.5127  0.993374
#                    2023-08-12 Nice-Lille                   1.12141   1.53437
#                    2023-08-12 Paris Saint Germain-Lorient  1.36166  0.136269
#                    2023-08-13 Clermont Foot-Monaco         1.97981   3.40428
#
#                                                            is_result  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                        True
#                    2023-08-12 Marseille-Reims                   True
#                    2023-08-12 Nice-Lille                        True
#                    2023-08-12 Paris Saint Germain-Lorient       True
#                    2023-08-13 Clermont Foot-Monaco              True
#
#                                                            has_data  \
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                       True
#                    2023-08-12 Marseille-Reims                  True
#                    2023-08-12 Nice-Lille                       True
#                    2023-08-12 Paris Saint Germain-Lorient      True
#                    2023-08-13 Clermont Foot-Monaco             True
#
#                                                                                          url
# league      season game
# FRA-Ligue 1 2324   2023-08-12 Brest-Lens                   https://understat.com/match/23378
#                    2023-08-12 Marseille-Reims              https://understat.com/match/23372
#                    2023-08-12 Nice-Lille                   https://understat.com/match/23377
#                    2023-08-12 Paris Saint Germain-Lorient  https://understat.com/match/23379
#                    2023-08-13 Clermont Foot-Monaco         https://understat.com/match/23375

# %%
import pandas as pd

# Assuming 'schedule_df' is your DataFrame and it's already loaded

# Make sure the 'date' column is in datetime format
schedule_df['date'] = pd.to_datetime(schedule_df['date'])

# Define the start and end dates for filtering
start_date = pd.to_datetime('2024-03-29')
end_date = pd.to_datetime('2024-04-01')

# Filter the DataFrame for games within the date range, and use .copy() to avoid SettingWithCopyWarning
filtered_games = schedule_df[(schedule_df['date'] >= start_date) & (schedule_df['date'] <= end_date)].copy()

# Create a new column 'game_matchup' by concatenating 'home_team', 'vs.', and 'away_team'
filtered_games['game_matchup'] = filtered_games['home_team'] + ' vs. ' + filtered_games['away_team']

# Now, create a separate DataFrame that contains only the 'game_matchup' column
games_list_df = filtered_games[['game_matchup']].reset_index(drop=True)

# Display the new DataFrame to verify
print(games_list_df)
# Out:
#                         game_matchup
# 0                     Lille vs. Lens
# 1                     Lyon vs. Reims
# 2                    Metz vs. Monaco
# 3         Clermont Foot vs. Toulouse
# 4           Le Havre vs. Montpellier
# 5                  Lorient vs. Brest
# 6  Marseille vs. Paris Saint Germain
# 7                    Nice vs. Nantes
# 8              Strasbourg vs. Rennes

# %%
import pandas as pd

# Assuming 'teams_per_match_averages' and 'games_list_df' are already defined

# Initialize an empty list for storing game metrics along with the matchup information
games_metrics_list = []

# Retrieve the 'Average' row for league-wide average stats
avg_stats = teams_per_match_averages.loc['Average']

# Looping through each game to calculate metrics using 'teams_per_match_averages'
for index, row in games_list_df.iterrows():
    # Extract home and away team names
    home_team, away_team = row['game_matchup'].split(' vs. ')
    
    # Retrieve team stats from 'teams_per_match_averages'
    home_team_stats = teams_per_match_averages.loc[home_team]
    away_team_stats = teams_per_match_averages.loc[away_team]
    
    # Calculate the metrics using the per match averages
    home_attack = home_team_stats['per_match_home_xg'] / avg_stats['per_match_home_xg']
    away_defence = away_team_stats['per_match_away_xga'] / avg_stats['per_match_away_xga']
    away_attack = away_team_stats['per_match_away_xg'] / avg_stats['per_match_away_xg']
    home_defence = home_team_stats['per_match_home_xga'] / avg_stats['per_match_home_xga']
    
    # Append the calculated metrics for this game to the list along with the game_matchup
    games_metrics_list.append({
        'Game Matchup': row['game_matchup'],
        'Home Attack': home_attack, 
        'Away Defence': away_defence,
        'Away Attack': away_attack, 
        'Home Defence': home_defence
    })

# Once all games are processed, create the DataFrame from the list
games_metrics_df = pd.DataFrame(games_metrics_list)

# Splitting 'Game Matchup' into 'Home Team' and 'Away Team'
games_metrics_df[['Home Team', 'Away Team']] = games_metrics_df['Game Matchup'].str.split(' vs. ', expand=True)

# Display the DataFrame with calculated metrics for each game
games_metrics_df
# Out:
#                         Game Matchup  Home Attack  Away Defence  Away Attack  \
# 0                     Lille vs. Lens     1.437645      0.977780     1.142374
# 1                     Lyon vs. Reims     1.047692      0.877621     1.210319
# 2                    Metz vs. Monaco     0.535072      1.037050     1.508079
# 3         Clermont Foot vs. Toulouse     0.693668      1.174972     0.848979
# 4           Le Havre vs. Montpellier     0.861989      1.117394     0.905252
# 5                  Lorient vs. Brest     0.668547      0.873520     0.955937
# 6  Marseille vs. Paris Saint Germain     1.280231      1.175998     1.874905
# 7                    Nice vs. Nantes     1.027971      1.104526     0.798961
# 8              Strasbourg vs. Rennes     0.799955      0.813404     0.858313
#
#    Home Defence      Home Team            Away Team
# 0      0.732030          Lille                 Lens
# 1      1.281413           Lyon                Reims
# 2      0.815152           Metz               Monaco
# 3      1.433180  Clermont Foot             Toulouse
# 4      1.083241       Le Havre          Montpellier
# 5      1.335133        Lorient                Brest
# 6      0.565289      Marseille  Paris Saint Germain
# 7      0.795152           Nice               Nantes
# 8      1.188874     Strasbourg               Rennes

# %%
# Merge home team averages
games_metrics_df = games_metrics_df.merge(
    teams_xg_xga_df[['Team', 'Average Home xG Last 5', 'Average Home xGA Last 5']],
    left_on='Home Team',
    right_on='Team',
    how='left'
).drop(columns=['Team'])  # Dropping the redundant 'Team' column after merge

# Merge away team averages
games_metrics_df = games_metrics_df.merge(
    teams_xg_xga_df[['Team', 'Average Away xG Last 5', 'Average Away xGA Last 5']],
    left_on='Away Team',
    right_on='Team',
    how='left',
    suffixes=('_home', '_away')
).drop(columns=['Team'])  # Dropping the redundant 'Team' column after merge

# %%
import pandas as pd

# Assuming 'teams_per_match_averages', 'games_list_df', and 'teams_xg_xga_df' are already defined

# Retrieve season-long averages
season_avg_home_xg = teams_per_match_averages['per_match_home_xg'].mean()
season_avg_away_xg = teams_per_match_averages['per_match_away_xg'].mean()
season_avg_home_xga = teams_per_match_averages['per_match_home_xga'].mean()
season_avg_away_xga = teams_per_match_averages['per_match_away_xga'].mean()

# Initialize an empty list for storing game metrics along with the matchup information
games_metrics_list = []

# Loop through each game to calculate metrics using 'teams_per_match_averages'
for index, row in games_list_df.iterrows():
    home_team, away_team = row['game_matchup'].split(' vs. ')
    
    # Retrieve team stats from 'teams_per_match_averages'
    home_team_stats = teams_per_match_averages.loc[home_team]
    away_team_stats = teams_per_match_averages.loc[away_team]
    
    # Retrieve recent form from 'teams_xg_xga_df'
    home_recent_xg = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == home_team, 'Average Home xG Last 5'].values[0]
    away_recent_xg = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == away_team, 'Average Away xG Last 5'].values[0]
    home_recent_xga = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == home_team, 'Average Home xGA Last 5'].values[0]
    away_recent_xga = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == away_team, 'Average Away xGA Last 5'].values[0]
    
    # Compare recent form to season-long averages to get adjustment factors
    home_attack_factor = home_recent_xg / home_team_stats['per_match_home_xg'] if home_team_stats['per_match_home_xg'] != 0 else 1
    away_defence_factor = away_recent_xga / away_team_stats['per_match_away_xga'] if away_team_stats['per_match_away_xga'] != 0 else 1
    away_attack_factor = away_recent_xg / away_team_stats['per_match_away_xg'] if away_team_stats['per_match_away_xg'] != 0 else 1
    home_defence_factor = home_recent_xga / home_team_stats['per_match_home_xga'] if home_team_stats['per_match_home_xga'] != 0 else 1
    
    # Adjust metrics using the factors
    home_attack_adjusted = home_team_stats['per_match_home_xg'] * home_attack_factor / season_avg_home_xg
    away_defence_adjusted = away_team_stats['per_match_away_xga'] * away_defence_factor / season_avg_away_xga
    away_attack_adjusted = away_team_stats['per_match_away_xg'] * away_attack_factor / season_avg_away_xg
    home_defence_adjusted = home_team_stats['per_match_home_xga'] * home_defence_factor / season_avg_home_xga
    
    # Append the adjusted metrics for this game to the list
    games_metrics_list.append({
        'Game Matchup': row['game_matchup'],
        'Home Attack': home_attack_adjusted,
        'Away Defence': away_defence_adjusted,
        'Away Attack': away_attack_adjusted,
        'Home Defence': home_defence_adjusted
    })

# Create the DataFrame from the list
games_metrics_df = pd.DataFrame(games_metrics_list)

# Split 'Game Matchup' into 'Home Team' and 'Away Team'
games_metrics_df[['Home Team', 'Away Team']] = games_metrics_df['Game Matchup'].str.split(' vs. ', expand=True)

games_metrics_df
# Out:
#                         Game Matchup  Home Attack  Away Defence  Away Attack  \
# 0                     Lille vs. Lens     1.696706      1.112808     1.306098
# 1                     Lyon vs. Reims     0.953424      0.941495     1.384498
# 2                    Metz vs. Monaco     0.700795      1.242988     1.338260
# 3         Clermont Foot vs. Toulouse     0.649097      1.041160     0.974027
# 4           Le Havre vs. Montpellier     0.930523      1.421124     0.766934
# 5                  Lorient vs. Brest     0.720676      0.646696     1.042779
# 6  Marseille vs. Paris Saint Germain     1.487491      1.484387     1.523507
# 7                    Nice vs. Nantes     1.271493      0.825979     0.518908
# 8              Strasbourg vs. Rennes     0.663342      0.895978     1.131888
#
#    Home Defence      Home Team            Away Team
# 0      0.616990          Lille                 Lens
# 1      1.009631           Lyon                Reims
# 2      0.799902           Metz               Monaco
# 3      1.479752  Clermont Foot             Toulouse
# 4      1.139577       Le Havre          Montpellier
# 5      1.126055        Lorient                Brest
# 6      0.679534      Marseille  Paris Saint Germain
# 7      1.103086           Nice               Nantes
# 8      1.288762     Strasbourg               Rennes

# %%
# Initialize an empty list for storing projected goals data
projected_goals_list = []

# Retrieve the league-wide average per match home and away xG
league_avg_per_match_home_xg = teams_per_match_averages.loc['Average', 'per_match_home_xg']
league_avg_per_match_away_xg = teams_per_match_averages.loc['Average', 'per_match_away_xg']

# Iterate over each row in the games_metrics_df to calculate projected goals
for index, row in games_metrics_df.iterrows():
    # Extract home and away team names from the game matchup
    home_team, away_team = row['Game Matchup'].split(' vs. ')

    # Calculate metrics using the teams' attack and defence strengths
    home_attack = row['Home Attack']
    away_defence = row['Away Defence']
    away_attack = row['Away Attack']
    home_defence = row['Home Defence']

    # Calculate projected home and away goals using the league-wide average per game xG
    projected_home_goals = home_attack * away_defence * league_avg_per_match_home_xg
    projected_away_goals = away_attack * home_defence * league_avg_per_match_away_xg

    # Calculate total projected goals
    total_projected_goals = projected_home_goals + projected_away_goals

    # Append the results to the list
    projected_goals_list.append({
        'Game Matchup': row['Game Matchup'],
        'Projected Home Goals': projected_home_goals,
        'Projected Away Goals': projected_away_goals,
        'Total Projected Goals': total_projected_goals
    })

# Convert the list to a DataFrame
projected_goals_df = pd.DataFrame(projected_goals_list)

# Display the DataFrame
projected_goals_df
# Out:
#                         Game Matchup  Projected Home Goals  \
# 0                     Lille vs. Lens              3.141489
# 1                     Lyon vs. Reims              1.493526
# 2                    Metz vs. Monaco              1.449328
# 3         Clermont Foot vs. Toulouse              1.124438
# 4           Le Havre vs. Montpellier              2.200227
# 5                  Lorient vs. Brest              0.775440
# 6  Marseille vs. Paris Saint Germain              3.673755
# 7                    Nice vs. Nantes              1.747396
# 8              Strasbourg vs. Rennes              0.988880
#
#    Projected Away Goals  Total Projected Goals
# 0              1.007051               4.148540
# 1              1.746837               3.240363
# 2              1.337749               2.787077
# 3              1.801181               2.925619
# 4              1.092193               3.292420
# 5              1.467402               2.242842
# 6              1.293757               4.967512
# 7              0.715315               2.462711
# 8              1.822945               2.811825

# %%
import numpy as np

# Number of simulations to run for each game
n_simulations = 10000

# Initialize lists to store the win/draw probabilities
home_win_probs = []
away_win_probs = []
draw_probs = []

for index, row in projected_goals_df.iterrows():
    home_goals_proj = row['Projected Home Goals']
    away_goals_proj = row['Projected Away Goals']

    # Simulate match outcomes
    home_goals_sim = np.random.poisson(home_goals_proj, n_simulations)
    away_goals_sim = np.random.poisson(away_goals_proj, n_simulations)

    # Calculate outcomes
    home_wins = np.sum(home_goals_sim > away_goals_sim)
    away_wins = np.sum(away_goals_sim > home_goals_sim)
    draws = np.sum(home_goals_sim == away_goals_sim)

    # Calculate probabilities
    home_win_prob = home_wins / n_simulations
    away_win_prob = away_wins / n_simulations
    draw_prob = draws / n_simulations

    # Append probabilities to lists
    home_win_probs.append(home_win_prob)
    away_win_probs.append(away_win_prob)
    draw_probs.append(draw_prob)

# Add the calculated probabilities to the projected_goals_df DataFrame
projected_goals_df['Home Win Probability'] = home_win_probs
projected_goals_df['Away Win Probability'] = away_win_probs
projected_goals_df['Draw Probability'] = draw_probs

# Convert probabilities to percentage format and append '%' sign
projected_goals_df['Home Win Probability'] = (projected_goals_df['Home Win Probability'] * 100).apply(lambda x: f'{x:.2f}%')
projected_goals_df['Away Win Probability'] = (projected_goals_df['Away Win Probability'] * 100).apply(lambda x: f'{x:.2f}%')
projected_goals_df['Draw Probability'] = (projected_goals_df['Draw Probability'] * 100).apply(lambda x: f'{x:.2f}%')

# Display the updated DataFrame with formatted probabilities
projected_goals_df
# Out:
#                         Game Matchup  Projected Home Goals  \
# 0                     Lille vs. Lens              3.141489
# 1                     Lyon vs. Reims              1.493526
# 2                    Metz vs. Monaco              1.449328
# 3         Clermont Foot vs. Toulouse              1.124438
# 4           Le Havre vs. Montpellier              2.200227
# 5                  Lorient vs. Brest              0.775440
# 6  Marseille vs. Paris Saint Germain              3.673755
# 7                    Nice vs. Nantes              1.747396
# 8              Strasbourg vs. Rennes              0.988880
#
#    Projected Away Goals  Total Projected Goals Home Win Probability  \
# 0              1.007051               4.148540               79.05%
# 1              1.746837               3.240363               33.13%
# 2              1.337749               2.787077               39.91%
# 3              1.801181               2.925619               23.04%
# 4              1.092193               3.292420               62.31%
# 5              1.467402               2.242842               20.02%
# 6              1.293757               4.967512               80.08%
# 7              0.715315               2.462711               61.89%
# 8              1.822945               2.811825               20.67%
#
#   Away Win Probability Draw Probability
# 0                8.75%           12.20%
# 1               44.28%           22.59%
# 2               34.99%           25.10%
# 3               53.79%           23.17%
# 4               17.80%           19.89%
# 5               52.71%           27.27%
# 6                9.04%           10.88%
# 7               14.75%           23.36%
# 8               55.53%           23.80%

# %%
import requests


# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
API_KEY = '6ea2753ab77393e63fe86bb67324fc40'

SPORT = 'soccer' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h,spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# %%
import requests

# Your API key for the odds API
api_key = '6ea2753ab77393e63fe86bb67324fc40'

# Define the endpoint URL
url = 'https://api.the-odds-api.com/v4/sports/soccer_france_ligue_one/odds/'

# Parameters for the API request
params = {
    'apiKey': api_key,
    'regions': 'us',  # Adjust if targeting a different region
    'markets': 'h2h',  # Head-to-head odds; adjust if looking for different market types
    'bookmakers': 'bovada',
    'oddsFormat': 'decimal'
}

# Make the GET request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Convert the response to JSON
    odds_data = response.json()
    # Process your data here
    print(odds_data)
else:
    print(f"Error fetching data: {response.status_code}")
# Out:
# [{'id': 'f52b50f0b2bd05369529954766c0fddb', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-03-29T20:00:00Z', 'home_team': 'Lille', 'away_team': 'RC Lens', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:07:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:07:01Z', 'outcomes': [{'name': 'Lille', 'price': 2.1}, {'name': 'RC Lens', 'price': 3.5}, {'name': 'Draw', 'price': 3.55}]}]}]}, {'id': '0f7c41bf84ba09760bd982846d880661', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-03-30T16:00:00Z', 'home_team': 'Metz', 'away_team': 'AS Monaco', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:07:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:07:01Z', 'outcomes': [{'name': 'AS Monaco', 'price': 1.62}, {'name': 'Metz', 'price': 5.0}, {'name': 'Draw', 'price': 4.2}]}]}]}, {'id': '74d30895af722c4a2b352ba1cbb253a2', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-03-30T20:00:00Z', 'home_team': 'Lyon', 'away_team': 'Stade de Reims', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:07:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:07:01Z', 'outcomes': [{'name': 'Lyon', 'price': 2.1}, {'name': 'Stade de Reims', 'price': 3.25}, {'name': 'Draw', 'price': 3.7}]}]}]}, {'id': 'd9ec4cc317a2b14d3d5d46015c1c6b5c', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-03-31T11:00:00Z', 'home_team': 'Lorient', 'away_team': 'Brest', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:07:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:07:01Z', 'outcomes': [{'name': 'Brest', 'price': 2.0}, {'name': 'Lorient', 'price': 3.9}, {'name': 'Draw', 'price': 3.45}]}]}]}, {'id': '9752475e211aa045ed830b3947574bc6', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-03-31T13:00:00Z', 'home_team': 'Clermont', 'away_team': 'Toulouse', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:07:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:07:01Z', 'outcomes': [{'name': 'Clermont', 'price': 3.05}, {'name': 'Toulouse', 'price': 2.3}, {'name': 'Draw', 'price': 3.45}]}]}]}, {'id': '154154a5a06a0799623705d8d87b8699', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-03-31T13:00:00Z', 'home_team': 'Le Havre', 'away_team': 'Montpellier', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:07:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:07:01Z', 'outcomes': [{'name': 'Le Havre', 'price': 2.65}, {'name': 'Montpellier', 'price': 2.7}, {'name': 'Draw', 'price': 3.35}]}]}]}, {'id': 'b58b3733de3a0b7467e7c719f781844d', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-03-31T13:00:00Z', 'home_team': 'Nice', 'away_team': 'Nantes', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:07:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:07:01Z', 'outcomes': [{'name': 'Nantes', 'price': 5.2}, {'name': 'Nice', 'price': 1.71}, {'name': 'Draw', 'price': 3.7}]}]}]}, {'id': 'c0d6bed113eb13b15d404200bd11e265', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-03-31T15:05:00Z', 'home_team': 'Strasbourg', 'away_team': 'Rennes', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:07:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:07:01Z', 'outcomes': [{'name': 'Rennes', 'price': 2.25}, {'name': 'Strasbourg', 'price': 3.1}, {'name': 'Draw', 'price': 3.5}]}]}]}, {'id': '9fcc79d04ee0b37ef82b84d4d2438755', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Li ...

# %%
# Initialize an empty list to hold the simplified odds data
simplified_odds_list = []

# Iterate over the odds data
for event in odds_data:
    # Extract the essential information
    event_name = event.get('sport_title', 'No sport title')
    home_team = event.get('home_team', 'No home team')
    away_team = event.get('away_team', 'No away team')
    start_time = event.get('commence_time', 'No start time')
    
    # Initialize default odds
    home_team_odds = 'N/A'
    away_team_odds = 'N/A'
    draw_odds = 'N/A'  # Initialize draw odds

    # If there are bookmakers data available
    if event.get('bookmakers'):
        # Look for the Bovada bookmaker in the list
        for bookmaker in event['bookmakers']:
            if bookmaker['key'].lower() == 'bovada':  # Ensure case-insensitive matching
                # Assuming 'markets' is a list and we're interested in the first item (h2h)
                markets = bookmaker.get('markets', [])
                if markets:
                    # Assuming the structure of 'outcomes' in the first market
                    outcomes = markets[0].get('outcomes', [])
                    for outcome in outcomes:
                        # Assign odds based on the team or if it's a draw
                        if outcome['name'] == home_team:
                            home_team_odds = outcome.get('price', 'N/A')
                        elif outcome['name'] == away_team:
                            away_team_odds = outcome.get('price', 'N/A')
                        elif outcome['name'].lower() == 'draw':  # Checking for a draw
                            draw_odds = outcome.get('price', 'N/A')
                
                # Once we've found Bovada and extracted the odds, no need to check other bookmakers
                break

    # Create a simplified representation of the event including draw odds
    simplified_event = f"{event_name}: {home_team} vs. {away_team}, Date: {start_time}, Home Odds: {home_team_odds}, Away Odds: {away_team_odds}, Draw Odds: {draw_odds}"
    
    # Add to the list
    simplified_odds_list.append(simplified_event)

# Now, 'simplified_odds_list' contains a more readable version of the odds data, including draw odds
for item in simplified_odds_list:
    print(item)
# Out:
# Ligue 1 - France: Lille vs. RC Lens, Date: 2024-03-29T20:00:00Z, Home Odds: 2.1, Away Odds: 3.5, Draw Odds: 3.55
# Ligue 1 - France: Metz vs. AS Monaco, Date: 2024-03-30T16:00:00Z, Home Odds: 5.0, Away Odds: 1.62, Draw Odds: 4.2
# Ligue 1 - France: Lyon vs. Stade de Reims, Date: 2024-03-30T20:00:00Z, Home Odds: 2.1, Away Odds: 3.25, Draw Odds: 3.7
# Ligue 1 - France: Lorient vs. Brest, Date: 2024-03-31T11:00:00Z, Home Odds: 3.9, Away Odds: 2.0, Draw Odds: 3.45
# Ligue 1 - France: Clermont vs. Toulouse, Date: 2024-03-31T13:00:00Z, Home Odds: 3.05, Away Odds: 2.3, Draw Odds: 3.45
# Ligue 1 - France: Le Havre vs. Montpellier, Date: 2024-03-31T13:00:00Z, Home Odds: 2.65, Away Odds: 2.7, Draw Odds: 3.35
# Ligue 1 - France: Nice vs. Nantes, Date: 2024-03-31T13:00:00Z, Home Odds: 1.71, Away Odds: 5.2, Draw Odds: 3.7
# Ligue 1 - France: Strasbourg vs. Rennes, Date: 2024-03-31T15:05:00Z, Home Odds: 3.1, Away Odds: 2.25, Draw Odds: 3.5
# Ligue 1 - France: Marseille vs. Paris Saint Germain, Date: 2024-03-31T18:45:00Z, Home Odds: 3.1, Away Odds: 2.15, Draw Odds: 3.8
# Ligue 1 - France: Lille vs. Marseille, Date: 2024-04-05T19:00:00Z, Home Odds: 2.3, Away Odds: 3.1, Draw Odds: 3.45
# Ligue 1 - France: RC Lens vs. Le Havre, Date: 2024-04-06T15:00:00Z, Home Odds: 1.56, Away Odds: 6.0, Draw Odds: 4.2
# Ligue 1 - France: Paris Saint Germain vs. Clermont, Date: 2024-04-06T19:00:00Z, Home Odds: 1.15, Away Odds: 16.0, Draw Odds: 8.5
# Ligue 1 - France: Brest vs. Metz, Date: 2024-04-07T11:00:00Z, Home Odds: 1.54, Away Odds: 6.5, Draw Odds: 4.0
# Ligue 1 - France: Montpellier vs. Lorient, Date: 2024-04-07T13:00:00Z, Home Odds: 1.67, Away Odds: 4.9, Draw Odds: 4.1
# Ligue 1 - France: Stade de Reims vs. Nice, Date: 2024-04-07T13:00:00Z, Home Odds: 2.5, Away Odds: 2.85, Draw Odds: 3.3
# Ligue 1 - France: Toulouse vs. Strasbourg, Date: 2024-04-07T13:00:00Z, Home Odds: 2.1, Away Odds: 3.4, Draw Odds: 3.65
# Ligue 1 - France: AS Monaco vs. Rennes, Date: 2024-04-07T15:00:00Z, Home Odds: 1.91, Away Odds: 3.8, Draw Odds: 3.85
# Ligue 1 - France: Paris Saint Germain vs. Clermont, Date: 2024-04-07T15:00:00Z, Home Odds: N/A, Away Odds: N/A, Draw Odds: N/A
# Ligue 1 - France: RC Lens vs. Le Havre, Date: 2024-04-07T15:00:00Z, Home Odds: N/A, Away Odds: N/A, Draw Odds: N/A
# Ligue 1 - France: Lille vs. Marseille, Date: 2024-04-07T15:00:00Z, Home Odds: N/A, Away Odds: N/A, Draw Odds: N/A
# Ligue 1 - France: Nantes vs. Lyon, Date: 2024-04-07T15:00:00Z, Home Odds: 3.15, Away Odds: 2.3, Draw Odds: 3.4

# %%
odds_data_list = []

for event in odds_data:
    home_team = event.get('home_team')
    away_team = event.get('away_team')
    start_time = event.get('commence_time')  # Assuming datetime format or additional parsing might be needed
    
    # Initialize odds
    home_odds = 'N/A'
    away_odds = 'N/A'
    draw_odds = 'N/A'  # Initialize draw odds variable

    # Iterate through bookmakers to find Bovada and extract the odds
    for bookmaker in event.get('bookmakers', []):
        if bookmaker['key'].lower() == 'bovada':  # Ensure case-insensitive matching
            markets = bookmaker.get('markets', [])
            if markets:
                outcomes = markets[0].get('outcomes', [])
                for outcome in outcomes:
                    # Check and assign odds based on the team or if it's a draw
                    if outcome['name'] == home_team:
                        home_odds = outcome.get('price', 'N/A')
                    elif outcome['name'] == away_team:
                        away_odds = outcome.get('price', 'N/A')
                    elif outcome['name'].lower() == 'draw':  # Check for draw odds
                        draw_odds = outcome.get('price', 'N/A')

    # Append the data including draw odds to the list
    odds_data_list.append({
        'Game Matchup': f"{home_team} vs. {away_team}",
        'Home Odds': home_odds,
        'Away Odds': away_odds,
        'Draw Odds': draw_odds,  # Include draw odds
        'Start Time': start_time
    })

# Convert the list to a DataFrame
odds_df = pd.DataFrame(odds_data_list)

# %%
name_replacements = {
    'RC Lens': 'Lens',
    'AS Monaco': 'Monaco',
    'SC Freiburg': 'Freiburg',
    'Stade de Reims': 'Reims',
    'Clermont': 'Clermont Foot'
}
import pandas as pd

# Assuming odds_df is already defined

# Apply replacements in the 'Game Matchup' column
for original_name, new_name in name_replacements.items():
    odds_df['Game Matchup'] = odds_df['Game Matchup'].str.replace(original_name, new_name, regex=False)

# Display the updated DataFrame
print(odds_df)
# Out:
#                              Game Matchup Home Odds Away Odds Draw Odds  \
# 0                          Lille vs. Lens       2.1       3.5      3.55
# 1                         Metz vs. Monaco       5.0      1.62       4.2
# 2                          Lyon vs. Reims       2.1      3.25       3.7
# 3                       Lorient vs. Brest       3.9       2.0      3.45
# 4              Clermont Foot vs. Toulouse      3.05       2.3      3.45
# 5                Le Havre vs. Montpellier      2.65       2.7      3.35
# 6                         Nice vs. Nantes      1.71       5.2       3.7
# 7                   Strasbourg vs. Rennes       3.1      2.25       3.5
# 8       Marseille vs. Paris Saint Germain       3.1      2.15       3.8
# 9                     Lille vs. Marseille       2.3       3.1      3.45
# 10                      Lens vs. Le Havre      1.56       6.0       4.2
# 11  Paris Saint Germain vs. Clermont Foot      1.15      16.0       8.5
# 12                         Brest vs. Metz      1.54       6.5       4.0
# 13                Montpellier vs. Lorient      1.67       4.9       4.1
# 14                         Reims vs. Nice       2.5      2.85       3.3
# 15                Toulouse vs. Strasbourg       2.1       3.4      3.65
# 16                      Monaco vs. Rennes      1.91       3.8      3.85
# 17  Paris Saint Germain vs. Clermont Foot       N/A       N/A       N/A
# 18                      Lens vs. Le Havre       N/A       N/A       N/A
# 19                    Lille vs. Marseille       N/A       N/A       N/A
# 20                        Nantes vs. Lyon      3.15       2.3       3.4
#
#               Start Time
# 0   2024-03-29T20:00:00Z
# 1   2024-03-30T16:00:00Z
# 2   2024-03-30T20:00:00Z
# 3   2024-03-31T11:00:00Z
# 4   2024-03-31T13:00:00Z
# 5   2024-03-31T13:00:00Z
# 6   2024-03-31T13:00:00Z
# 7   2024-03-31T15:05:00Z
# 8   2024-03-31T18:45:00Z
# 9   2024-04-05T19:00:00Z
# 10  2024-04-06T15:00:00Z
# 11  2024-04-06T19:00:00Z
# 12  2024-04-07T11:00:00Z
# 13  2024-04-07T13:00:00Z
# 14  2024-04-07T13:00:00Z
# 15  2024-04-07T13:00:00Z
# 16  2024-04-07T15:00:00Z
# 17  2024-04-07T15:00:00Z
# 18  2024-04-07T15:00:00Z
# 19  2024-04-07T15:00:00Z
# 20  2024-04-07T15:00:00Z

# %%
# Assuming 'projected_goals_df' exists and has a 'Game Matchup' column
merged_df = pd.merge(projected_goals_df, odds_df, on='Game Matchup', how='left')

# Now 'merged_df' contains both the projected probabilities and the odds

# %%
merged_df
# Out:
#                         Game Matchup  Projected Home Goals  \
# 0                     Lille vs. Lens              3.141489
# 1                     Lyon vs. Reims              1.493526
# 2                    Metz vs. Monaco              1.449328
# 3         Clermont Foot vs. Toulouse              1.124438
# 4           Le Havre vs. Montpellier              2.200227
# 5                  Lorient vs. Brest              0.775440
# 6  Marseille vs. Paris Saint Germain              3.673755
# 7                    Nice vs. Nantes              1.747396
# 8              Strasbourg vs. Rennes              0.988880
#
#    Projected Away Goals  Total Projected Goals Home Win Probability  \
# 0              1.007051               4.148540               79.05%
# 1              1.746837               3.240363               33.13%
# 2              1.337749               2.787077               39.91%
# 3              1.801181               2.925619               23.04%
# 4              1.092193               3.292420               62.31%
# 5              1.467402               2.242842               20.02%
# 6              1.293757               4.967512               80.08%
# 7              0.715315               2.462711               61.89%
# 8              1.822945               2.811825               20.67%
#
#   Away Win Probability Draw Probability Home Odds Away Odds Draw Odds  \
# 0                8.75%           12.20%       2.1       3.5      3.55
# 1               44.28%           22.59%       2.1      3.25       3.7
# 2               34.99%           25.10%       5.0      1.62       4.2
# 3               53.79%           23.17%      3.05       2.3      3.45
# 4               17.80%           19.89%      2.65       2.7      3.35
# 5               52.71%           27.27%       3.9       2.0      3.45
# 6                9.04%           10.88%       3.1      2.15       3.8
# 7               14.75%           23.36%      1.71       5.2       3.7
# 8               55.53%           23.80%       3.1      2.25       3.5
#
#              Start Time
# 0  2024-03-29T20:00:00Z
# 1  2024-03-30T20:00:00Z
# 2  2024-03-30T16:00:00Z
# 3  2024-03-31T13:00:00Z
# 4  2024-03-31T13:00:00Z
# 5  2024-03-31T11:00:00Z
# 6  2024-03-31T18:45:00Z
# 7  2024-03-31T13:00:00Z
# 8  2024-03-31T15:05:00Z

# %%
# Convert percentage strings to decimal probabilities
merged_df['Home Win Probability'] = merged_df['Home Win Probability'].str.rstrip('%').astype(float) / 100
merged_df['Away Win Probability'] = merged_df['Away Win Probability'].str.rstrip('%').astype(float) / 100
merged_df['Draw Probability'] = merged_df['Draw Probability'].str.rstrip('%').astype(float) / 100
# Calculate implied odds
merged_df['Implied Home Odds'] = 1 / merged_df['Home Win Probability']
merged_df['Implied Away Odds'] = 1 / merged_df['Away Win Probability']
merged_df['Implied Draw Odds'] = 1 / merged_df['Draw Probability']
# Create a new DataFrame with implied odds
implied_odds_df = merged_df[['Game Matchup', 'Implied Home Odds', 'Implied Away Odds', 'Implied Draw Odds', 'Home Odds', 'Away Odds', 'Draw Odds']].copy()

# %%
implied_odds_df.dtypes
# Out:
# Game Matchup          object
# Implied Home Odds    float64
# Implied Away Odds    float64
# Implied Draw Odds    float64
# Home Odds             object
# Away Odds             object
# Draw Odds             object
# dtype: object

# %%
import pandas as pd

# Assuming implied_odds_df is already defined

# Convert object columns to numeric
cols_to_convert = ['Home Odds', 'Away Odds', 'Draw Odds']
implied_odds_df[cols_to_convert] = implied_odds_df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# Round implied odds to 2 decimal places
implied_odds_df['Implied Home Odds'] = round(implied_odds_df['Implied Home Odds'], 2)
implied_odds_df['Implied Away Odds'] = round(implied_odds_df['Implied Away Odds'], 2)
implied_odds_df['Implied Draw Odds'] = round(implied_odds_df['Implied Draw Odds'], 2)

# Calculate edge for home win
implied_odds_df['Home Win Edge'] = round((1 / implied_odds_df['Implied Home Odds']) * implied_odds_df['Home Odds'] - 1, 2)

# Calculate edge for away win
implied_odds_df['Away Win Edge'] = round((1 / implied_odds_df['Implied Away Odds']) * implied_odds_df['Away Odds'] - 1, 2)

# Calculate edge for draw
implied_odds_df['Draw Edge'] = round((1 / implied_odds_df['Implied Draw Odds']) * implied_odds_df['Draw Odds'] - 1, 2)

# Round edges to 2 decimal places
implied_odds_df['Home Win Edge'] = round(implied_odds_df['Home Win Edge'], 2)
implied_odds_df['Away Win Edge'] = round(implied_odds_df['Away Win Edge'], 2)
implied_odds_df['Draw Edge'] = round(implied_odds_df['Draw Edge'], 2)

print(implied_odds_df)
# Out:
#                         Game Matchup  Implied Home Odds  Implied Away Odds  \
# 0                     Lille vs. Lens               1.27              11.43
# 1                     Lyon vs. Reims               3.02               2.26
# 2                    Metz vs. Monaco               2.51               2.86
# 3         Clermont Foot vs. Toulouse               4.34               1.86
# 4           Le Havre vs. Montpellier               1.60               5.62
# 5                  Lorient vs. Brest               5.00               1.90
# 6  Marseille vs. Paris Saint Germain               1.25              11.06
# 7                    Nice vs. Nantes               1.62               6.78
# 8              Strasbourg vs. Rennes               4.84               1.80
#
#    Implied Draw Odds  Home Odds  Away Odds  Draw Odds  Home Win Edge  \
# 0               8.20       2.10       3.50       3.55           0.65
# 1               4.43       2.10       3.25       3.70          -0.30
# 2               3.98       5.00       1.62       4.20           0.99
# 3               4.32       3.05       2.30       3.45          -0.30
# 4               5.03       2.65       2.70       3.35           0.66
# 5               3.67       3.90       2.00       3.45          -0.22
# 6               9.19       3.10       2.15       3.80           1.48
# 7               4.28       1.71       5.20       3.70           0.06
# 8               4.20       3.10       2.25       3.50          -0.36
#
#    Away Win Edge  Draw Edge
# 0          -0.69      -0.57
# 1           0.44      -0.16
# 2          -0.43       0.06
# 3           0.24      -0.20
# 4          -0.52      -0.33
# 5           0.05      -0.06
# 6          -0.81      -0.59
# 7          -0.23      -0.14
# 8           0.25      -0.17

# %%
# Assuming 'projected_goals_df' is the DataFrame containing projected goals

# Merge the implied odds DataFrame with the projected goals DataFrame on the 'Game Matchup' column
implied_odds_with_goals = implied_odds_df.merge(projected_goals_df, on='Game Matchup', how='left')

# Display the DataFrame with projected goals added
implied_odds_with_goals
# Out:
#                         Game Matchup  Implied Home Odds  Implied Away Odds  \
# 0                     Lille vs. Lens               1.27              11.43
# 1                     Lyon vs. Reims               3.02               2.26
# 2                    Metz vs. Monaco               2.51               2.86
# 3         Clermont Foot vs. Toulouse               4.34               1.86
# 4           Le Havre vs. Montpellier               1.60               5.62
# 5                  Lorient vs. Brest               5.00               1.90
# 6  Marseille vs. Paris Saint Germain               1.25              11.06
# 7                    Nice vs. Nantes               1.62               6.78
# 8              Strasbourg vs. Rennes               4.84               1.80
#
#    Implied Draw Odds  Home Odds  Away Odds  Draw Odds  Home Win Edge  \
# 0               8.20       2.10       3.50       3.55           0.65
# 1               4.43       2.10       3.25       3.70          -0.30
# 2               3.98       5.00       1.62       4.20           0.99
# 3               4.32       3.05       2.30       3.45          -0.30
# 4               5.03       2.65       2.70       3.35           0.66
# 5               3.67       3.90       2.00       3.45          -0.22
# 6               9.19       3.10       2.15       3.80           1.48
# 7               4.28       1.71       5.20       3.70           0.06
# 8               4.20       3.10       2.25       3.50          -0.36
#
#    Away Win Edge  Draw Edge  Projected Home Goals  Projected Away Goals  \
# 0          -0.69      -0.57              3.141489              1.007051
# 1           0.44      -0.16              1.493526              1.746837
# 2          -0.43       0.06              1.449328              1.337749
# 3           0.24      -0.20              1.124438              1.801181
# 4          -0.52      -0.33              2.200227              1.092193
# 5           0.05      -0.06              0.775440              1.467402
# 6          -0.81      -0.59              3.673755              1.293757
# 7          -0.23      -0.14              1.747396              0.715315
# 8           0.25      -0.17              0.988880              1.822945
#
#    Total Projected Goals Home Win Probability Away Win Probability  \
# 0               4.148540               79.05%                8.75%
# 1               3.240363               33.13%               44.28%
# 2               2.787077               39.91%               34.99%
# 3               2.925619               23.04%               53.79%
# 4               3.292420               62.31%               17.80%
# 5               2.242842               20.02%               52.71%
# 6               4.967512               80.08%                9.04%
# 7               2.462711               61.89%               14.75%
# 8               2.811825               20.67%               55.53%
#
#   Draw Probability
# 0           12.20%
# 1           22.59%
# 2           25.10%
# 3           23.17%
# 4           19.89%
# 5           27.27%
# 6           10.88%
# 7           23.36%
# 8           23.80%

# %%
# Save the DataFrame to a CSV file
implied_odds_with_goals.to_csv('Ligue_une_odds_3-29.csv', index=False)

# %%
# Define a function to color code values based on conditions
def color_edges(val):
    if val < 0:
        return 'background-color: maroon'
    elif 0.0 <= val < 0.1:
        return 'background-color: yellow'
    else:
        return 'background-color: green'

# Apply the styling to the specified columns
styled_df = implied_odds_with_goals.style.applymap(color_edges, subset=['Home Win Edge', 'Away Win Edge', 'Draw Edge'])

# Display the styled DataFrame
styled_df
# Out:
# C:\Users\jbuck\AppData\Local\Temp\ipykernel_24956\2992074314.py:11: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = implied_odds_with_goals.style.applymap(color_edges, subset=['Home Win Edge', 'Away Win Edge', 'Draw Edge'])
# <style type="text/css">
# #T_e0d35_row0_col7, #T_e0d35_row1_col8, #T_e0d35_row2_col7, #T_e0d35_row3_col8, #T_e0d35_row4_col7, #T_e0d35_row6_col7, #T_e0d35_row8_col8 {
#   background-color: green;
# }
# #T_e0d35_row0_col8, #T_e0d35_row0_col9, #T_e0d35_row1_col7, #T_e0d35_row1_col9, #T_e0d35_row2_col8, #T_e0d35_row3_col7, #T_e0d35_row3_col9, #T_e0d35_row4_col8, #T_e0d35_row4_col9, #T_e0d35_row5_col7, #T_e0d35_row5_col9, #T_e0d35_row6_col8, #T_e0d35_row6_col9, #T_e0d35_row7_col8, #T_e0d35_row7_col9, #T_e0d35_row8_col7, #T_e0d35_row8_col9 {
#   background-color: maroon;
# }
# #T_e0d35_row2_col9, #T_e0d35_row5_col8, #T_e0d35_row7_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_e0d35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0d35_level0_col0" class="col_heading level0 col0" >Game Matchup</th>
#       <th id="T_e0d35_level0_col1" class="col_heading level0 col1" >Implied Home Odds</th>
#       <th id="T_e0d35_level0_col2" class="col_heading level0 col2" >Implied Away Odds</th>
#       <th id="T_e0d35_level0_col3" class="col_heading level0 col3" >Implied Draw Odds</th>
#       <th id="T_e0d35_level0_col4" class="col_heading level0 col4" >Home Odds</th>
#       <th id="T_e0d35_level0_col5" class="col_heading level0 col5" >Away Odds</th>
#       <th id="T_e0d35_level0_col6" class="col_heading level0 col6" >Draw Odds</th>
#       <th id="T_e0d35_level0_col7" class="col_heading level0 col7" >Home Win Edge</th>
#       <th id="T_e0d35_level0_col8" class="col_heading level0 col8" >Away Win Edge</th>
#       <th id="T_e0d35_level0_col9" class="col_heading level0 col9" >Draw Edge</th>
#       <th id="T_e0d35_level0_col10" class="col_heading level0 col10" >Projected Home Goals</th>
#       <th id="T_e0d35_level0_col11" class="col_heading level0 col11" >Projected Away Goals</th>
#       <th id="T_e0d35_level0_col12" class="col_heading level0 col12" >Total Projected Goals</th>
#       <th id="T_e0d35_level0_col13" class="col_heading level0 col13" >Home Win Probability</th>
#       <th id="T_e0d35_level0_col14" class="col_heading level0 col14" >Away Win Probability</th>
#       <th id="T_e0d35_level0_col15" class="col_heading level0 col15" >Draw Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0d35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0d35_row0_col0" class="data row0 col0" >Lille vs. Lens</td>
#       <td id="T_e0d35_row0_col1" class="data row0 col1" >1.270000</td>
#       <td id="T_e0d35_row0_col2" class="data row0 col2" >11.430000</td>
#       <td id="T_e0d35_row0_col3" class="data row0 col3" >8.200000</td>
#       <td id="T_e0d35_row0_col4" class="data row0 col4" >2.100000</td>
#       <td id="T_e0d35_row0_col5" class="data row0 col5" >3.500000</td>
#       <td id="T_e0d35_row0_col6" class="data row0 col6" >3.550000</td>
#       <td id="T_e0d35_row0_col7" class="data row0 col7" >0.650000</td>
#       <td id="T_e0d35_row0_col8" class="data row0 col8" >-0.690000</td>
#       <td id="T_e0d35_row0_col9" class="data row0 col9" >-0.570000</td>
#       <td id="T_e0d35_row0_col10" class="data row0 col10" >3.141489</td>
#       <td id="T_e0d35_row0_col11" class="data row0 col11" >1.007051</td>
#       <td id="T_e0d35_row0_col12" class="data row0 col12" >4.148540</td>
#       <td id="T_e0d35_row0_col13" class="data row0 col13" >79.05%</td>
#       <td id="T_e0d35_row0_col14" class="data row0 col14" >8.75%</td>
#       <td id="T_e0d35_row0_col15" class="data row0 col15" >12.20%</td>
#     </tr>
#     <tr>
#       <th id="T_e0d35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0d35_row1_col0" class="data row1 col0" >Lyon vs. Reims</td>
#       <td id="T_e0d35_row1_col1" class="data row1 col1" >3.020000</td>
#       <td id="T_e0d35_row1_col2" class="data row1 col2" >2.260000</td>
#       <td id="T_e0d35_row1_col3" class="data row1 col3" >4.430000</td>
#       <td id="T_e0d35_row1_col4" class="data row1 col4" >2.100000</td>
#       <td id="T_e0d35_row1_col5" class="data row1 col5" >3.250000</td>
#       <td id="T_e0d35_row1_col6" class="data row1 col6" >3.700000</td>
#       <td id="T_e0d35_row1_col7" class="data row1 col7" >-0.300000</td>
#       <td id="T_e0d35_row1_col8" class="data row1 col8" >0.440000</td>
#       <td id="T_e0d35_row1_col9" class="data row1 col9" >-0.160000</td>
#       <td id="T_e0d35_row1_col10" class="data row1 col10" >1.493526</td>
#       <td id="T_e0d35_row1_col11" class="data row1 col11" >1.746837</td>
#       <td id="T_e0d35_row1_col12" class="data row1 col12" >3.240363</td>
#       <td id="T_e0d35_row1_col13" class="data row1 col13" >33.13%</td>
#       <td id="T_e0d35_row1_col14" class="data row1 col14" >44.28%</td>
#       <td id="T_e0d35_row1_col15" class="data row1 col15" >22.59%</td>
#     </tr>
#     <tr>
#       <th id="T_e0d35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0d35_row2_col0" class="data row2 col0" >Metz vs. Monaco</td>
#       <td id="T_e0d35_row2_col1" class="data row2 col1" >2.510000</td>
#       <td id="T_e0d35_row2_col2" class="data row2 col2" >2.860000</td>
#       <td id="T_e0d35_row2_col3" class="data row2 col3" >3.980000</td>
#       <td id="T_e0d35_row2_col4" class="data row2 col4" >5.000000</td>
#       <td id="T_e0d35_row2_col5" class="data row2 col5" >1.620000</td>
#       <td id="T_e0d35_row2_col6" class="data row2 col6" >4.200000</td>
#       <td id="T_e0d35_row2_col7" class="data row2 col7" >0.990000</td>
#       <td id="T_e0d35_row2_col8" class="data row2 col8" >-0.430000</td>
#       <td id="T_e0d35_row2_col9" class="data row2 col9" >0.060000</td>
#       <td id="T_e0d35_row2_col10" class="data row2 col10" >1.449328</td>
#       <td id="T_e0d35_row2_col11" class="data row2 col11" >1.337749</td>
#       <td id="T_e0d35_row2_col12" class="data row2 col12" >2.787077</td>
#       <td id="T_e0d35_row2_col13" class="data row2 col13" >39.91%</td>
#       <td id="T_e0d35_row2_col14" class="data row2 col14" >34.99%</td>
#       <td id="T_e0d35_row2_col15" class="data row2 col15" >25.10%</td>
#     </tr>
#     <tr>
#       <th id="T_e0d35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0d35_row3_col0" class="data row3 col0" >Clermont Foot vs. Toulouse</td>
#       <td id="T_e0d35_row3_col1" class="data row3 col1" >4.340000</td>
#       <td id="T_e0d35_row3_col2" class="data row3 col2" >1.860000</td>
#       <td id="T_e0d35_row3_col3" class="data row3 col3" >4.320000</td>
#       <td id="T_e0d35_row3_col4" class="data row3 col4" >3.050000</td>
#       <td id="T_e0d35_row3_col5" class="data row3 col5" >2.300000</td>
#       <td id="T_e0d35_row3_col6" class="data row3 col6" >3.450000</td>
#       <td id="T_e0d35_row3_col7" class="data row3 col7" >-0.300000</td>
#       <td id="T_e0d35_row3_col8" class="data row3 col8" >0.240000</td>
#       <td id="T_e0d35_row3_col9" class="data row3 col9" >-0.200000</td>
#       <td id="T_e0d35_row3_col10" class="data row3 col10" >1.124438</td>
#       <td id="T_e0d35_row3_col11" class="data row3 col11" >1.801181</td>
#       <td id="T_e0d35_row3_col12" class="data row3 col12" >2.925619</td>
#       <td id="T_e0d35_row3_col13" class="data row3 col13" >23.04%</td>
#       <td id="T_e0d35_row3_col14" class="data row3 col14" >53.79%</td>
#       <td id="T_e0d35_row3_col15" class="data row3 col15" >23.17%</td>
#     </tr>
#     <tr>
#       <th id="T_e0d35_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0d35_row4_col0" class="data row4 col0" >Le Havre vs. Montpellier</td>
#       <td id="T_e0d35_row4_col1" class="data row4 col1" >1.600000</td>
#       <td id="T_e0d35_row4_col2" class="data row4 col2" >5.620000</td>
#       <td id="T_e0d35_row4_col3" class="data row4 col3" >5.030000</td>
#       <td id="T_e0d35_row4_col4" class="data row4 col4" >2.650000</td>
#       <td id="T_e0d35_row4_col5" class="data row4 col5" >2.700000</td>
#       <td id="T_e0d35_row4_col6" class="data row4 col6" >3.350000</td>
#       <td id="T_e0d35_row4_col7" class="data row4 col7" >0.660000</td>
#       <td id="T_e0d35_row4_col8" class="data row4 col8" >-0.520000</td>
#       <td id="T_e0d35_row4_col9" class="data row4 col9

# %%
# Round all numbers to the 2nd decimal place
styled_df = styled_df.format('{:.2f}')

# Display the styled DataFrame with rounded numbers
styled_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:408, in Styler._repr_html_(self)
#     403 """
#     404 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     405 default if an object is returned at the end of a cell.
#     406 """
#     407 if get_option("styler.render.repr") == "html":
# --> 408     return self.to_html()
#     409 return None
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1348, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1345     obj.set_caption(caption)
#    1347 # Build HTML string..
# -> 1348 html = obj._render_html(
#    1349     sparse_index=sparse_index,
#    1350     sparse_columns=sparse_columns,
#    1351     max_rows=max_rows,
#    1352     max_cols=max_columns,
#    1353     exclude_styles=exclude_styles,
#    1354     encoding=encoding or get_option("styler.render.encoding"),
#    1355     doctype_html=doctype_html,
#    1356     **kwargs,
#    1357 )
#    1359 return save_to_buffer(
#    1360     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1361 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:204, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     192 def _render_html(
#     193     self,
#     194     sparse_index: bool,
#    (...)
#     198     **kwargs,
#     199 ) -> str:
#     200     """
#     201     Renders the ``Styler`` including all applied styles to HTML.
#     202     Generates a dict with necessary kwargs passed to jinja2 template.
#     203     """
# --> 204     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     205     d.update(kwargs)
#     206     return self.template_html.render(
#     207         **d,
#     208         html_table_tpl=self.template_html_table,
#     209         html_style_tpl=self.template_html_style,
#     210     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:187, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     183         self.ctx_index[(r + ctx_len, c)] = v
#     185     ctx_len += len(concatenated.index)
# --> 187 d = self._translate(
#     188     sparse_index, sparse_columns, max_rows, max_cols, blank, dxs
#     189 )
#     190 return d
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:335, in StylerRenderer._translate(self, sparse_index, sparse_cols, max_rows, max_cols, blank, dxs)
#     329 self.cellstyle_map: DefaultDict[tuple[CSSPair, ...], list[str]] = defaultdict(
#     330     list
#     331 )
#     332 self.cellstyle_map_index: DefaultDict[
#     333     tuple[CSSPair, ...], list[str]
#     334 ] = defaultdict(list)
# --> 335 body: list = self._translate_body(idx_lengths, max_rows, max_cols)
#     336 d.update({"body": body})
#     338 ctx_maps = {
#     339     "cellstyle": "cellstyle_map",
#     340     "cellstyle_index": "cellstyle_map_index",
#     341     "cellstyle_columns": "cellstyle_map_columns",
#     342 }  # add the cell_ids styles map to the render dictionary in right format
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:629, in StylerRenderer._translate_body(self, idx_lengths, max_rows, max_cols)
#     621     if self._check_trim(
#     622         visible_row_count,
#     623         max_rows,
#     624         body,
#     625         "row",
#     626     ):
#     627         break
# --> 629     body_row = self._generate_body_row(
#     630         (r, row_tup, rlabels), max_cols, idx_lengths
#     631     )
#     632     body.append(body_row)
#     633 return body
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:826, in StylerRenderer._generate_body_row(self, iter, max_cols, idx_lengths)
#     814 if (r, c) in self.cell_context:
#     815     cls = " " + self.cell_context[r, c]
#     817 data_element = _element(
#     818     "td",
#     819     (
#     820         f"{self.css['data']} {self.css['row']}{r} "
#     821         f"{self.css['col']}{c}{cls}"
#     822     ),
#     823     value,
#     824     data_element_visible,
#     825     attributes="",
# --> 826     display_value=self._display_funcs[(r, c)](value),
#     827 )
#     829 if self.cell_ids:
#     830     data_element["id"] = f"{self.css['row']}{r}_{self.css['col']}{c}"
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:1829, in _maybe_wrap_formatter.<locals>.<lambda>(x)
#    1827 # Get initial func from input string, input callable, or from default factory
#    1828 if isinstance(formatter, str):
# -> 1829     func_0 = lambda x: formatter.format(x)
#    1830 elif callable(formatter):
#    1831     func_0 = formatter
#
# ValueError: Unknown format code 'f' for object of type 'str'
