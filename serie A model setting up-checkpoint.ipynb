# %%
import soccerdata as sd
understat = sd.Understat(leagues="ITA-Serie A", seasons="2023/2024")
team_match_stats = understat.read_team_match_stats()
team_match_stats.head()
# Out:
# [03/26/24 21:11:53] INFO     No custom team name replacements found. You can configure these in       ]8;id=93080;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=461390;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py#87\87]8;;\
#                              C:\Users\jbuck\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=616411;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=394891;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py#177\177]8;;\
#                              C:\Users\jbuck\soccerdata\config\league_dict.json.
#                     INFO     Saving cached data to C:\Users\jbuck\soccerdata\data\Understat           ]8;id=868708;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=390798;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py#92\92]8;;\
#                                                league_id  season_id  game_id  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona            2       2023    22305
#                    2023-08-19 Frosinone-Napoli         2       2023    22306
#                    2023-08-19 Genoa-Fiorentina         2       2023    22308
#                    2023-08-19 Inter-Monza              2       2023    22307
#                    2023-08-20 Lecce-Lazio              2       2023    22312
#
#                                                               date  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona    2023-08-19 16:30:00
#                    2023-08-19 Frosinone-Napoli 2023-08-19 16:30:00
#                    2023-08-19 Genoa-Fiorentina 2023-08-19 18:45:00
#                    2023-08-19 Inter-Monza      2023-08-19 18:45:00
#                    2023-08-20 Lecce-Lazio      2023-08-20 18:45:00
#
#                                                 home_team_id  away_team_id  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona              108            94
#                    2023-08-19 Frosinone-Napoli           112           105
#                    2023-08-19 Genoa-Fiorentina           101           110
#                    2023-08-19 Inter-Monza                106           271
#                    2023-08-20 Lecce-Lazio                243            96
#
#                                                 home_team   away_team  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona        Empoli      Verona
#                    2023-08-19 Frosinone-Napoli  Frosinone      Napoli
#                    2023-08-19 Genoa-Fiorentina      Genoa  Fiorentina
#                    2023-08-19 Inter-Monza           Inter       Monza
#                    2023-08-20 Lecce-Lazio           Lecce       Lazio
#
#                                                away_team_code home_team_code  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona               VER            EMP
#                    2023-08-19 Frosinone-Napoli            NAP            FRO
#                    2023-08-19 Genoa-Fiorentina            FIO            GEN
#                    2023-08-19 Inter-Monza                 MON            INT
#                    2023-08-20 Lecce-Lazio                 LAZ            LEC
#
#                                                 ...  away_ppda  \
# league      season game                         ...
# ITA-Serie A 2324   2023-08-19 Empoli-Verona     ...   6.695652
#                    2023-08-19 Frosinone-Napoli  ...       11.1
#                    2023-08-19 Genoa-Fiorentina  ...    10.1875
#                    2023-08-19 Inter-Monza       ...  14.111111
#                    2023-08-20 Lecce-Lazio       ...       9.96
#
#                                                 away_deep_completions  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona                         6
#                    2023-08-19 Frosinone-Napoli                     10
#                    2023-08-19 Genoa-Fiorentina                      6
#                    2023-08-19 Inter-Monza                          10
#                    2023-08-20 Lecce-Lazio                           9
#
#                                                 home_points  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona               0
#                    2023-08-19 Frosinone-Napoli            0
#                    2023-08-19 Genoa-Fiorentina            0
#                    2023-08-19 Inter-Monza                 3
#                    2023-08-20 Lecce-Lazio                 3
#
#                                                 home_expected_points  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona                   1.4686
#                    2023-08-19 Frosinone-Napoli                0.9918
#                    2023-08-19 Genoa-Fiorentina                1.0316
#                    2023-08-19 Inter-Monza                     2.7046
#                    2023-08-20 Lecce-Lazio                     1.0589
#
#                                                 home_goals   home_xg  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona              0  0.844727
#                    2023-08-19 Frosinone-Napoli           1  0.871157
#                    2023-08-19 Genoa-Fiorentina           1   0.79732
#                    2023-08-19 Inter-Monza                2   2.49549
#                    2023-08-20 Lecce-Lazio                2   1.75411
#
#                                                 home_np_xg  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona       0.844727
#                    2023-08-19 Frosinone-Napoli    0.109858
#                    2023-08-19 Genoa-Fiorentina     0.79732
#                    2023-08-19 Inter-Monza          2.49549
#                    2023-08-20 Lecce-Lazio          1.75411
#
#                                                 home_np_xg_difference  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona                  0.153885
#                    2023-08-19 Frosinone-Napoli              -1.204782
#                    2023-08-19 Genoa-Fiorentina               -0.32238
#                    2023-08-19 Inter-Monza                    1.914243
#                    2023-08-20 Lecce-Lazio                    -0.46804
#
#                                                 home_ppda  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona     10.166667
#                    2023-08-19 Frosinone-Napoli  20.785714
#                    2023-08-19 Genoa-Fiorentina      16.08
#                    2023-08-19 Inter-Monza       17.666667
#                    2023-08-20 Lecce-Lazio       15.714286
#
#                                                 home_deep_completions
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona                         3
#                    2023-08-19 Frosinone-Napoli                      4
#                    2023-08-19 Genoa-Fiorentina                      5
#                    2023-08-19 Inter-Monza                           9
#                    2023-08-20 Lecce-Lazio                          13
#
# [5 rows x 26 columns]

# %%
import pandas as pd

# Assuming 'team_match_stats' is your DataFrame loaded from the code you've provided

# Calculating total xG for teams when they are at home
home_xg = team_match_stats.groupby('home_team')['home_xg'].sum().rename('total_home_xg')

# Calculating total xG for teams when they are away
away_xg = team_match_stats.groupby('away_team')['away_xg'].sum().rename('total_away_xg')

# Calculating total xGA (expected goals against) for teams when they are at home
home_xga = team_match_stats.groupby('home_team')['away_xg'].sum().rename('total_home_xga')

# Calculating total xGA for teams when they are away
away_xga = team_match_stats.groupby('away_team')['home_xg'].sum().rename('total_away_xga')

# Merging the above series into a single DataFrame
teams_xg_xga = pd.concat([home_xg, away_xg, home_xga, away_xga], axis=1)

# Filling NaN values with 0, in case some teams didn't play home or away games yet
teams_xg_xga = teams_xg_xga.fillna(0)

# Calculating overall total xG and xGA
teams_xg_xga['total_xg'] = teams_xg_xga['total_home_xg'] + teams_xg_xga['total_away_xg']
teams_xg_xga['total_xga'] = teams_xg_xga['total_home_xga'] + teams_xg_xga['total_away_xga']

teams_xg_xga
# Out:
#              total_home_xg  total_away_xg  total_home_xga  total_away_xga  \
# AC Milan         23.868932      26.212379       15.374868       19.916606
# Atalanta         32.108106      16.419081       15.637447       18.145465
# Bologna          22.600408      18.629205       13.857788       16.595232
# Cagliari         22.221537      12.218291       19.212303       29.985149
# Empoli           15.703243      14.185673       21.814367       20.471098
# Fiorentina       24.874155      15.140591       15.504294       23.846798
# Frosinone        21.500364      16.549879        23.16814       28.953599
# Genoa            15.622637      12.293386       17.478848       19.610395
# Inter            40.009164      26.592727       11.844522       12.288707
# Juventus         26.159978      24.233775        8.282079       13.604653
# Lazio            19.425393      20.346337       12.508194       23.937505
# Lecce            17.955066      16.591095       23.368741        29.66474
# Monza            20.067317      16.469314       22.316163       23.115844
# Napoli           28.107614      22.593716        16.85309       14.255725
# Roma             25.644294      18.734513       11.808304       19.475058
# Salernitana      14.004101       9.437763       26.458575       32.340688
# Sassuolo         16.916869      17.789873       22.667515       26.359634
# Torino           18.598075      14.211856        9.117915       19.381269
# Udinese          21.195787      13.633911       18.270974       23.204512
# Verona           13.412914      13.409268       20.148505       24.843277
#
#               total_xg  total_xga
# AC Milan     50.081311  35.291474
# Atalanta     48.527187  33.782912
# Bologna      41.229613   30.45302
# Cagliari     34.439828  49.197452
# Empoli       29.888916  42.285465
# Fiorentina   40.014746  39.351092
# Frosinone    38.050243  52.121739
# Genoa        27.916023  37.089243
# Inter        66.601891  24.133229
# Juventus     50.393753  21.886732
# Lazio         39.77173  36.445699
# Lecce        34.546161  53.033481
# Monza        36.536631  45.432007
# Napoli        50.70133  31.108815
# Roma         44.378807  31.283362
# Salernitana  23.441864  58.799263
# Sassuolo     34.706742  49.027149
# Torino       32.809931  28.499184
# Udinese      34.829698  41.475486
# Verona       26.822182  44.991782

# %%
import pandas as pd

# Identify all unique teams
teams = pd.concat([team_match_stats['home_team'], team_match_stats['away_team']]).unique()

# Prepare a list to collect each team's average xG and xGA for home and away games
team_averages = []

# Iterate through each team
for team in teams:
    # Filter home games involving the current team
    team_home_games = team_match_stats[team_match_stats['home_team'] == team]
    # Sort home games by date in descending order and select the last 5
    team_last_5_home_games = team_home_games.sort_values(by='date', ascending=False).head(5)
    
    # Filter away games involving the current team
    team_away_games = team_match_stats[team_match_stats['away_team'] == team]
    # Sort away games by date in descending order and select the last 5
    team_last_5_away_games = team_away_games.sort_values(by='date', ascending=False).head(5)
    
    # Calculate average xG and xGA for home games
    team_home_xg_avg = team_last_5_home_games['home_xg'].mean()
    team_home_xga_avg = team_last_5_home_games['away_xg'].mean()
    
    # Calculate average xG and xGA for away games
    team_away_xg_avg = team_last_5_away_games['away_xg'].mean()
    team_away_xga_avg = team_last_5_away_games['home_xg'].mean()
    
    # Append the averages to the list
    team_averages.append({
        'Team': team,
        'Average Home xG Last 5': team_home_xg_avg,
        'Average Home xGA Last 5': team_home_xga_avg,
        'Average Away xG Last 5': team_away_xg_avg,
        'Average Away xGA Last 5': team_away_xga_avg
    })

# Convert the list of averages into a DataFrame
teams_xg_xga_df = pd.DataFrame(team_averages)

# Display the DataFrame
teams_xg_xga_df
# Out:
#            Team  Average Home xG Last 5  Average Home xGA Last 5  \
# 0        Empoli                1.137118                 1.020183
# 1     Frosinone                1.810934                 1.805968
# 2         Genoa                1.401221                 1.487754
# 3         Inter                2.666408                 0.686787
# 4         Lecce                1.276828                 1.636801
# 5          Roma                1.640919                 0.834087
# 6      Sassuolo                0.788284                 1.862240
# 7       Udinese                1.027450                 1.151729
# 8       Bologna                1.663566                 0.899704
# 9        Torino                1.382279                 0.539022
# 10     AC Milan                1.785178                 1.059429
# 11        Monza                1.065819                 0.994766
# 12       Verona                1.047332                 1.461063
# 13   Fiorentina                2.616910                 0.891661
# 14     Juventus                1.560887                 0.609144
# 15        Lazio                1.277767                 0.927925
# 16       Napoli                1.857944                 0.957032
# 17     Cagliari                1.498599                 1.479841
# 18  Salernitana                1.112627                 1.874530
# 19     Atalanta                3.067152                 1.148790
#
#     Average Away xG Last 5  Average Away xGA Last 5
# 0                 1.302385                 1.126374
# 1                 1.068432                 2.547038
# 2                 0.663848                 1.443578
# 3                 2.095582                 1.114278
# 4                 1.426507                 1.675046
# 5                 1.443437                 1.624080
# 6                 0.915089                 1.536133
# 7                 0.945342                 1.755712
# 8                 1.571905                 1.461521
# 9                 1.351988                 1.260747
# 10                1.875293                 1.132708
# 11                1.343496                 1.251207
# 12                0.823220                 1.526249
# 13                1.031102                 1.435260
# 14                1.749698                 1.092085
# 15                1.433906                 2.258476
# 16                1.258547                 0.864096
# 17                0.558454                 2.082480
# 18                0.458230                 2.672851
# 19                1.150513                 1.892590

# %%
# Count the number of home matches played by each team
home_matches_played = team_match_stats.groupby('home_team')['home_ppda'].count().rename('home_matches_played')

# Count the number of away matches played by each team
away_matches_played = team_match_stats.groupby('away_team')['away_ppda'].count().rename('away_matches_played')

# Merging these counts into the teams_xg_xga DataFrame
teams_xg_xga = teams_xg_xga.merge(home_matches_played, how='left', left_index=True, right_index=True)
teams_xg_xga = teams_xg_xga.merge(away_matches_played, how='left', left_index=True, right_index=True)

# Filling NaN values with 0 in case some teams didn't play home or away games
teams_xg_xga['home_matches_played'] = teams_xg_xga['home_matches_played'].fillna(0)
teams_xg_xga['away_matches_played'] = teams_xg_xga['away_matches_played'].fillna(0)

# Calculating the total matches played by adding home and away matches
teams_xg_xga['matches_played'] = teams_xg_xga['home_matches_played'] + teams_xg_xga['away_matches_played']

teams_xg_xga
# Out:
#              total_home_xg  total_away_xg  total_home_xga  total_away_xga  \
# AC Milan         23.868932      26.212379       15.374868       19.916606
# Atalanta         32.108106      16.419081       15.637447       18.145465
# Bologna          22.600408      18.629205       13.857788       16.595232
# Cagliari         22.221537      12.218291       19.212303       29.985149
# Empoli           15.703243      14.185673       21.814367       20.471098
# Fiorentina       24.874155      15.140591       15.504294       23.846798
# Frosinone        21.500364      16.549879        23.16814       28.953599
# Genoa            15.622637      12.293386       17.478848       19.610395
# Inter            40.009164      26.592727       11.844522       12.288707
# Juventus         26.159978      24.233775        8.282079       13.604653
# Lazio            19.425393      20.346337       12.508194       23.937505
# Lecce            17.955066      16.591095       23.368741        29.66474
# Monza            20.067317      16.469314       22.316163       23.115844
# Napoli           28.107614      22.593716        16.85309       14.255725
# Roma             25.644294      18.734513       11.808304       19.475058
# Salernitana      14.004101       9.437763       26.458575       32.340688
# Sassuolo         16.916869      17.789873       22.667515       26.359634
# Torino           18.598075      14.211856        9.117915       19.381269
# Udinese          21.195787      13.633911       18.270974       23.204512
# Verona           13.412914      13.409268       20.148505       24.843277
#
#               total_xg  total_xga  home_matches_played  away_matches_played  \
# AC Milan     50.081311  35.291474                   14                   15
# Atalanta     48.527187  33.782912                   14                   14
# Bologna      41.229613   30.45302                   15                   14
# Cagliari     34.439828  49.197452                   14                   15
# Empoli       29.888916  42.285465                   15                   14
# Fiorentina   40.014746  39.351092                   14                   14
# Frosinone    38.050243  52.121739                   15                   14
# Genoa        27.916023  37.089243                   14                   15
# Inter        66.601891  24.133229                   15                   14
# Juventus     50.393753  21.886732                   15                   14
# Lazio         39.77173  36.445699                   14                   15
# Lecce        34.546161  53.033481                   14                   15
# Monza        36.536631  45.432007                   15                   14
# Napoli        50.70133  31.108815                   14                   15
# Roma         44.378807  31.283362                   15                   14
# Salernitana  23.441864  58.799263                   15                   14
# Sassuolo     34.706742  49.027149                   14                   15
# Torino       32.809931  28.499184                   14                   15
# Udinese      34.829698  41.475486                   15                   14
# Verona       26.822182  44.991782                   14                   15
#
#              matches_played
# AC Milan                 29
# Atalanta                 28
# Bologna                  29
# Cagliari                 29
# Empoli                   29
# Fiorentina               28
# Frosinone                29
# Genoa                    29
# Inter                    29
# Juventus                 29
# Lazio                    29
# Lecce                    29
# Monza                    29
# Napoli                   29
# Roma                     29
# Salernitana              29
# Sassuolo                 29
# Torino                   29
# Udinese                  29
# Verona                   29

# %%
# Calculating xG difference for home games
teams_xg_xga['home_xg_diff'] = teams_xg_xga['total_home_xg'] - teams_xg_xga['total_home_xga']

# Calculating xG difference for away games
teams_xg_xga['away_xg_diff'] = teams_xg_xga['total_away_xg'] - teams_xg_xga['total_away_xga']

# Display the updated DataFrame
teams_xg_xga
# Out:
#              total_home_xg  total_away_xg  total_home_xga  total_away_xga  \
# AC Milan         23.868932      26.212379       15.374868       19.916606
# Atalanta         32.108106      16.419081       15.637447       18.145465
# Bologna          22.600408      18.629205       13.857788       16.595232
# Cagliari         22.221537      12.218291       19.212303       29.985149
# Empoli           15.703243      14.185673       21.814367       20.471098
# Fiorentina       24.874155      15.140591       15.504294       23.846798
# Frosinone        21.500364      16.549879        23.16814       28.953599
# Genoa            15.622637      12.293386       17.478848       19.610395
# Inter            40.009164      26.592727       11.844522       12.288707
# Juventus         26.159978      24.233775        8.282079       13.604653
# Lazio            19.425393      20.346337       12.508194       23.937505
# Lecce            17.955066      16.591095       23.368741        29.66474
# Monza            20.067317      16.469314       22.316163       23.115844
# Napoli           28.107614      22.593716        16.85309       14.255725
# Roma             25.644294      18.734513       11.808304       19.475058
# Salernitana      14.004101       9.437763       26.458575       32.340688
# Sassuolo         16.916869      17.789873       22.667515       26.359634
# Torino           18.598075      14.211856        9.117915       19.381269
# Udinese          21.195787      13.633911       18.270974       23.204512
# Verona           13.412914      13.409268       20.148505       24.843277
#
#               total_xg  total_xga  home_matches_played  away_matches_played  \
# AC Milan     50.081311  35.291474                   14                   15
# Atalanta     48.527187  33.782912                   14                   14
# Bologna      41.229613   30.45302                   15                   14
# Cagliari     34.439828  49.197452                   14                   15
# Empoli       29.888916  42.285465                   15                   14
# Fiorentina   40.014746  39.351092                   14                   14
# Frosinone    38.050243  52.121739                   15                   14
# Genoa        27.916023  37.089243                   14                   15
# Inter        66.601891  24.133229                   15                   14
# Juventus     50.393753  21.886732                   15                   14
# Lazio         39.77173  36.445699                   14                   15
# Lecce        34.546161  53.033481                   14                   15
# Monza        36.536631  45.432007                   15                   14
# Napoli        50.70133  31.108815                   14                   15
# Roma         44.378807  31.283362                   15                   14
# Salernitana  23.441864  58.799263                   15                   14
# Sassuolo     34.706742  49.027149                   14                   15
# Torino       32.809931  28.499184                   14                   15
# Udinese      34.829698  41.475486                   15                   14
# Verona       26.822182  44.991782                   14                   15
#
#              matches_played  home_xg_diff  away_xg_diff
# AC Milan                 29      8.494064      6.295773
# Atalanta                 28     16.470659     -1.726384
# Bologna                  29       8.74262      2.033973
# Cagliari                 29      3.009234    -17.766858
# Empoli                   29     -6.111124     -6.285425
# Fiorentina               28      9.369861     -8.706207
# Frosinone                29     -1.667776     -12.40372
# Genoa                    29     -1.856211     -7.317009
# Inter                    29     28.164642      14.30402
# Juventus                 29     17.877899     10.629122
# Lazio                    29      6.917199     -3.591168
# Lecce                    29     -5.413675    -13.073645
# Monza                    29     -2.248846      -6.64653
# Napoli                   29     11.254524      8.337991
# Roma                     29      13.83599     -0.740545
# Salernitana              29    -12.454474    -22.902925
# Sassuolo                 29     -5.750646     -8.569761
# Torino                   29       9.48016     -5.169413
# Udinese                  29      2.924813     -9.570601
# Verona                   29     -6.735591    -11.434009

# %%
# Assuming 'teams_xg_xga' is your DataFrame

# Calculate the averages for each specified column
averages = teams_xg_xga.mean()

# Creating a new DataFrame with the averages to append it properly with a label
averages_df = pd.DataFrame([averages], index=['Average'])

# Append the averages row to your original DataFrame
teams_xg_xga_with_averages = pd.concat([teams_xg_xga, averages_df])

teams_xg_xga_with_averages
# Out:
#              total_home_xg  total_away_xg  total_home_xga  total_away_xga  \
# AC Milan         23.868932      26.212379       15.374868       19.916606
# Atalanta         32.108106      16.419081       15.637447       18.145465
# Bologna          22.600408      18.629205       13.857788       16.595232
# Cagliari         22.221537      12.218291       19.212303       29.985149
# Empoli           15.703243      14.185673       21.814367       20.471098
# Fiorentina       24.874155      15.140591       15.504294       23.846798
# Frosinone        21.500364      16.549879        23.16814       28.953599
# Genoa            15.622637      12.293386       17.478848       19.610395
# Inter            40.009164      26.592727       11.844522       12.288707
# Juventus         26.159978      24.233775        8.282079       13.604653
# Lazio            19.425393      20.346337       12.508194       23.937505
# Lecce            17.955066      16.591095       23.368741        29.66474
# Monza            20.067317      16.469314       22.316163       23.115844
# Napoli           28.107614      22.593716        16.85309       14.255725
# Roma             25.644294      18.734513       11.808304       19.475058
# Salernitana      14.004101       9.437763       26.458575       32.340688
# Sassuolo         16.916869      17.789873       22.667515       26.359634
# Torino           18.598075      14.211856        9.117915       19.381269
# Udinese          21.195787      13.633911       18.270974       23.204512
# Verona           13.412914      13.409268       20.148505       24.843277
# Average          21.999798      17.284632       17.284632       21.999798
#
#               total_xg  total_xga  home_matches_played  away_matches_played  \
# AC Milan     50.081311  35.291474                 14.0                 15.0
# Atalanta     48.527187  33.782912                 14.0                 14.0
# Bologna      41.229613   30.45302                 15.0                 14.0
# Cagliari     34.439828  49.197452                 14.0                 15.0
# Empoli       29.888916  42.285465                 15.0                 14.0
# Fiorentina   40.014746  39.351092                 14.0                 14.0
# Frosinone    38.050243  52.121739                 15.0                 14.0
# Genoa        27.916023  37.089243                 14.0                 15.0
# Inter        66.601891  24.133229                 15.0                 14.0
# Juventus     50.393753  21.886732                 15.0                 14.0
# Lazio         39.77173  36.445699                 14.0                 15.0
# Lecce        34.546161  53.033481                 14.0                 15.0
# Monza        36.536631  45.432007                 15.0                 14.0
# Napoli        50.70133  31.108815                 14.0                 15.0
# Roma         44.378807  31.283362                 15.0                 14.0
# Salernitana  23.441864  58.799263                 15.0                 14.0
# Sassuolo     34.706742  49.027149                 14.0                 15.0
# Torino       32.809931  28.499184                 14.0                 15.0
# Udinese      34.829698  41.475486                 15.0                 14.0
# Verona       26.822182  44.991782                 14.0                 15.0
# Average      39.284429  39.284429                14.45                14.45
#
#              matches_played  home_xg_diff  away_xg_diff
# AC Milan               29.0      8.494064      6.295773
# Atalanta               28.0     16.470659     -1.726384
# Bologna                29.0       8.74262      2.033973
# Cagliari               29.0      3.009234    -17.766858
# Empoli                 29.0     -6.111124     -6.285425
# Fiorentina             28.0      9.369861     -8.706207
# Frosinone              29.0     -1.667776     -12.40372
# Genoa                  29.0     -1.856211     -7.317009
# Inter                  29.0     28.164642      14.30402
# Juventus               29.0     17.877899     10.629122
# Lazio                  29.0      6.917199     -3.591168
# Lecce                  29.0     -5.413675    -13.073645
# Monza                  29.0     -2.248846      -6.64653
# Napoli                 29.0     11.254524      8.337991
# Roma                   29.0      13.83599     -0.740545
# Salernitana            29.0    -12.454474    -22.902925
# Sassuolo               29.0     -5.750646     -8.569761
# Torino                 29.0       9.48016     -5.169413
# Udinese                29.0      2.924813     -9.570601
# Verona                 29.0     -6.735591    -11.434009
# Average                28.9      4.715166     -4.715166

# %%
import numpy as np

# Create a new DataFrame for per match averages
teams_per_match_averages = pd.DataFrame(index=teams_xg_xga.index)

# Calculate per match averages for home and away xG and xGA
teams_per_match_averages['per_match_home_xg'] = teams_xg_xga['total_home_xg'] / teams_xg_xga['home_matches_played']
teams_per_match_averages['per_match_away_xg'] = teams_xg_xga['total_away_xg'] / teams_xg_xga['away_matches_played']
teams_per_match_averages['per_match_home_xga'] = teams_xg_xga['total_home_xga'] / teams_xg_xga['home_matches_played']
teams_per_match_averages['per_match_away_xga'] = teams_xg_xga['total_away_xga'] / teams_xg_xga['away_matches_played']

# Calculate overall total xG and xGA per match
teams_per_match_averages['total_xg_per_match'] = teams_xg_xga['total_xg'] / teams_xg_xga['matches_played']
teams_per_match_averages['total_xga_per_match'] = teams_xg_xga['total_xga'] / teams_xg_xga['matches_played']

# Replace any potential infinite values with NaN (in case of division by zero) and then fill with 0
teams_per_match_averages.replace([np.inf, -np.inf], np.nan, inplace=True)
teams_per_match_averages.fillna(0, inplace=True)

# Calculate the average for each column
average_stats = teams_per_match_averages.mean()

# Append the 'Average' row with these averages to the DataFrame
teams_per_match_averages.loc['Average'] = average_stats

teams_per_match_averages
# Out:
#              per_match_home_xg  per_match_away_xg  per_match_home_xga  \
# AC Milan              1.704924           1.747492            1.098205
# Atalanta              2.293436           1.172791            1.116961
# Bologna               1.506694           1.330657            0.923853
# Cagliari              1.587253           0.814553            1.372307
# Empoli                1.046883           1.013262            1.454291
# Fiorentina            1.776725           1.081471             1.10745
# Frosinone             1.433358           1.182134            1.544543
# Genoa                 1.115903           0.819559            1.248489
# Inter                 2.667278            1.89948            0.789635
# Juventus              1.743999           1.730984            0.552139
# Lazio                 1.387528           1.356422            0.893442
# Lecce                 1.282505           1.106073            1.669196
# Monza                 1.337821            1.17638            1.487744
# Napoli                2.007687           1.506248            1.203792
# Roma                   1.70962            1.33818             0.78722
# Salernitana           0.933607           0.674126            1.763905
# Sassuolo              1.208348           1.185992            1.619108
# Torino                1.328434           0.947457             0.65128
# Udinese               1.413052           0.973851            1.218065
# Verona                0.958065           0.893951            1.439179
# Average               1.522156           1.197553             1.19704
#
#              per_match_away_xga  total_xg_per_match  total_xga_per_match
# AC Milan               1.327774            1.726942             1.216947
# Atalanta               1.296105            1.733114             1.206533
# Bologna                1.185374            1.421711             1.050104
# Cagliari                1.99901             1.18758             1.696464
# Empoli                 1.462221            1.030652             1.458119
# Fiorentina             1.703343            1.429098             1.405396
# Frosinone              2.068114            1.312077             1.797301
# Genoa                   1.30736            0.962621             1.278939
# Inter                  0.877765            2.296617              0.83218
# Juventus               0.971761            1.737716             0.754715
# Lazio                  1.595834            1.371439             1.256748
# Lecce                  1.977649            1.191247             1.828741
# Monza                  1.651132            1.259884             1.566621
# Napoli                 0.950382            1.748322             1.072718
# Roma                   1.391076            1.530304             1.078737
# Salernitana            2.310049             0.80834             2.027561
# Sassuolo               1.757309            1.196784             1.690591
# Torino                 1.292085            1.131377              0.98273
# Udinese                1.657465            1.201024             1.430189
# Verona                 1.656218            0.924903             1.551441
# Average                1.521901            1.360088             1.359139

# %%
# Load the full schedule
schedule_df = understat.read_schedule()

# Convert the 'date' column to datetime format, then format it to keep only the date part
schedule_df['date'] = pd.to_datetime(schedule_df['date']).dt.date

# Display the first few rows to verify the change
print(schedule_df.head())
# Out:
#                                                league_id  season_id  game_id  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona            2       2023    22305
#                    2023-08-19 Frosinone-Napoli         2       2023    22306
#                    2023-08-19 Genoa-Fiorentina         2       2023    22308
#                    2023-08-19 Inter-Monza              2       2023    22307
#                    2023-08-20 Lecce-Lazio              2       2023    22312
#
#                                                       date  home_team_id  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona     2023-08-19           108
#                    2023-08-19 Frosinone-Napoli  2023-08-19           112
#                    2023-08-19 Genoa-Fiorentina  2023-08-19           101
#                    2023-08-19 Inter-Monza       2023-08-19           106
#                    2023-08-20 Lecce-Lazio       2023-08-20           243
#
#                                                 away_team_id  home_team  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona               94     Empoli
#                    2023-08-19 Frosinone-Napoli           105  Frosinone
#                    2023-08-19 Genoa-Fiorentina           110      Genoa
#                    2023-08-19 Inter-Monza                271      Inter
#                    2023-08-20 Lecce-Lazio                 96      Lecce
#
#                                                  away_team away_team_code  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona         Verona            VER
#                    2023-08-19 Frosinone-Napoli      Napoli            NAP
#                    2023-08-19 Genoa-Fiorentina  Fiorentina            FIO
#                    2023-08-19 Inter-Monza            Monza            MON
#                    2023-08-20 Lecce-Lazio            Lazio            LAZ
#
#                                                home_team_code  home_goals  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona               EMP           0
#                    2023-08-19 Frosinone-Napoli            FRO           1
#                    2023-08-19 Genoa-Fiorentina            GEN           1
#                    2023-08-19 Inter-Monza                 INT           2
#                    2023-08-20 Lecce-Lazio                 LEC           2
#
#                                                 away_goals   home_xg  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona              1  0.844727
#                    2023-08-19 Frosinone-Napoli           3  0.871157
#                    2023-08-19 Genoa-Fiorentina           4   0.79732
#                    2023-08-19 Inter-Monza                0   2.49549
#                    2023-08-20 Lecce-Lazio                1   1.75411
#
#                                                  away_xg  is_result  has_data  \
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona     0.690842       True      True
#                    2023-08-19 Frosinone-Napoli   1.31464       True      True
#                    2023-08-19 Genoa-Fiorentina    1.1197       True      True
#                    2023-08-19 Inter-Monza       0.581247       True      True
#                    2023-08-20 Lecce-Lazio        2.22215       True      True
#
#                                                                               url
# league      season game
# ITA-Serie A 2324   2023-08-19 Empoli-Verona     https://understat.com/match/22305
#                    2023-08-19 Frosinone-Napoli  https://understat.com/match/22306
#                    2023-08-19 Genoa-Fiorentina  https://understat.com/match/22308
#                    2023-08-19 Inter-Monza       https://understat.com/match/22307
#                    2023-08-20 Lecce-Lazio       https://understat.com/match/22312

# %%
import pandas as pd

# Assuming 'schedule_df' is your DataFrame and it's already loaded

# Make sure the 'date' column is in datetime format
schedule_df['date'] = pd.to_datetime(schedule_df['date'])

# Define the start and end dates for filtering
start_date = pd.to_datetime('2024-03-29')
end_date = pd.to_datetime('2024-04-01')

# Filter the DataFrame for games within the date range, and use .copy() to avoid SettingWithCopyWarning
filtered_games = schedule_df[(schedule_df['date'] >= start_date) & (schedule_df['date'] <= end_date)].copy()

# Create a new column 'game_matchup' by concatenating 'home_team', 'vs.', and 'away_team'
filtered_games['game_matchup'] = filtered_games['home_team'] + ' vs. ' + filtered_games['away_team']

# Now, create a separate DataFrame that contains only the 'game_matchup' column
games_list_df = filtered_games[['game_matchup']].reset_index(drop=True)

# Display the new DataFrame to verify
print(games_list_df)
# Out:
#               game_matchup
# 0  Fiorentina vs. AC Milan
# 1      Genoa vs. Frosinone
# 2       Lazio vs. Juventus
# 3      Napoli vs. Atalanta
# 4         Torino vs. Monza
# 5  Bologna vs. Salernitana
# 6      Cagliari vs. Verona
# 7         Inter vs. Empoli
# 8           Lecce vs. Roma
# 9     Sassuolo vs. Udinese

# %%
import pandas as pd

# Assuming 'teams_per_match_averages' and 'games_list_df' are already defined

# Initialize an empty list for storing game metrics along with the matchup information
games_metrics_list = []

# Retrieve the 'Average' row for league-wide average stats
avg_stats = teams_per_match_averages.loc['Average']

# Looping through each game to calculate metrics using 'teams_per_match_averages'
for index, row in games_list_df.iterrows():
    # Extract home and away team names
    home_team, away_team = row['game_matchup'].split(' vs. ')
    
    # Retrieve team stats from 'teams_per_match_averages'
    home_team_stats = teams_per_match_averages.loc[home_team]
    away_team_stats = teams_per_match_averages.loc[away_team]
    
    # Calculate the metrics using the per match averages
    home_attack = home_team_stats['per_match_home_xg'] / avg_stats['per_match_home_xg']
    away_defence = away_team_stats['per_match_away_xga'] / avg_stats['per_match_away_xga']
    away_attack = away_team_stats['per_match_away_xg'] / avg_stats['per_match_away_xg']
    home_defence = home_team_stats['per_match_home_xga'] / avg_stats['per_match_home_xga']
    
    # Append the calculated metrics for this game to the list along with the game_matchup
    games_metrics_list.append({
        'Game Matchup': row['game_matchup'],
        'Home Attack': home_attack, 
        'Away Defence': away_defence,
        'Away Attack': away_attack, 
        'Home Defence': home_defence
    })

# Once all games are processed, create the DataFrame from the list
games_metrics_df = pd.DataFrame(games_metrics_list)

# Splitting 'Game Matchup' into 'Home Team' and 'Away Team'
games_metrics_df[['Home Team', 'Away Team']] = games_metrics_df['Game Matchup'].str.split(' vs. ', expand=True)

# Display the DataFrame with calculated metrics for each game
games_metrics_df
# Out:
#               Game Matchup  Home Attack  Away Defence  Away Attack  \
# 0  Fiorentina vs. AC Milan     1.167243      0.872444     1.459219
# 1      Genoa vs. Frosinone     0.733107      1.358902     0.987125
# 2       Lazio vs. Juventus     0.911555      0.638518     1.445434
# 3      Napoli vs. Atalanta     1.318976      0.851635     0.979323
# 4         Torino vs. Monza     0.872732      1.084914     0.982319
# 5  Bologna vs. Salernitana     0.989842      1.517871     0.562919
# 6      Cagliari vs. Verona     1.042766      1.088256     0.746481
# 7         Inter vs. Empoli     1.752303      0.960786     0.846111
# 8           Lecce vs. Roma     0.842558      0.914038     1.117428
# 9     Sassuolo vs. Udinese     0.793840      1.089075     0.813200
#
#    Home Defence   Home Team    Away Team
# 0      0.925157  Fiorentina     AC Milan
# 1      1.042980       Genoa    Frosinone
# 2      0.746376       Lazio     Juventus
# 3      1.005641      Napoli     Atalanta
# 4      0.544075      Torino        Monza
# 5      0.771781     Bologna  Salernitana
# 6      1.146417    Cagliari       Verona
# 7      0.659656       Inter       Empoli
# 8      1.394436       Lecce         Roma
# 9      1.352593    Sassuolo      Udinese

# %%
# Merge home team averages
games_metrics_df = games_metrics_df.merge(
    teams_xg_xga_df[['Team', 'Average Home xG Last 5', 'Average Home xGA Last 5']],
    left_on='Home Team',
    right_on='Team',
    how='left'
).drop(columns=['Team'])  # Dropping the redundant 'Team' column after merge

# Merge away team averages
games_metrics_df = games_metrics_df.merge(
    teams_xg_xga_df[['Team', 'Average Away xG Last 5', 'Average Away xGA Last 5']],
    left_on='Away Team',
    right_on='Team',
    how='left',
    suffixes=('_home', '_away')
).drop(columns=['Team'])  # Dropping the redundant 'Team' column after merge

# %%
import pandas as pd

# Assuming 'teams_per_match_averages', 'games_list_df', and 'teams_xg_xga_df' are already defined

# Retrieve season-long averages
season_avg_home_xg = teams_per_match_averages['per_match_home_xg'].mean()
season_avg_away_xg = teams_per_match_averages['per_match_away_xg'].mean()
season_avg_home_xga = teams_per_match_averages['per_match_home_xga'].mean()
season_avg_away_xga = teams_per_match_averages['per_match_away_xga'].mean()

# Initialize an empty list for storing game metrics along with the matchup information
games_metrics_list = []

# Loop through each game to calculate metrics using 'teams_per_match_averages'
for index, row in games_list_df.iterrows():
    home_team, away_team = row['game_matchup'].split(' vs. ')
    
    # Retrieve team stats from 'teams_per_match_averages'
    home_team_stats = teams_per_match_averages.loc[home_team]
    away_team_stats = teams_per_match_averages.loc[away_team]
    
    # Retrieve recent form from 'teams_xg_xga_df'
    home_recent_xg = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == home_team, 'Average Home xG Last 5'].values[0]
    away_recent_xg = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == away_team, 'Average Away xG Last 5'].values[0]
    home_recent_xga = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == home_team, 'Average Home xGA Last 5'].values[0]
    away_recent_xga = teams_xg_xga_df.loc[teams_xg_xga_df['Team'] == away_team, 'Average Away xGA Last 5'].values[0]
    
    # Compare recent form to season-long averages to get adjustment factors
    home_attack_factor = home_recent_xg / home_team_stats['per_match_home_xg'] if home_team_stats['per_match_home_xg'] != 0 else 1
    away_defence_factor = away_recent_xga / away_team_stats['per_match_away_xga'] if away_team_stats['per_match_away_xga'] != 0 else 1
    away_attack_factor = away_recent_xg / away_team_stats['per_match_away_xg'] if away_team_stats['per_match_away_xg'] != 0 else 1
    home_defence_factor = home_recent_xga / home_team_stats['per_match_home_xga'] if home_team_stats['per_match_home_xga'] != 0 else 1
    
    # Adjust metrics using the factors
    home_attack_adjusted = home_team_stats['per_match_home_xg'] * home_attack_factor / season_avg_home_xg
    away_defence_adjusted = away_team_stats['per_match_away_xga'] * away_defence_factor / season_avg_away_xga
    away_attack_adjusted = away_team_stats['per_match_away_xg'] * away_attack_factor / season_avg_away_xg
    home_defence_adjusted = home_team_stats['per_match_home_xga'] * home_defence_factor / season_avg_home_xga
    
    # Append the adjusted metrics for this game to the list
    games_metrics_list.append({
        'Game Matchup': row['game_matchup'],
        'Home Attack': home_attack_adjusted,
        'Away Defence': away_defence_adjusted,
        'Away Attack': away_attack_adjusted,
        'Home Defence': home_defence_adjusted
    })

# Create the DataFrame from the list
games_metrics_df = pd.DataFrame(games_metrics_list)

# Split 'Game Matchup' into 'Home Team' and 'Away Team'
games_metrics_df[['Home Team', 'Away Team']] = games_metrics_df['Game Matchup'].str.split(' vs. ', expand=True)

games_metrics_df
# Out:
#               Game Matchup  Home Attack  Away Defence  Away Attack  \
# 0  Fiorentina vs. AC Milan     1.719213      0.744272     1.565937
# 1      Genoa vs. Frosinone     0.920551      1.673589     0.892179
# 2       Lazio vs. Juventus     0.839445      0.717580     1.461061
# 3      Napoli vs. Atalanta     1.220600      1.243569     0.960720
# 4         Torino vs. Monza     0.908106      0.822134     1.121868
# 5  Bologna vs. Salernitana     1.092901      1.756258     0.382639
# 6      Cagliari vs. Verona     0.984524      1.002857     0.687419
# 7         Inter vs. Empoli     1.751731      0.740110     1.087539
# 8           Lecce vs. Roma     0.838828      1.067139     1.205322
# 9     Sassuolo vs. Udinese     0.517873      1.153631     0.789395
#
#    Home Defence   Home Team    Away Team
# 0      0.744888  Fiorentina     AC Milan
# 1      1.242860       Genoa    Frosinone
# 2      0.775183       Lazio     Juventus
# 3      0.799499      Napoli     Atalanta
# 4      0.450295      Torino        Monza
# 5      0.751607     Bologna  Salernitana
# 6      1.236250    Cagliari       Verona
# 7      0.573737       Inter       Empoli
# 8      1.367374       Lecce         Roma
# 9      1.555704    Sassuolo      Udinese

# %%
# Initialize an empty list for storing projected goals data
projected_goals_list = []

# Retrieve the league-wide average per match home and away xG
league_avg_per_match_home_xg = teams_per_match_averages.loc['Average', 'per_match_home_xg']
league_avg_per_match_away_xg = teams_per_match_averages.loc['Average', 'per_match_away_xg']

# Iterate over each row in the games_metrics_df to calculate projected goals
for index, row in games_metrics_df.iterrows():
    # Extract home and away team names from the game matchup
    home_team, away_team = row['Game Matchup'].split(' vs. ')

    # Calculate metrics using the teams' attack and defence strengths
    home_attack = row['Home Attack']
    away_defence = row['Away Defence']
    away_attack = row['Away Attack']
    home_defence = row['Home Defence']

    # Calculate projected home and away goals using the league-wide average per game xG
    projected_home_goals = home_attack * away_defence * league_avg_per_match_home_xg
    projected_away_goals = away_attack * home_defence * league_avg_per_match_away_xg

    # Calculate total projected goals
    total_projected_goals = projected_home_goals + projected_away_goals

    # Append the results to the list
    projected_goals_list.append({
        'Game Matchup': row['Game Matchup'],
        'Projected Home Goals': projected_home_goals,
        'Projected Away Goals': projected_away_goals,
        'Total Projected Goals': total_projected_goals
    })

# Convert the list to a DataFrame
projected_goals_df = pd.DataFrame(projected_goals_list)

# Display the DataFrame
projected_goals_df
# Out:
#               Game Matchup  Projected Home Goals  Projected Away Goals  \
# 0  Fiorentina vs. AC Milan              1.947692              1.396884
# 1      Genoa vs. Frosinone              2.345069              1.327911
# 2       Lazio vs. Juventus              0.916899              1.356337
# 3      Napoli vs. Atalanta              2.310482              0.919834
# 4         Torino vs. Monza              1.136419              0.604970
# 5  Bologna vs. Salernitana              2.921651              0.344409
# 6      Cagliari vs. Verona              1.502880              1.017706
# 7         Inter vs. Empoli              1.973434              0.747227
# 8           Lecce vs. Roma              1.362552              1.973718
# 9     Sassuolo vs. Udinese              0.909389              1.470673
#
#    Total Projected Goals
# 0               3.344577
# 1               3.672981
# 2               2.273236
# 3               3.230317
# 4               1.741389
# 5               3.266061
# 6               2.520586
# 7               2.720661
# 8               3.336270
# 9               2.380062

# %%
import numpy as np

# Number of simulations to run for each game
n_simulations = 10000

# Initialize lists to store the win/draw probabilities
home_win_probs = []
away_win_probs = []
draw_probs = []

for index, row in projected_goals_df.iterrows():
    home_goals_proj = row['Projected Home Goals']
    away_goals_proj = row['Projected Away Goals']

    # Simulate match outcomes
    home_goals_sim = np.random.poisson(home_goals_proj, n_simulations)
    away_goals_sim = np.random.poisson(away_goals_proj, n_simulations)

    # Calculate outcomes
    home_wins = np.sum(home_goals_sim > away_goals_sim)
    away_wins = np.sum(away_goals_sim > home_goals_sim)
    draws = np.sum(home_goals_sim == away_goals_sim)

    # Calculate probabilities
    home_win_prob = home_wins / n_simulations
    away_win_prob = away_wins / n_simulations
    draw_prob = draws / n_simulations

    # Append probabilities to lists
    home_win_probs.append(home_win_prob)
    away_win_probs.append(away_win_prob)
    draw_probs.append(draw_prob)

# Add the calculated probabilities to the projected_goals_df DataFrame
projected_goals_df['Home Win Probability'] = home_win_probs
projected_goals_df['Away Win Probability'] = away_win_probs
projected_goals_df['Draw Probability'] = draw_probs

# Convert probabilities to percentage format and append '%' sign
projected_goals_df['Home Win Probability'] = (projected_goals_df['Home Win Probability'] * 100).apply(lambda x: f'{x:.2f}%')
projected_goals_df['Away Win Probability'] = (projected_goals_df['Away Win Probability'] * 100).apply(lambda x: f'{x:.2f}%')
projected_goals_df['Draw Probability'] = (projected_goals_df['Draw Probability'] * 100).apply(lambda x: f'{x:.2f}%')

# Display the updated DataFrame with formatted probabilities
projected_goals_df
# Out:
#               Game Matchup  Projected Home Goals  Projected Away Goals  \
# 0  Fiorentina vs. AC Milan              1.947692              1.396884
# 1      Genoa vs. Frosinone              2.345069              1.327911
# 2       Lazio vs. Juventus              0.916899              1.356337
# 3      Napoli vs. Atalanta              2.310482              0.919834
# 4         Torino vs. Monza              1.136419              0.604970
# 5  Bologna vs. Salernitana              2.921651              0.344409
# 6      Cagliari vs. Verona              1.502880              1.017706
# 7         Inter vs. Empoli              1.973434              0.747227
# 8           Lecce vs. Roma              1.362552              1.973718
# 9     Sassuolo vs. Udinese              0.909389              1.470673
#
#    Total Projected Goals Home Win Probability Away Win Probability  \
# 0               3.344577               49.60%               27.66%
# 1               3.672981               60.13%               20.90%
# 2               2.273236               25.32%               47.22%
# 3               3.230317               68.75%               13.47%
# 4               1.741389               48.63%               19.40%
# 5               3.266061               88.65%                2.43%
# 6               2.520586               48.14%               25.61%
# 7               2.720661               66.31%               12.87%
# 8               3.336270               26.62%               51.15%
# 9               2.380062               23.52%               50.11%
#
#   Draw Probability
# 0           22.74%
# 1           18.97%
# 2           27.46%
# 3           17.78%
# 4           31.97%
# 5            8.92%
# 6           26.25%
# 7           20.82%
# 8           22.23%
# 9           26.37%

# %%
import requests


# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
API_KEY = '6ea2753ab77393e63fe86bb67324fc40'

SPORT = 'soccer' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h,spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# %%
import requests

# Your API key for the odds API
api_key = '6ea2753ab77393e63fe86bb67324fc40'

# Define the endpoint URL
url = 'https://api.the-odds-api.com/v4/sports/soccer_italy_serie_a/odds/'

# Parameters for the API request
params = {
    'apiKey': api_key,
    'regions': 'us',  # Adjust if targeting a different region
    'markets': 'h2h',  # Head-to-head odds; adjust if looking for different market types
    'bookmakers': 'bovada',
    'oddsFormat': 'decimal'
}

# Make the GET request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Convert the response to JSON
    odds_data = response.json()
    # Process your data here
    print(odds_data)
else:
    print(f"Error fetching data: {response.status_code}")
# Out:
# [{'id': 'b98ab57cc7bdb943c2846c5f6f6f8810', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie A - Italy', 'commence_time': '2024-03-30T11:30:00Z', 'home_team': 'Napoli', 'away_team': 'Atalanta BC', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:10:54Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:10:54Z', 'outcomes': [{'name': 'Atalanta BC', 'price': 3.35}, {'name': 'Napoli', 'price': 2.1}, {'name': 'Draw', 'price': 3.65}]}]}]}, {'id': '4da46bbe99b4f934278a2e10efca318d', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie A - Italy', 'commence_time': '2024-03-30T14:00:00Z', 'home_team': 'Genoa', 'away_team': 'Frosinone', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:10:54Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:10:54Z', 'outcomes': [{'name': 'Frosinone', 'price': 3.8}, {'name': 'Genoa', 'price': 1.95}, {'name': 'Draw', 'price': 3.6}]}]}]}, {'id': '6c6766efd8f0d38118c57fe9f1005ad5', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie A - Italy', 'commence_time': '2024-03-30T14:00:00Z', 'home_team': 'Torino', 'away_team': 'Monza', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:10:54Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:10:54Z', 'outcomes': [{'name': 'Monza', 'price': 4.5}, {'name': 'Torino', 'price': 1.83}, {'name': 'Draw', 'price': 3.5}]}]}]}, {'id': '22749b912ca3c094cc2b1b308ac20bb7', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie A - Italy', 'commence_time': '2024-03-30T17:00:00Z', 'home_team': 'Lazio', 'away_team': 'Juventus', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:10:54Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:10:54Z', 'outcomes': [{'name': 'Juventus', 'price': 2.45}, {'name': 'Lazio', 'price': 3.05}, {'name': 'Draw', 'price': 3.15}]}]}]}, {'id': 'ef0e3dc4b3cccf0604cfc3829d38375e', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie A - Italy', 'commence_time': '2024-03-30T19:45:00Z', 'home_team': 'Fiorentina', 'away_team': 'AC Milan', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:10:54Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:10:54Z', 'outcomes': [{'name': 'AC Milan', 'price': 2.55}, {'name': 'Fiorentina', 'price': 2.75}, {'name': 'Draw', 'price': 3.4}]}]}]}, {'id': 'e20cc4124ef98ae373f0bf8d2bf9a5ed', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie A - Italy', 'commence_time': '2024-04-01T10:30:00Z', 'home_team': 'Bologna', 'away_team': 'Salernitana', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:10:54Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:10:54Z', 'outcomes': [{'name': 'Bologna', 'price': 1.3}, {'name': 'Salernitana', 'price': 10.0}, {'name': 'Draw', 'price': 5.6}]}]}]}, {'id': 'b9fba05ea0ff90a0c55d54d0739c0783', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie A - Italy', 'commence_time': '2024-04-01T13:00:00Z', 'home_team': 'Cagliari', 'away_team': 'Hellas Verona FC', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:10:54Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:10:54Z', 'outcomes': [{'name': 'Cagliari', 'price': 2.2}, {'name': 'Hellas Verona FC', 'price': 3.45}, {'name': 'Draw', 'price': 3.25}]}]}]}, {'id': 'd2db9640ff2ea48c01ee88aba31be474', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie A - Italy', 'commence_time': '2024-04-01T13:00:00Z', 'home_team': 'Sassuolo', 'away_team': 'Udinese', 'bookmakers': [{'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-03-27T03:10:54Z', 'markets': [{'key': 'h2h', 'last_update': '2024-03-27T03:10:54Z', 'outcomes': [{'name': 'Sassuolo', 'price': 2.85}, {'name': 'Udinese', 'price': 2.45}, {'name': 'Draw', 'price': 3.4}]}]}]}, {'id': 'ae9f80bb78d29aba67036b44338366e5', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie ...

# %%
# Initialize an empty list to hold the simplified odds data
simplified_odds_list = []

# Iterate over the odds data
for event in odds_data:
    # Extract the essential information
    event_name = event.get('sport_title', 'No sport title')
    home_team = event.get('home_team', 'No home team')
    away_team = event.get('away_team', 'No away team')
    start_time = event.get('commence_time', 'No start time')
    
    # Initialize default odds
    home_team_odds = 'N/A'
    away_team_odds = 'N/A'
    draw_odds = 'N/A'  # Initialize draw odds

    # If there are bookmakers data available
    if event.get('bookmakers'):
        # Look for the Bovada bookmaker in the list
        for bookmaker in event['bookmakers']:
            if bookmaker['key'].lower() == 'bovada':  # Ensure case-insensitive matching
                # Assuming 'markets' is a list and we're interested in the first item (h2h)
                markets = bookmaker.get('markets', [])
                if markets:
                    # Assuming the structure of 'outcomes' in the first market
                    outcomes = markets[0].get('outcomes', [])
                    for outcome in outcomes:
                        # Assign odds based on the team or if it's a draw
                        if outcome['name'] == home_team:
                            home_team_odds = outcome.get('price', 'N/A')
                        elif outcome['name'] == away_team:
                            away_team_odds = outcome.get('price', 'N/A')
                        elif outcome['name'].lower() == 'draw':  # Checking for a draw
                            draw_odds = outcome.get('price', 'N/A')
                
                # Once we've found Bovada and extracted the odds, no need to check other bookmakers
                break

    # Create a simplified representation of the event including draw odds
    simplified_event = f"{event_name}: {home_team} vs. {away_team}, Date: {start_time}, Home Odds: {home_team_odds}, Away Odds: {away_team_odds}, Draw Odds: {draw_odds}"
    
    # Add to the list
    simplified_odds_list.append(simplified_event)

# Now, 'simplified_odds_list' contains a more readable version of the odds data, including draw odds
for item in simplified_odds_list:
    print(item)
# Out:
# Serie A - Italy: Napoli vs. Atalanta BC, Date: 2024-03-30T11:30:00Z, Home Odds: 2.1, Away Odds: 3.35, Draw Odds: 3.65
# Serie A - Italy: Genoa vs. Frosinone, Date: 2024-03-30T14:00:00Z, Home Odds: 1.95, Away Odds: 3.8, Draw Odds: 3.6
# Serie A - Italy: Torino vs. Monza, Date: 2024-03-30T14:00:00Z, Home Odds: 1.83, Away Odds: 4.5, Draw Odds: 3.5
# Serie A - Italy: Lazio vs. Juventus, Date: 2024-03-30T17:00:00Z, Home Odds: 3.05, Away Odds: 2.45, Draw Odds: 3.15
# Serie A - Italy: Fiorentina vs. AC Milan, Date: 2024-03-30T19:45:00Z, Home Odds: 2.75, Away Odds: 2.55, Draw Odds: 3.4
# Serie A - Italy: Bologna vs. Salernitana, Date: 2024-04-01T10:30:00Z, Home Odds: 1.3, Away Odds: 10.0, Draw Odds: 5.6
# Serie A - Italy: Cagliari vs. Hellas Verona FC, Date: 2024-04-01T13:00:00Z, Home Odds: 2.2, Away Odds: 3.45, Draw Odds: 3.25
# Serie A - Italy: Sassuolo vs. Udinese, Date: 2024-04-01T13:00:00Z, Home Odds: 2.85, Away Odds: 2.45, Draw Odds: 3.4
# Serie A - Italy: Lecce vs. AS Roma, Date: 2024-04-01T16:00:00Z, Home Odds: 4.2, Away Odds: 1.87, Draw Odds: 3.6
# Serie A - Italy: Inter Milan vs. Empoli, Date: 2024-04-01T18:45:00Z, Home Odds: 1.23, Away Odds: 11.0, Draw Odds: 6.75
# Serie A - Italy: Salernitana vs. Sassuolo, Date: 2024-04-05T18:45:00Z, Home Odds: 2.65, Away Odds: 2.55, Draw Odds: 3.55
# Serie A - Italy: AC Milan vs. Lecce, Date: 2024-04-06T14:00:00Z, Home Odds: 1.43, Away Odds: 7.0, Draw Odds: 4.8
# Serie A - Italy: AS Roma vs. Lazio, Date: 2024-04-06T14:00:00Z, Home Odds: 2.05, Away Odds: 3.65, Draw Odds: 3.45
# Serie A - Italy: Empoli vs. Torino, Date: 2024-04-06T14:00:00Z, Home Odds: 3.3, Away Odds: 2.25, Draw Odds: 3.3
# Serie A - Italy: Udinese vs. Inter Milan, Date: 2024-04-06T14:00:00Z, Home Odds: N/A, Away Odds: N/A, Draw Odds: N/A
# Serie A - Italy: Salernitana vs. Sassuolo, Date: 2024-04-06T14:00:00Z, Home Odds: N/A, Away Odds: N/A, Draw Odds: N/A
# Serie A - Italy: Frosinone vs. Bologna, Date: 2024-04-07T10:30:00Z, Home Odds: 3.65, Away Odds: 2.0, Draw Odds: 3.6
# Serie A - Italy: Monza vs. Napoli, Date: 2024-04-07T13:00:00Z, Home Odds: 3.95, Away Odds: 1.87, Draw Odds: 3.8
# Serie A - Italy: Cagliari vs. Atalanta BC, Date: 2024-04-07T16:00:00Z, Home Odds: 4.5, Away Odds: 1.74, Draw Odds: 4.0
# Serie A - Italy: Hellas Verona FC vs. Genoa, Date: 2024-04-07T16:00:00Z, Home Odds: 2.7, Away Odds: 2.75, Draw Odds: 3.2
# Serie A - Italy: Juventus vs. Fiorentina, Date: 2024-04-07T18:45:00Z, Home Odds: 1.83, Away Odds: 4.4, Draw Odds: 3.65
# Serie A - Italy: Udinese vs. Inter Milan, Date: 2024-04-08T18:45:00Z, Home Odds: 6.0, Away Odds: 1.51, Draw Odds: 4.5

# %%
odds_data_list = []

for event in odds_data:
    home_team = event.get('home_team')
    away_team = event.get('away_team')
    start_time = event.get('commence_time')  # Assuming datetime format or additional parsing might be needed
    
    # Initialize odds
    home_odds = 'N/A'
    away_odds = 'N/A'
    draw_odds = 'N/A'  # Initialize draw odds variable

    # Iterate through bookmakers to find Bovada and extract the odds
    for bookmaker in event.get('bookmakers', []):
        if bookmaker['key'].lower() == 'bovada':  # Ensure case-insensitive matching
            markets = bookmaker.get('markets', [])
            if markets:
                outcomes = markets[0].get('outcomes', [])
                for outcome in outcomes:
                    # Check and assign odds based on the team or if it's a draw
                    if outcome['name'] == home_team:
                        home_odds = outcome.get('price', 'N/A')
                    elif outcome['name'] == away_team:
                        away_odds = outcome.get('price', 'N/A')
                    elif outcome['name'].lower() == 'draw':  # Check for draw odds
                        draw_odds = outcome.get('price', 'N/A')

    # Append the data including draw odds to the list
    odds_data_list.append({
        'Game Matchup': f"{home_team} vs. {away_team}",
        'Home Odds': home_odds,
        'Away Odds': away_odds,
        'Draw Odds': draw_odds,  # Include draw odds
        'Start Time': start_time
    })

# Convert the list to a DataFrame
odds_df = pd.DataFrame(odds_data_list)

# %%
name_replacements = {
    'Atalanta BC': 'Atalanta',
    'Hellas Verona FC': 'Verona',
    'Inter Milan ': 'Inter ',
    'AS Roma': 'Roma'
    # Add any other specific replacements you need here
}
import pandas as pd

# Assuming odds_df is already defined

# Apply replacements in the 'Game Matchup' column
for original_name, new_name in name_replacements.items():
    odds_df['Game Matchup'] = odds_df['Game Matchup'].str.replace(original_name, new_name, regex=False)

# Display the updated DataFrame
print(odds_df)
# Out:
#                 Game Matchup Home Odds Away Odds Draw Odds  \
# 0        Napoli vs. Atalanta       2.1      3.35      3.65
# 1        Genoa vs. Frosinone      1.95       3.8       3.6
# 2           Torino vs. Monza      1.83       4.5       3.5
# 3         Lazio vs. Juventus      3.05      2.45      3.15
# 4    Fiorentina vs. AC Milan      2.75      2.55       3.4
# 5    Bologna vs. Salernitana       1.3      10.0       5.6
# 6        Cagliari vs. Verona       2.2      3.45      3.25
# 7       Sassuolo vs. Udinese      2.85      2.45       3.4
# 8             Lecce vs. Roma       4.2      1.87       3.6
# 9           Inter vs. Empoli      1.23      11.0      6.75
# 10  Salernitana vs. Sassuolo      2.65      2.55      3.55
# 11        AC Milan vs. Lecce      1.43       7.0       4.8
# 12            Roma vs. Lazio      2.05      3.65      3.45
# 13         Empoli vs. Torino       3.3      2.25       3.3
# 14   Udinese vs. Inter Milan       N/A       N/A       N/A
# 15  Salernitana vs. Sassuolo       N/A       N/A       N/A
# 16     Frosinone vs. Bologna      3.65       2.0       3.6
# 17          Monza vs. Napoli      3.95      1.87       3.8
# 18     Cagliari vs. Atalanta       4.5      1.74       4.0
# 19          Verona vs. Genoa       2.7      2.75       3.2
# 20   Juventus vs. Fiorentina      1.83       4.4      3.65
# 21   Udinese vs. Inter Milan       6.0      1.51       4.5
#
#               Start Time
# 0   2024-03-30T11:30:00Z
# 1   2024-03-30T14:00:00Z
# 2   2024-03-30T14:00:00Z
# 3   2024-03-30T17:00:00Z
# 4   2024-03-30T19:45:00Z
# 5   2024-04-01T10:30:00Z
# 6   2024-04-01T13:00:00Z
# 7   2024-04-01T13:00:00Z
# 8   2024-04-01T16:00:00Z
# 9   2024-04-01T18:45:00Z
# 10  2024-04-05T18:45:00Z
# 11  2024-04-06T14:00:00Z
# 12  2024-04-06T14:00:00Z
# 13  2024-04-06T14:00:00Z
# 14  2024-04-06T14:00:00Z
# 15  2024-04-06T14:00:00Z
# 16  2024-04-07T10:30:00Z
# 17  2024-04-07T13:00:00Z
# 18  2024-04-07T16:00:00Z
# 19  2024-04-07T16:00:00Z
# 20  2024-04-07T18:45:00Z
# 21  2024-04-08T18:45:00Z

# %%
# Assuming 'projected_goals_df' exists and has a 'Game Matchup' column
merged_df = pd.merge(projected_goals_df, odds_df, on='Game Matchup', how='left')

# Now 'merged_df' contains both the projected probabilities and the odds

# %%
merged_df
# Out:
#               Game Matchup  Projected Home Goals  Projected Away Goals  \
# 0  Fiorentina vs. AC Milan              1.947692              1.396884
# 1      Genoa vs. Frosinone              2.345069              1.327911
# 2       Lazio vs. Juventus              0.916899              1.356337
# 3      Napoli vs. Atalanta              2.310482              0.919834
# 4         Torino vs. Monza              1.136419              0.604970
# 5  Bologna vs. Salernitana              2.921651              0.344409
# 6      Cagliari vs. Verona              1.502880              1.017706
# 7         Inter vs. Empoli              1.973434              0.747227
# 8           Lecce vs. Roma              1.362552              1.973718
# 9     Sassuolo vs. Udinese              0.909389              1.470673
#
#    Total Projected Goals Home Win Probability Away Win Probability  \
# 0               3.344577               49.60%               27.66%
# 1               3.672981               60.13%               20.90%
# 2               2.273236               25.32%               47.22%
# 3               3.230317               68.75%               13.47%
# 4               1.741389               48.63%               19.40%
# 5               3.266061               88.65%                2.43%
# 6               2.520586               48.14%               25.61%
# 7               2.720661               66.31%               12.87%
# 8               3.336270               26.62%               51.15%
# 9               2.380062               23.52%               50.11%
#
#   Draw Probability Home Odds Away Odds Draw Odds            Start Time
# 0           22.74%      2.75      2.55       3.4  2024-03-30T19:45:00Z
# 1           18.97%      1.95       3.8       3.6  2024-03-30T14:00:00Z
# 2           27.46%      3.05      2.45      3.15  2024-03-30T17:00:00Z
# 3           17.78%       2.1      3.35      3.65  2024-03-30T11:30:00Z
# 4           31.97%      1.83       4.5       3.5  2024-03-30T14:00:00Z
# 5            8.92%       1.3      10.0       5.6  2024-04-01T10:30:00Z
# 6           26.25%       2.2      3.45      3.25  2024-04-01T13:00:00Z
# 7           20.82%      1.23      11.0      6.75  2024-04-01T18:45:00Z
# 8           22.23%       4.2      1.87       3.6  2024-04-01T16:00:00Z
# 9           26.37%      2.85      2.45       3.4  2024-04-01T13:00:00Z

# %%
# Convert percentage strings to decimal probabilities
merged_df['Home Win Probability'] = merged_df['Home Win Probability'].str.rstrip('%').astype(float) / 100
merged_df['Away Win Probability'] = merged_df['Away Win Probability'].str.rstrip('%').astype(float) / 100
merged_df['Draw Probability'] = merged_df['Draw Probability'].str.rstrip('%').astype(float) / 100
# Calculate implied odds
merged_df['Implied Home Odds'] = 1 / merged_df['Home Win Probability']
merged_df['Implied Away Odds'] = 1 / merged_df['Away Win Probability']
merged_df['Implied Draw Odds'] = 1 / merged_df['Draw Probability']
# Create a new DataFrame with implied odds
implied_odds_df = merged_df[['Game Matchup', 'Implied Home Odds', 'Implied Away Odds', 'Implied Draw Odds', 'Home Odds', 'Away Odds', 'Draw Odds']].copy()

# %%
implied_odds_df
# Out:
#               Game Matchup  Implied Home Odds  Implied Away Odds  \
# 0  Fiorentina vs. AC Milan           2.016129           3.615329
# 1      Genoa vs. Frosinone           1.663063           4.784689
# 2       Lazio vs. Juventus           3.949447           2.117747
# 3      Napoli vs. Atalanta           1.454545           7.423905
# 4         Torino vs. Monza           2.056344           5.154639
# 5  Bologna vs. Salernitana           1.128032          41.152263
# 6      Cagliari vs. Verona           2.077275           3.904725
# 7         Inter vs. Empoli           1.508068           7.770008
# 8           Lecce vs. Roma           3.756574           1.955034
# 9     Sassuolo vs. Udinese           4.251701           1.995610
#
#    Implied Draw Odds Home Odds Away Odds Draw Odds
# 0           4.397537      2.75      2.55       3.4
# 1           5.271481      1.95       3.8       3.6
# 2           3.641661      3.05      2.45      3.15
# 3           5.624297       2.1      3.35      3.65
# 4           3.127932      1.83       4.5       3.5
# 5          11.210762       1.3      10.0       5.6
# 6           3.809524       2.2      3.45      3.25
# 7           4.803074      1.23      11.0      6.75
# 8           4.498426       4.2      1.87       3.6
# 9           3.792188      2.85      2.45       3.4

# %%
import pandas as pd

# Assuming implied_odds_df is already defined

# Convert object columns to numeric
cols_to_convert = ['Home Odds', 'Away Odds', 'Draw Odds']
implied_odds_df[cols_to_convert] = implied_odds_df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# Round implied odds to 2 decimal places
implied_odds_df['Implied Home Odds'] = round(implied_odds_df['Implied Home Odds'], 2)
implied_odds_df['Implied Away Odds'] = round(implied_odds_df['Implied Away Odds'], 2)
implied_odds_df['Implied Draw Odds'] = round(implied_odds_df['Implied Draw Odds'], 2)

# Calculate edge for home win
implied_odds_df['Home Win Edge'] = round((1 / implied_odds_df['Implied Home Odds']) * implied_odds_df['Home Odds'] - 1, 2)

# Calculate edge for away win
implied_odds_df['Away Win Edge'] = round((1 / implied_odds_df['Implied Away Odds']) * implied_odds_df['Away Odds'] - 1, 2)

# Calculate edge for draw
implied_odds_df['Draw Edge'] = round((1 / implied_odds_df['Implied Draw Odds']) * implied_odds_df['Draw Odds'] - 1, 2)

# Round edges to 2 decimal places
implied_odds_df['Home Win Edge'] = round(implied_odds_df['Home Win Edge'], 2)
implied_odds_df['Away Win Edge'] = round(implied_odds_df['Away Win Edge'], 2)
implied_odds_df['Draw Edge'] = round(implied_odds_df['Draw Edge'], 2)

print(implied_odds_df)
# Out:
#               Game Matchup  Implied Home Odds  Implied Away Odds  \
# 0  Fiorentina vs. AC Milan               2.02               3.62
# 1      Genoa vs. Frosinone               1.66               4.78
# 2       Lazio vs. Juventus               3.95               2.12
# 3      Napoli vs. Atalanta               1.45               7.42
# 4         Torino vs. Monza               2.06               5.15
# 5  Bologna vs. Salernitana               1.13              41.15
# 6      Cagliari vs. Verona               2.08               3.90
# 7         Inter vs. Empoli               1.51               7.77
# 8           Lecce vs. Roma               3.76               1.96
# 9     Sassuolo vs. Udinese               4.25               2.00
#
#    Implied Draw Odds  Home Odds  Away Odds  Draw Odds  Home Win Edge  \
# 0               4.40       2.75       2.55       3.40           0.36
# 1               5.27       1.95       3.80       3.60           0.17
# 2               3.64       3.05       2.45       3.15          -0.23
# 3               5.62       2.10       3.35       3.65           0.45
# 4               3.13       1.83       4.50       3.50          -0.11
# 5              11.21       1.30      10.00       5.60           0.15
# 6               3.81       2.20       3.45       3.25           0.06
# 7               4.80       1.23      11.00       6.75          -0.19
# 8               4.50       4.20       1.87       3.60           0.12
# 9               3.79       2.85       2.45       3.40          -0.33
#
#    Away Win Edge  Draw Edge
# 0          -0.30      -0.23
# 1          -0.21      -0.32
# 2           0.16      -0.13
# 3          -0.55      -0.35
# 4          -0.13       0.12
# 5          -0.76      -0.50
# 6          -0.12      -0.15
# 7           0.42       0.41
# 8          -0.05      -0.20
# 9           0.23      -0.10

# %%
print(implied_odds_df.dtypes)
# Out:
# Game Matchup          object
# Implied Home Odds    float64
# Implied Away Odds    float64
# Implied Draw Odds    float64
# Home Odds            float64
# Away Odds            float64
# Draw Odds            float64
# Home Win Edge        float64
# Away Win Edge        float64
# Draw Edge            float64
# dtype: object

# %%
# Assuming 'projected_goals_df' is the DataFrame containing projected goals

# Merge the implied odds DataFrame with the projected goals DataFrame on the 'Game Matchup' column
implied_odds_with_goals = implied_odds_df.merge(projected_goals_df, on='Game Matchup', how='left')

# Display the DataFrame with projected goals added
implied_odds_with_goals
# Out:
#               Game Matchup  Implied Home Odds  Implied Away Odds  \
# 0  Fiorentina vs. AC Milan               2.02               3.62
# 1      Genoa vs. Frosinone               1.66               4.78
# 2       Lazio vs. Juventus               3.95               2.12
# 3      Napoli vs. Atalanta               1.45               7.42
# 4         Torino vs. Monza               2.06               5.15
# 5  Bologna vs. Salernitana               1.13              41.15
# 6      Cagliari vs. Verona               2.08               3.90
# 7         Inter vs. Empoli               1.51               7.77
# 8           Lecce vs. Roma               3.76               1.96
# 9     Sassuolo vs. Udinese               4.25               2.00
#
#    Implied Draw Odds  Home Odds  Away Odds  Draw Odds  Home Win Edge  \
# 0               4.40       2.75       2.55       3.40           0.36
# 1               5.27       1.95       3.80       3.60           0.17
# 2               3.64       3.05       2.45       3.15          -0.23
# 3               5.62       2.10       3.35       3.65           0.45
# 4               3.13       1.83       4.50       3.50          -0.11
# 5              11.21       1.30      10.00       5.60           0.15
# 6               3.81       2.20       3.45       3.25           0.06
# 7               4.80       1.23      11.00       6.75          -0.19
# 8               4.50       4.20       1.87       3.60           0.12
# 9               3.79       2.85       2.45       3.40          -0.33
#
#    Away Win Edge  Draw Edge  Projected Home Goals  Projected Away Goals  \
# 0          -0.30      -0.23              1.947692              1.396884
# 1          -0.21      -0.32              2.345069              1.327911
# 2           0.16      -0.13              0.916899              1.356337
# 3          -0.55      -0.35              2.310482              0.919834
# 4          -0.13       0.12              1.136419              0.604970
# 5          -0.76      -0.50              2.921651              0.344409
# 6          -0.12      -0.15              1.502880              1.017706
# 7           0.42       0.41              1.973434              0.747227
# 8          -0.05      -0.20              1.362552              1.973718
# 9           0.23      -0.10              0.909389              1.470673
#
#    Total Projected Goals Home Win Probability Away Win Probability  \
# 0               3.344577               49.60%               27.66%
# 1               3.672981               60.13%               20.90%
# 2               2.273236               25.32%               47.22%
# 3               3.230317               68.75%               13.47%
# 4               1.741389               48.63%               19.40%
# 5               3.266061               88.65%                2.43%
# 6               2.520586               48.14%               25.61%
# 7               2.720661               66.31%               12.87%
# 8               3.336270               26.62%               51.15%
# 9               2.380062               23.52%               50.11%
#
#   Draw Probability
# 0           22.74%
# 1           18.97%
# 2           27.46%
# 3           17.78%
# 4           31.97%
# 5            8.92%
# 6           26.25%
# 7           20.82%
# 8           22.23%
# 9           26.37%

# %%
# Save the DataFrame to a CSV file
implied_odds_with_goals.to_csv('Italy_odds_3-29.csv', index=False)

# %%
# Define a function to color code values based on conditions
def color_edges(val):
    if val < 0:
        return 'background-color: maroon'
    elif 0.0 <= val < 0.1:
        return 'background-color: yellow'
    else:
        return 'background-color: green'

# Apply the styling to the specified columns
styled_df = implied_odds_with_goals.style.applymap(color_edges, subset=['Home Win Edge', 'Away Win Edge', 'Draw Edge'])

# Display the styled DataFrame
styled_df
# Out:
# C:\Users\jbuck\AppData\Local\Temp\ipykernel_31068\2992074314.py:11: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = implied_odds_with_goals.style.applymap(color_edges, subset=['Home Win Edge', 'Away Win Edge', 'Draw Edge'])
# <style type="text/css">
# #T_2cdbc_row0_col7, #T_2cdbc_row1_col7, #T_2cdbc_row2_col8, #T_2cdbc_row3_col7, #T_2cdbc_row4_col9, #T_2cdbc_row5_col7, #T_2cdbc_row7_col8, #T_2cdbc_row7_col9, #T_2cdbc_row8_col7, #T_2cdbc_row9_col8 {
#   background-color: green;
# }
# #T_2cdbc_row0_col8, #T_2cdbc_row0_col9, #T_2cdbc_row1_col8, #T_2cdbc_row1_col9, #T_2cdbc_row2_col7, #T_2cdbc_row2_col9, #T_2cdbc_row3_col8, #T_2cdbc_row3_col9, #T_2cdbc_row4_col7, #T_2cdbc_row4_col8, #T_2cdbc_row5_col8, #T_2cdbc_row5_col9, #T_2cdbc_row6_col8, #T_2cdbc_row6_col9, #T_2cdbc_row7_col7, #T_2cdbc_row8_col8, #T_2cdbc_row8_col9, #T_2cdbc_row9_col7, #T_2cdbc_row9_col9 {
#   background-color: maroon;
# }
# #T_2cdbc_row6_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2cdbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cdbc_level0_col0" class="col_heading level0 col0" >Game Matchup</th>
#       <th id="T_2cdbc_level0_col1" class="col_heading level0 col1" >Implied Home Odds</th>
#       <th id="T_2cdbc_level0_col2" class="col_heading level0 col2" >Implied Away Odds</th>
#       <th id="T_2cdbc_level0_col3" class="col_heading level0 col3" >Implied Draw Odds</th>
#       <th id="T_2cdbc_level0_col4" class="col_heading level0 col4" >Home Odds</th>
#       <th id="T_2cdbc_level0_col5" class="col_heading level0 col5" >Away Odds</th>
#       <th id="T_2cdbc_level0_col6" class="col_heading level0 col6" >Draw Odds</th>
#       <th id="T_2cdbc_level0_col7" class="col_heading level0 col7" >Home Win Edge</th>
#       <th id="T_2cdbc_level0_col8" class="col_heading level0 col8" >Away Win Edge</th>
#       <th id="T_2cdbc_level0_col9" class="col_heading level0 col9" >Draw Edge</th>
#       <th id="T_2cdbc_level0_col10" class="col_heading level0 col10" >Projected Home Goals</th>
#       <th id="T_2cdbc_level0_col11" class="col_heading level0 col11" >Projected Away Goals</th>
#       <th id="T_2cdbc_level0_col12" class="col_heading level0 col12" >Total Projected Goals</th>
#       <th id="T_2cdbc_level0_col13" class="col_heading level0 col13" >Home Win Probability</th>
#       <th id="T_2cdbc_level0_col14" class="col_heading level0 col14" >Away Win Probability</th>
#       <th id="T_2cdbc_level0_col15" class="col_heading level0 col15" >Draw Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cdbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2cdbc_row0_col0" class="data row0 col0" >Fiorentina vs. AC Milan</td>
#       <td id="T_2cdbc_row0_col1" class="data row0 col1" >2.020000</td>
#       <td id="T_2cdbc_row0_col2" class="data row0 col2" >3.620000</td>
#       <td id="T_2cdbc_row0_col3" class="data row0 col3" >4.400000</td>
#       <td id="T_2cdbc_row0_col4" class="data row0 col4" >2.750000</td>
#       <td id="T_2cdbc_row0_col5" class="data row0 col5" >2.550000</td>
#       <td id="T_2cdbc_row0_col6" class="data row0 col6" >3.400000</td>
#       <td id="T_2cdbc_row0_col7" class="data row0 col7" >0.360000</td>
#       <td id="T_2cdbc_row0_col8" class="data row0 col8" >-0.300000</td>
#       <td id="T_2cdbc_row0_col9" class="data row0 col9" >-0.230000</td>
#       <td id="T_2cdbc_row0_col10" class="data row0 col10" >1.947692</td>
#       <td id="T_2cdbc_row0_col11" class="data row0 col11" >1.396884</td>
#       <td id="T_2cdbc_row0_col12" class="data row0 col12" >3.344577</td>
#       <td id="T_2cdbc_row0_col13" class="data row0 col13" >49.60%</td>
#       <td id="T_2cdbc_row0_col14" class="data row0 col14" >27.66%</td>
#       <td id="T_2cdbc_row0_col15" class="data row0 col15" >22.74%</td>
#     </tr>
#     <tr>
#       <th id="T_2cdbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2cdbc_row1_col0" class="data row1 col0" >Genoa vs. Frosinone</td>
#       <td id="T_2cdbc_row1_col1" class="data row1 col1" >1.660000</td>
#       <td id="T_2cdbc_row1_col2" class="data row1 col2" >4.780000</td>
#       <td id="T_2cdbc_row1_col3" class="data row1 col3" >5.270000</td>
#       <td id="T_2cdbc_row1_col4" class="data row1 col4" >1.950000</td>
#       <td id="T_2cdbc_row1_col5" class="data row1 col5" >3.800000</td>
#       <td id="T_2cdbc_row1_col6" class="data row1 col6" >3.600000</td>
#       <td id="T_2cdbc_row1_col7" class="data row1 col7" >0.170000</td>
#       <td id="T_2cdbc_row1_col8" class="data row1 col8" >-0.210000</td>
#       <td id="T_2cdbc_row1_col9" class="data row1 col9" >-0.320000</td>
#       <td id="T_2cdbc_row1_col10" class="data row1 col10" >2.345069</td>
#       <td id="T_2cdbc_row1_col11" class="data row1 col11" >1.327911</td>
#       <td id="T_2cdbc_row1_col12" class="data row1 col12" >3.672981</td>
#       <td id="T_2cdbc_row1_col13" class="data row1 col13" >60.13%</td>
#       <td id="T_2cdbc_row1_col14" class="data row1 col14" >20.90%</td>
#       <td id="T_2cdbc_row1_col15" class="data row1 col15" >18.97%</td>
#     </tr>
#     <tr>
#       <th id="T_2cdbc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2cdbc_row2_col0" class="data row2 col0" >Lazio vs. Juventus</td>
#       <td id="T_2cdbc_row2_col1" class="data row2 col1" >3.950000</td>
#       <td id="T_2cdbc_row2_col2" class="data row2 col2" >2.120000</td>
#       <td id="T_2cdbc_row2_col3" class="data row2 col3" >3.640000</td>
#       <td id="T_2cdbc_row2_col4" class="data row2 col4" >3.050000</td>
#       <td id="T_2cdbc_row2_col5" class="data row2 col5" >2.450000</td>
#       <td id="T_2cdbc_row2_col6" class="data row2 col6" >3.150000</td>
#       <td id="T_2cdbc_row2_col7" class="data row2 col7" >-0.230000</td>
#       <td id="T_2cdbc_row2_col8" class="data row2 col8" >0.160000</td>
#       <td id="T_2cdbc_row2_col9" class="data row2 col9" >-0.130000</td>
#       <td id="T_2cdbc_row2_col10" class="data row2 col10" >0.916899</td>
#       <td id="T_2cdbc_row2_col11" class="data row2 col11" >1.356337</td>
#       <td id="T_2cdbc_row2_col12" class="data row2 col12" >2.273236</td>
#       <td id="T_2cdbc_row2_col13" class="data row2 col13" >25.32%</td>
#       <td id="T_2cdbc_row2_col14" class="data row2 col14" >47.22%</td>
#       <td id="T_2cdbc_row2_col15" class="data row2 col15" >27.46%</td>
#     </tr>
#     <tr>
#       <th id="T_2cdbc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2cdbc_row3_col0" class="data row3 col0" >Napoli vs. Atalanta</td>
#       <td id="T_2cdbc_row3_col1" class="data row3 col1" >1.450000</td>
#       <td id="T_2cdbc_row3_col2" class="data row3 col2" >7.420000</td>
#       <td id="T_2cdbc_row3_col3" class="data row3 col3" >5.620000</td>
#       <td id="T_2cdbc_row3_col4" class="data row3 col4" >2.100000</td>
#       <td id="T_2cdbc_row3_col5" class="data row3 col5" >3.350000</td>
#       <td id="T_2cdbc_row3_col6" class="data row3 col6" >3.650000</td>
#       <td id="T_2cdbc_row3_col7" class="data row3 col7" >0.450000</td>
#       <td id="T_2cdbc_row3_col8" class="data row3 col8" >-0.550000</td>
#       <td id="T_2cdbc_row3_col9" class="data row3 col9" >-0.350000</td>
#       <td id="T_2cdbc_row3_col10" class="data row3 col10" >2.310482</td>
#       <td id="T_2cdbc_row3_col11" class="data row3 col11" >0.919834</td>
#       <td id="T_2cdbc_row3_col12" class="data row3 col12" >3.230317</td>
#       <td id="T_2cdbc_row3_col13" class="data row3 col13" >68.75%</td>
#       <td id="T_2cdbc_row3_col14" class="data row3 col14" >13.47%</td>
#       <td id="T_2cdbc_row3_col15" class="data row3 col15" >17.78%</td>
#     </tr>
#     <tr>
#       <th id="T_2cdbc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2cdbc_row4_col0" class="data row4 col0" >Torino vs. Monza</td>
#       <td id="T_2cdbc_row4_col1" class="data row4 col1" >2.060000</td>
#       <td id="T_2cdbc_row4_col2" class="data row4 col2" >5.150000</td>
#       <td id="T_2cdbc_row4_col3" class="data row4 col3" >3.130000</td>
#       <td id="T_2cdbc_row4_col4" class="data row4 col4" >1.830000</td>
#       <td id="T_2cdbc_row4_col5" class="data row4 col5" >4.500000</td>
#       <td id="T_2cdbc_row4_col6" class="data row4 col6" >3.500000</td>
#       <td id="T_2cdbc_row4_col7" class="data row4 col7" >-0.110000</td>
#       <td id="T_2cdbc_row4_col8" class="data row4 col8" >-0.13

# %%
# Round all numbers to the 2nd decimal place
styled_df = styled_df.format('{:.2f}')

# Display the styled DataFrame with rounded numbers
styled_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:408, in Styler._repr_html_(self)
#     403 """
#     404 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     405 default if an object is returned at the end of a cell.
#     406 """
#     407 if get_option("styler.render.repr") == "html":
# --> 408     return self.to_html()
#     409 return None
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1348, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1345     obj.set_caption(caption)
#    1347 # Build HTML string..
# -> 1348 html = obj._render_html(
#    1349     sparse_index=sparse_index,
#    1350     sparse_columns=sparse_columns,
#    1351     max_rows=max_rows,
#    1352     max_cols=max_columns,
#    1353     exclude_styles=exclude_styles,
#    1354     encoding=encoding or get_option("styler.render.encoding"),
#    1355     doctype_html=doctype_html,
#    1356     **kwargs,
#    1357 )
#    1359 return save_to_buffer(
#    1360     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1361 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:204, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     192 def _render_html(
#     193     self,
#     194     sparse_index: bool,
#    (...)
#     198     **kwargs,
#     199 ) -> str:
#     200     """
#     201     Renders the ``Styler`` including all applied styles to HTML.
#     202     Generates a dict with necessary kwargs passed to jinja2 template.
#     203     """
# --> 204     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     205     d.update(kwargs)
#     206     return self.template_html.render(
#     207         **d,
#     208         html_table_tpl=self.template_html_table,
#     209         html_style_tpl=self.template_html_style,
#     210     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:187, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     183         self.ctx_index[(r + ctx_len, c)] = v
#     185     ctx_len += len(concatenated.index)
# --> 187 d = self._translate(
#     188     sparse_index, sparse_columns, max_rows, max_cols, blank, dxs
#     189 )
#     190 return d
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:335, in StylerRenderer._translate(self, sparse_index, sparse_cols, max_rows, max_cols, blank, dxs)
#     329 self.cellstyle_map: DefaultDict[tuple[CSSPair, ...], list[str]] = defaultdict(
#     330     list
#     331 )
#     332 self.cellstyle_map_index: DefaultDict[
#     333     tuple[CSSPair, ...], list[str]
#     334 ] = defaultdict(list)
# --> 335 body: list = self._translate_body(idx_lengths, max_rows, max_cols)
#     336 d.update({"body": body})
#     338 ctx_maps = {
#     339     "cellstyle": "cellstyle_map",
#     340     "cellstyle_index": "cellstyle_map_index",
#     341     "cellstyle_columns": "cellstyle_map_columns",
#     342 }  # add the cell_ids styles map to the render dictionary in right format
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:629, in StylerRenderer._translate_body(self, idx_lengths, max_rows, max_cols)
#     621     if self._check_trim(
#     622         visible_row_count,
#     623         max_rows,
#     624         body,
#     625         "row",
#     626     ):
#     627         break
# --> 629     body_row = self._generate_body_row(
#     630         (r, row_tup, rlabels), max_cols, idx_lengths
#     631     )
#     632     body.append(body_row)
#     633 return body
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:826, in StylerRenderer._generate_body_row(self, iter, max_cols, idx_lengths)
#     814 if (r, c) in self.cell_context:
#     815     cls = " " + self.cell_context[r, c]
#     817 data_element = _element(
#     818     "td",
#     819     (
#     820         f"{self.css['data']} {self.css['row']}{r} "
#     821         f"{self.css['col']}{c}{cls}"
#     822     ),
#     823     value,
#     824     data_element_visible,
#     825     attributes="",
# --> 826     display_value=self._display_funcs[(r, c)](value),
#     827 )
#     829 if self.cell_ids:
#     830     data_element["id"] = f"{self.css['row']}{r}_{self.css['col']}{c}"
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:1829, in _maybe_wrap_formatter.<locals>.<lambda>(x)
#    1827 # Get initial func from input string, input callable, or from default factory
#    1828 if isinstance(formatter, str):
# -> 1829     func_0 = lambda x: formatter.format(x)
#    1830 elif callable(formatter):
#    1831     func_0 = formatter
#
# ValueError: Unknown format code 'f' for object of type 'str'
